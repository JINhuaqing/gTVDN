# %% [markdown]
# In this file, we use the eig-decomposition

# %%
import gtvdn_utils
import post_process
import utils
import importlib
importlib.reload(gtvdn_utils)
importlib.reload(post_process);
importlib.reload(utils);

# %%
from pathlib import Path
from scipy.io import loadmat
import numpy as np
from easydict import EasyDict as edict
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from gtvdn_utils import get_bspline_est , get_newdata, screening, dyna_prog
from post_process import est_eigvals, update_kp
from utils import paras2name, eig_sorted, euclidean_proj_l1ball
from tqdm import trange
# %matplotlib inline

# %%
from scipy.stats import ttest_ind
import seaborn as sns

# %% [markdown]
# ## Some functions

# %% [markdown]
# ### Preprocess

# %%
# Preprocessing function
from scipy.signal import detrend, decimate
def preprocess_MEG(Ymats, paras):
    """args:
            Ymats: multiple MEG datasets, N x d x n, 
                   N is num of datasets, d is number of ROIs and n is the length of the sequences
            paras: Parameters for preprocess, dict
                   is_detrend: whether or detrend or not, Bool
                   decimate_rate: The rate to decimate from MEG data, reduce the resolution. If None, not decimate. Integer or None
    """
    # Decimate the data first
    decimate_rate = paras.decimate_rate
    if decimate_rate is not None:
        Ymats = decimate(Ymats, decimate_rate, ftype="fir")

    # Then Detrend the data
    is_detrend = paras.is_detrend
    if is_detrend:
        Ymats = detrend(Ymats)
            

    return Ymats

# %% [markdown]
# ### Estimate Amat

# %%
from scipy.stats import iqr

def lowrankA(Amat, rankKp=30):
    eigVals, eigVecs = eig_sorted(Amat)
    # if breaking conjugate eigval pair, add rankKp with 1
    if (eigVals[rankKp-1].imag + eigVals[rankKp].imag ) == 0:
        rankKp = rankKp + 1
    redAmat = np.matmul(np.matmul(eigVecs[:, :rankKp], np.diag(eigVals[:rankKp])), np.linalg.inv(eigVecs)[:rankKp, :])
    return redAmat.real

# bw.nrd0 fn in R
def bwnrd0_py(x):
    hi = np.std(x, ddof=1)
    lo = np.min((hi, iqr(x)/1.34))
    eps = 1e-10
    if np.abs(lo-0) <= eps:
        if np.abs(hi-0) > eps:
            lo = hi
        elif np.abs(x[0]-0) > eps:
            lo = x[0]
        else:
            lo = 1
    rev = 0.9 * lo * len(x)**(-0.2)
    return rev   

# Function to obtain the sum of Ai matrix
def get_Amat(dXmats, Xmats, timeSpan, downrate=1, fct=1, nRks=10, is_sum=False):
    """
    Input: 
        dXmats: The first derivative of Xmats, N x d x n matrix
        Xmats: Xmat, N x d x n matrix
        timeSpan: A list of time points with length n
        downrate: The downrate factor, determine how many Ai matrix to be summed
        nRks# the rank to keep when estimating the Amat for each data
    Return:
        A d x d matrix, it is sum of N x n/downrate  Ai matrix
    """
    h = bwnrd0_py(timeSpan)*fct
    N, d, n = Xmats.shape
    if is_sum:
        Amat = np.zeros((d, d))
    else:
        Amat = np.eye(d)
    for ix in trange(N):
        Xmat, dXmat = Xmats[ix, :, :], dXmats[ix, :, :]
        curAmat = np.zeros((d, d))
        flag = 0
        for s in timeSpan[::downrate]:
            t_diff = timeSpan - s
            kernels = 1/np.sqrt(2*np.pi) * np.exp(-t_diff**2/2/h**2) # normal_pdf(x/h)
            kernelroot = kernels ** (1/2)
            kerdXmat = kernelroot[:, np.newaxis] * (dXmat.T) # n x d
            kerXmat = kernelroot[:, np.newaxis] * (Xmat.T) # n x d
            M = kerXmat.T.dot(kerXmat)/n
            XY = kerdXmat.T.dot(kerXmat)/n # it is Y\trans x X , formula is Amat = Y\trans X (X\trans X)^{-1}
            U, S, VT = np.linalg.svd(M)
            # Num of singular values to keep
            r = np.argmax(np.cumsum(S)/np.sum(S) >= 0.999) + 1 # For real data
            invM = VT.T[:, :r].dot(np.diag(1/S[:r])).dot(U.T[:r, :]) # M is symmetric and PSD
            curAmat = curAmat + XY.dot(invM)
            flag += 1
            
        if is_sum:
            Amat = Amat + lowrankA(curAmat/flag, nRks)
        else:
            curAmat = curAmat/np.sqrt(flag)
            Amat = np.matmul(Amat, curAmat)
    return Amat



# Function to obtain the sum of Ai matrix
def get_Amats(dXmats, Xmats, timeSpan, downrate=1, fct=1, nRks=10, is_sum=False):
    """
    Input: 
        dXmats: The first derivative of Xmats, N x d x n matrix
        Xmats: Xmat, N x d x n matrix
        timeSpan: A list of time points with length n
        downrate: The downrate factor, determine how many Ai matrix to be summed
        nRks# the rank to keep when estimating the Amat for each data
    Return:
        A d x d matrix, it is sum of N x n/downrate  Ai matrix
    """
    h = bwnrd0_py(timeSpan)*fct
    N, d, n = Xmats.shape
    Amats = []
    AmatsLow = []
    for ix in trange(N):
        Xmat, dXmat = Xmats[ix, :, :], dXmats[ix, :, :]
        curAmat = np.zeros((d, d))
        flag = 0
        for s in timeSpan[::downrate]:
            t_diff = timeSpan - s
            kernels = 1/np.sqrt(2*np.pi) * np.exp(-t_diff**2/2/h**2) # normal_pdf(x/h)
            kernelroot = kernels ** (1/2)
            kerdXmat = kernelroot[:, np.newaxis] * (dXmat.T) # n x d
            kerXmat = kernelroot[:, np.newaxis] * (Xmat.T) # n x d
            M = kerXmat.T.dot(kerXmat)/n
            XY = kerdXmat.T.dot(kerXmat)/n # it is Y\trans x X , formula is Amat = Y\trans X (X\trans X)^{-1}
            U, S, VT = np.linalg.svd(M)
            # Num of singular values to keep
            r = np.argmax(np.cumsum(S)/np.sum(S) >= 0.999) + 1 # For real data
            invM = VT.T[:, :r].dot(np.diag(1/S[:r])).dot(U.T[:r, :]) # M is symmetric and PSD
            curAmat = curAmat + XY.dot(invM)
            flag += 1
            
        Amats.append(curAmat/flag)
        AmatsLow.append(lowrankA(curAmat/flag, nRks))
    return AmatsLow

# %% [markdown]
# ### misc

# %%
comsum_percent = lambda x: np.cumsum(np.abs(x))/np.sum(np.abs(x))

# %%
def euclidean_proj_l1ball_cplx(curVal, L):
    curValAbs = np.abs(curVal)
    redValAbs = euclidean_proj_l1ball(curValAbs.copy(), L)
    ratioValAbs = redValAbs/curValAbs
    redVal = curVal * ratioValAbs
    return redVal

def euclidean_proj_l1ball_cplxmat(curMat, L):
    curMatAbs = np.abs(curMat)
    rowNorms = np.sum(np.abs(curMatAbs), axis=1)
    redRowNorms = euclidean_proj_l1ball(rowNorms.copy(), L)
    rowNorms[rowNorms==0] = 1e-5 # avoid divided-by-0 error
    ratioVec = redRowNorms/rowNorms
    curMatRed = ratioVec.reshape(-1, 1) * curMat
    return curMatRed, redRowNorms

def euclidean_proj_l1ball_cplxmul(eigValsMat, L1):
    singleRedCurValList = []
    for ix in range(eigValsMat.shape[-1]):
        curVal = eigValsMat[:, ix]
        redCurVal = euclidean_proj_l1ball_Cplx(curVal.copy(), L1)
        singleRedCurValList.append(redCurVal)
    singleRedCurValMat = np.array(singleRedCurValList).T
    return singleRedCurValMat

# %%
def idenCPD(res):
    """
    args:
        res: the results from parafac function with normalize_factors=True
    return:
        For a D-dim tensor, normalize the first (D-1) components with L2 norm 1  and
                            sort the vector in the last model via its L2 norm.
    """
    factors = res.factors
    weights = res.weights
    sortIdxs = np.argsort(-weights)
    weightsSorted = weights[sortIdxs]
    factorsSorted = [factor[:, sortIdxs] for factor in factors]
    res.weights = np.ones_like(weightsSorted)
    res.factors = factorsSorted
    res.factors[-1] = factorsSorted[-1] * weightsSorted
    return res

def minmax_mat(Mat, is_row=True):
    if is_row:
        mins = np.min(Mat, axis=1)[:, np.newaxis]
        maxs = np.max(Mat, axis=1)[:, np.newaxis]
    else:
        mins = np.min(Mat, axis=0)[np.newaxis, :]
        maxs = np.max(Mat, axis=0)[np.newaxis, :]
    rv = (Mat-mins)/(maxs-mins)
    return rv

# %%
import tensorly as tl
import tensortools as tt
from tensortools.operations import unfold as tt_unfold, khatri_rao

def decompose_three_way_orth(tensor, rank, max_iter=501, verbose=False, init=None):

    if init is None:
        aT, _ = np.linalg.qr(np.random.random((rank, tensor.shape[0])).T)
        a = aT.T
        bT, _ = np.linalg.qr(np.random.random((rank, tensor.shape[1])).T)
        b = bT.T
        #c = np.random.random((rank, tensor.shape[2]))
    else:
        aT, bT = init
        a, b = aT.T, bT.T

    for epoch in range(max_iter):
        # optimize c
        input_c = khatri_rao([a.T, b.T])
        target_c = tl.unfold(tensor, mode=2).T
        c = np.linalg.solve(input_c.T.dot(input_c), input_c.T.dot(target_c))
        
        # optimize a
        input_a = khatri_rao([b.T, c.T])
        target_a = tl.unfold(tensor, mode=0).T
        a = np.linalg.solve(input_a.T.dot(input_a), input_a.T.dot(target_a))
        aT, _ = np.linalg.qr(a.T)
        a = aT.T
        #a = orth(a.T).T

        # optimize b
        input_b = khatri_rao([a.T, c.T])
        target_b = tl.unfold(tensor, mode=1).T
        b = np.linalg.solve(input_b.T.dot(input_b), input_b.T.dot(target_b))
        bT, _ = np.linalg.qr(b.T)
        b = bT.T
        #b = orth(b.T).T


        if verbose and epoch % int(max_iter * .10) == 0:
            res_a = np.square(input_a.dot(a) - target_a)
            res_b = np.square(input_b.dot(b) - target_b)
            res_c = np.square(input_c.dot(c) - target_c)
            print("Epoch:", epoch, "| Loss (C):", res_a.mean(), "| Loss (B):", res_b.mean(), "| Loss (C):", res_c.mean())

    return a.T, b.T, c.T

def decompose_three_way_orth_fix(tensor, init=None):

    aT, bT = init
    a, b = aT.T, bT.T

    input_c = khatri_rao([a.T, b.T])
    target_c = tl.unfold(tensor, mode=2).T
    c = np.linalg.solve(input_c.T.dot(input_c), input_c.T.dot(target_c))
        
    return a.T, b.T, c.T

# %%
def sort_orthCPD(res):
    """
    args:
        res: a, b, c
    return:
        For the 3-dim tensor,  sort the vector in the last model via its L2 norm.
    """
    B1, B2, B3 = res
    ws = np.sum(B3**2, axis=0)
    sortIds = np.argsort(-ws)
    sortB1 = B1[:, sortIds]
    sortB2 = B2[:, sortIds]
    sortB3 = B3[:, sortIds]
    return sortB1, sortB2, sortB3

# %%
def cumsum_cutoff(vec, cutoff=0.8):
    sorted_idx = np.argsort(-vec)
    ratio_vec = np.cumsum(vec[sorted_idx])/np.sum(vec)
    rank = np.sum(ratio_vec <cutoff) + 1
    keep_idx = np.sort(sorted_idx[:rank])
    return keep_idx

# %% [markdown]
# ## Load data

# %%
dataDir = Path("../data")
resDir = Path("../results")

# %%
datFil = list(dataDir.glob("70Ctrl*"))[0]
CtrlDat1 = loadmat(datFil)
CtrlDats = CtrlDat1["dk10"]

# %%
datFil = list(dataDir.glob("87AD*"))[0]
ADDat1 = loadmat(datFil)
ADDats = ADDat1["dk10"]

# %%
ADdatAdd = loadmat(dataDir/"DK_timecourse.mat")["DK_timecourse"]

# %%
import mat73
CtrldatAdd = mat73.loadmat(dataDir/"timecourse_ucsfCONT_group.mat")["dk10"]

# %%
baseDF = pd.read_csv(dataDir/"AllDataBaselineOrdered.csv")
CtrlKp = np.array(baseDF[baseDF["Grp"]=="Ctrl"]["KeepIt"] == 1)

# %%
ADDatsAll = np.concatenate([ADDats, ADdatAdd[np.newaxis, :, :]], axis=0)
CtrlDatsAll = np.concatenate([CtrlDats, CtrldatAdd], axis=0)
CtrlDatsAll = CtrlDatsAll[CtrlKp]

# %% [markdown]
# ## Set parameters

# %%
paras = edict()
paras.is_detrend = True
paras.decimate_rate = 5
paras.T = 2 # the total time course
paras.lamb = 1e-4 # the smooth parameter for smooth spline
paras.fct = 0.5 #fct: The factor to adjust h when estimating A matrix
paras.downsample_rate = 20#the downsample factor, determine how many Ai matrix to contribute to estimate the eigen values/vectors
paras.r = 20 #    r: The rank of A matrix, 
             # If r is decimal, the rank is the number of eigen values which account for 100r % of the total variance
             # If r is integer, the r in algorithm can be r + 1 if r breaks the conjugate eigval pairs. 
paras.Lmin = 200 # Lmin: The minimal length between 2 change points
paras.maxM = 20 #  MaxM: int, maximal number of change point 
paras.kappa = 3.210 #kappa: The parameter of penalty in MBIC
paras.wh = 20 # screening window size
paras.kps =  np.linspace(1, 4, 1000)
paras.save_dir = Path("./")
paras.L = 1e2 # the  L1-ball projectoin radius
paras.num_ranks = 10 # the rank to keep when estimating the Amat for each data
paras.cutoff = 0.5

# %% [markdown]
# ## Run

# %%
Ymat_ctrl = preprocess_MEG(CtrlDatsAll[:], paras)
Ymat_AD = preprocess_MEG(ADDatsAll[:], paras)

# %%
time_span = np.linspace(0, paras.T, Ymat_AD.shape[-1])

dXmats_AD, Xmats_AD = get_bspline_est(Ymat_AD, time_span, paras.lamb)
dXmats_ctrl, Xmats_ctrl = get_bspline_est(Ymat_ctrl, time_span, paras.lamb)

plt.figure(figsize=[10, 5])
plt.subplot(121)
for ix in range(68):
    plt.plot(Xmats_AD[0, ix, :])
plt.subplot(122)
for ix in range(68):
    plt.plot(Xmats_ctrl[0, ix, :])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:44<00:00,  1.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:45<00:00,  1.93it/s]

# %%
Amat_ctrls_lowrank = get_Amats(dXmats_ctrl[:], Xmats_ctrl[:], time_span, downrate=paras.downsample_rate, 
                              fct=paras.fct, nRks=paras.num_ranks, is_sum=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [04:27<00:00,  3.04s/it]

# %%
Amat_ADs_lowrank = get_Amats(dXmats_AD[:], Xmats_AD[:], time_span, downrate=paras.downsample_rate, 
                            fct=paras.fct, nRks=paras.num_ranks, is_sum=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [04:18<00:00,  2.94s/it]

# %%
Amat_AD = np.sum(Amat_ADs_lowrank, axis=0)
Amat_ctrl = np.sum(Amat_ctrls_lowrank, axis=0)

# %%
eigvals_ctrl, eigvecs_ctrl = eig_sorted(Amat_ctrl)
eigvecs_inv_ctrl = np.linalg.inv(eigvecs_ctrl)
eigvecs_ctrl_part = eigvecs_ctrl[:, :paras.r]
eigvecs_inv_ctrl_part = eigvecs_inv_ctrl[:paras.r, :]
left_mat_ctrl = np.linalg.inv(eigvecs_ctrl_part.T.dot(eigvecs_ctrl_part)).dot(eigvecs_ctrl_part.T)
right_mat_ctrl = eigvecs_inv_ctrl_part.T.dot(np.linalg.inv(eigvecs_inv_ctrl_part.dot(eigvecs_inv_ctrl_part.T)))

eigvals_AD, eigvecs_AD = eig_sorted(Amat_AD)
eigvecs_inv_AD = np.linalg.inv(eigvecs_AD)
eigvecs_AD_part = eigvecs_AD[:, :paras.r]
eigvecs_inv_AD_part = eigvecs_inv_AD[:paras.r, :]
left_mat_AD = np.linalg.inv(eigvecs_AD_part.T.dot(eigvecs_AD_part)).dot(eigvecs_AD_part.T)
right_mat_AD = eigvecs_inv_AD_part.T.dot(np.linalg.inv(eigvecs_inv_AD_part.dot(eigvecs_inv_AD_part.T)))

lams_ctrl = []
for ix in range(len(Amat_ctrls_lowrank)):
    cur_Amat = Amat_ctrls_lowrank[ix]
    cur_Lam = left_mat_ctrl.dot(cur_Amat).dot(right_mat_ctrl)
    lams_ctrl.append(np.diag(cur_Lam))
lams_ctrl = np.array(lams_ctrl)

lams_AD = []
for ix in range(len(Amat_ADs_lowrank)):
    cur_Amat = Amat_ADs_lowrank[ix]
    cur_Lam = left_mat_AD.dot(cur_Amat).dot(right_mat_AD)
    lams_AD.append(np.diag(cur_Lam))
lams_AD = np.array(lams_AD)

# %%
cur_cutoff = 0.5
lams_ctrl_abs = np.abs(lams_ctrl[:, :20])
ranks_ctrl = [len(cumsum_cutoff(lams_ctrl_abs[ix], cur_cutoff)) for ix in range(len(lams_ctrl_abs))]

lams_AD_abs = np.abs(lams_AD[:, :20])
ranks_AD = [len(cumsum_cutoff(lams_AD_abs[ix], cur_cutoff)) for ix in range(len(lams_AD_abs))]
print(np.mean(ranks_AD), np.mean(ranks_ctrl), ttest_ind(ranks_ctrl, ranks_AD))
# Out:
# 2.375 4.7727272727272725 Ttest_indResult(statistic=15.993227699020443, pvalue=5.3350604222633996e-36)

# %%
# Out:
# Ttest_indResult(statistic=0.6504580987674304, pvalue=0.5162543045797932)

# %%
plt_data = minmax_mat(np.abs(lams_ctrl)[:, :paras.r], True)
plt.figure(figsize=[10, 10])
sns.heatmap(plt_data>0.8, cmap="coolwarm", vmin=0, vmax=1)

#plt_data = np.abs(lams_ctrl)[:, :]
#sns.heatmap(np.log(plt_data+1), cmap="coolwarm", vmin=0)
# Out:
# <AxesSubplot:>

# %%
# Out:
# (88, 68)

# %% [markdown]
# ## Others

# %%
AmatCtrl = GetAmat(dXmatsCtrl[:], XmatsCtrl[:], timeSpan, downrate=paras.downRate, fct=paras.fct, nRks=paras.nRks, is_sum=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:15<00:00,  5.70it/s]

# %%
res = eig_sorted(AmatCtrl)
plt.figure(figsize=[10, 5])
plt.subplot(121)
plt.plot(ComPercentFn(res[0])*100)
plt.axhline(80, color="red")
plt.xlabel("Eig Val Index")
plt.ylabel("Cumsum percentage of Eig Val (%)")
plt.subplot(122)
plt.plot(np.abs(res[0]))
plt.xlabel("Eig Val Index")
plt.ylabel("Mode of Eig Val")
# Out:
# Text(0, 0.5, 'Mode of Eig Val')

# %%
ResCtrl = GetNewData(dXmatsCtrl, XmatsCtrl, AmatCtrl, paras.r, True)
ResAD_CtrlU = GetNewData(dXmatsAD, XmatsAD, AmatCtrl, paras.r, True)

# %%
canptssAD_CtrlU = Screening(ResAD_CtrlU.ndXmats, ResAD_CtrlU.nXmats, ResAD_CtrlU.kpidxs, wh=paras.wh, showProgress=True)
canptssCtrl = Screening(ResCtrl.ndXmats, ResCtrl.nXmats, ResCtrl.kpidxs, wh=paras.wh, showProgress=True)
# Out:
# Screening:  17%|██████████████▋                                                                       | 15/88 [04:59<24:22, 20.03s/it]

# %%
detRessAD_CtrlU = []
for ix in trange(len(canptssAD_CtrlU)):
    res = EGenDy(ResAD_CtrlU.ndXmats[ix], ResAD_CtrlU.nXmats[ix], paras.kappa, ResAD_CtrlU.kpidxs, 
                 Lmin=paras.Lmin,  canpts=canptssAD_CtrlU[ix], MaxM=paras.MaxM, 
                 is_full=True,  showProgress=False)
    detRessAD_CtrlU.append(res)

# %%
detRessCtrl = []
for ix in trange(len(canptssCtrl)):
    res = EGenDy(ResCtrl.ndXmats[ix], ResCtrl.nXmats[ix], paras.kappa, ResCtrl.kpidxs,
                 Lmin=paras.Lmin, canpts=canptssCtrl[ix], MaxM=paras.MaxM, 
                 is_full=True,  showProgress=False)
    detRessCtrl.append(res)

# %%
filNam = paras.saveDir/paras2name(paras)
print(filNam.exists())
filNam
# Out:
# False
# PosixPath('is_detrendTrue__decimateRate5__T2__lamb1.00E-04__fct5.00E-01__downRate200__r20__Lmin200__MaxM20__kappa3.21E+00__wh20__L1.00E+02__nRks10.pkl')

# %%
if not filNam.exists():
    resAll = edict()
    resAll.detRessAD_CtrlU = detRessAD_CtrlU
    resAll.detRessCtrl = detRessCtrl
    resAll.canptssAD_CtrlU = canptssAD_CtrlU
    resAll.canptssCtrl = canptssCtrl
    resAll.ResAD_CtrlU = ResAD_CtrlU
    resAll.ResCtrl = ResCtrl
    resAll.AmatCtrl = AmatCtrl
    resAll.paras = paras
    with open(filNam, "wb") as f:
        pickle.dump(resAll, f)
else:
    with open(filNam, "rb") as f:
        resAll = pickle.load(f)
        
    detRessAD_CtrlU = resAll.detRessAD_CtrlU
    detRessCtrl = resAll.detRessCtrl
    canptssAD_CtrlU = resAll.canptssAD_CtrlU
    canptssCtrl = resAll.canptssCtrl
    AmatCtrl = resAll.AmatCtrl
    ResAD_CtrlU = resAll.ResAD_CtrlU
    ResCtrl = resAll.ResCtrl

# %% [markdown]
# #### Results of switching pts

# %%
# sel kappa
ecptssCtrls = []
_, curR, n = ResCtrl.ndXmats.shape
for kp in paras.kps:
    ecptssCtrl = np.array([UpdateKp(kp, ix.U0, n, curR, paras) for ix in detRessCtrl])
    ecptssCtrls.append(ecptssCtrl)
    
ecptssAD_CtrlUs = []
_, curR, n = ResAD_CtrlU.ndXmats.shape
for kp in paras.kps:
    ecptssAD_CtrlU = np.array([UpdateKp(kp, ix.U0, n, curR, paras) for ix in detRessAD_CtrlU])
    ecptssAD_CtrlUs.append(ecptssAD_CtrlU)

ecptssCtrls = np.array(ecptssCtrls)
ecptssAD_CtrlUs = np.array(ecptssAD_CtrlUs)
stdRes = ecptssAD_CtrlUs.std(axis=1) + ecptssCtrls.std(axis=1)
meanRes = ecptssAD_CtrlUs.mean(axis=1) + ecptssCtrls.mean(axis=1)

kpsKpidxs1 = np.bitwise_and(ecptssCtrls.mean(axis=1)>=2, ecptssCtrls.mean(axis=1)<=18)
kpsKpidxs2 = np.bitwise_and(ecptssAD_CtrlUs.mean(axis=1)>=2, ecptssAD_CtrlUs.mean(axis=1)<=18)
kpsKpidxs = np.bitwise_and(kpsKpidxs1, kpsKpidxs2)


plt.plot(paras.kps[kpsKpidxs], stdRes[kpsKpidxs])
plt.xlabel("Kappa")
plt.ylabel("Std")


selKp = paras.kps[kpsKpidxs][np.argmin(stdRes[kpsKpidxs])]
selKp
# Out:
# 3.2612612612612613

# %%
curKp = selKp
_, curR, n = ResCtrl.ndXmats.shape
ecptssCtrl = np.array([UpdateKp(curKp, ix.U0, n, curR, paras) for ix in detRessCtrl])
_, curR, n = ResAD_CtrlU.ndXmats.shape
ecptssAD_CtrlU = np.array([UpdateKp(curKp, ix.U0, n, curR, paras) for ix in detRessAD_CtrlU])

# %%
# Out:
# 3.4886363636363638 6.806818181818182
# Ttest_indResult(statistic=-7.497186039159376, pvalue=3.1857560708074315e-12)

# %%
print(np.mean(ecptssAD_CtrlU), np.mean(ecptssCtrl))
ttest_ind(ecptssAD_CtrlU, ecptssCtrl)
plt.hist(ecptssCtrl, alpha=0.5, label="Ctrl")
plt.hist(ecptssAD_CtrlU, alpha=0.5, label="AD")
plt.legend()

# %%
res = ttest_ind(ecptssCtrl, ecptssAD_CtrlU, equal_var=False)
plt.figure(figsize=[5, 5])
sns.boxplot(data=[ecptssCtrl, ecptssAD_CtrlU], showfliers=0)
plt.xticks([0, 1], ["Ctrl", "AD"])
plt.title(f"Num of switching points (T-test:{res.pvalue:.3f})")
# Out:
# Text(0.5, 1.0, 'Num of switching points (T-test:0.000)')

# %% [markdown]
# #### Results of rks

# %%
paras.L1 = 25000
paras.L = 200

rksCtrl = []
kpidxs = ResCtrl.kpidxs
for ix in range(len(detRessCtrl)):
    ndXmat = ResCtrl.ndXmats[ix]
    nXmat = ResCtrl.nXmats[ix]
    necpts = ecptssCtrl[ix]
    ecpts = detRessCtrl[ix].chgMat[necpts-1, :necpts]
    eigValsMat = estEigVals(ecpts, ndXmat, nXmat, kpidxs)
    #eigValsMat = euclidean_proj_l1ball_CplxMul(eigValsMat, paras.L1)
    _, redRowNorms = euclidean_proj_l1ball_CplxMat(eigValsMat, paras.L)
    curKpidxs = np.intersect1d(np.where(redRowNorms!=0)[0], kpidxs)
    
    curRk = np.sum(redRowNorms != 0)
    rksCtrl.append(curRk)

# %%
rksAD_CtrlU= []
kpidxs = ResAD_CtrlU.kpidxs
for ix in range(len(detRessAD_CtrlU)):
    ndXmat = ResAD_CtrlU.ndXmats[ix]
    nXmat = ResAD_CtrlU.nXmats[ix]
    necpts = ecptssAD_CtrlU[ix]
    ecpts = detRessAD_CtrlU[ix].chgMat[necpts-1, :necpts]
    eigValsMat = estEigVals(ecpts, ndXmat, nXmat, kpidxs)
    #eigValsMat = euclidean_proj_l1ball_CplxMul(eigValsMat, paras.L1)
    _, redRowNorms = euclidean_proj_l1ball_CplxMat(eigValsMat, paras.L)
    curKpidxs = np.intersect1d(np.where(redRowNorms!=0)[0], kpidxs)
    
    curRk = np.sum(redRowNorms != 0)
    rksAD_CtrlU.append(curRk)
    #print(np.std(redRowNorms))

# %%
print(np.mean(rksAD_CtrlU), np.mean(rksCtrl))
print(ttest_ind(rksAD_CtrlU, rksCtrl))
plt.hist(rksCtrl, alpha=0.5, label="ctrl")
plt.hist(rksAD_CtrlU, alpha=0.5, label="ad")
plt.legend()
# Out:
# 18.03409090909091 17.420454545454547
# Ttest_indResult(statistic=1.5575483102519536, pvalue=0.12115734336100596)

# %%
ix = 2
kpidxs = ResAD_CtrlU.kpidxs
ndXmat = ResAD_CtrlU.ndXmats[ix]
nXmat = ResAD_CtrlU.nXmats[ix]
ecpts = detRessAD_CtrlU[ix].mbic_ecpts

plt.figure(figsize=[20, 10])

plt.subplot(111)
eigValsMat = estEigVals(ecpts, ndXmat, nXmat, kpidxs)
rowNorms = (np.sum(np.abs(eigValsMat), axis=1))
sns.heatmap(np.abs(eigValsMat), yticklabels=np.round(rowNorms, 0), cmap="coolwarm", annot=np.abs(eigValsMat), vmin=0)
plt.xlabel("Segment")
plt.ylabel("Rank")

# plt.subplot(132)
# redEigValsMat, redRowNorms = euclidean_proj_l1ball_CplxMat(eigValsMat, paras.L)
# sns.heatmap(np.abs(redEigValsMat), yticklabels=np.round(redRowNorms, 0), cmap="coolwarm", annot=np.abs(redEigValsMat), vmin=0)
# plt.xlabel("Segment")
# plt.ylabel("Rank")
# 
# plt.subplot(133)
# eigValsMat1 = euclidean_proj_l1ball_CplxMul(eigValsMat, paras.L1)
# redEigValsMat1, redRowNorms1 = euclidean_proj_l1ball_CplxMat(eigValsMat1, paras.L)
# sns.heatmap(np.abs(redEigValsMat1), yticklabels=np.round(redRowNorms1, 0), cmap="coolwarm", annot=np.abs(redEigValsMat1), vmin=0)
# plt.xlabel("Segment")
# plt.ylabel("Rank")
# Out:
# Text(159.0, 0.5, 'Rank')

# %% [markdown]
# ### Use combined U for AD and Ctrl

# %%
BothDats = np.concatenate([ADDats, CtrlDats], axis=0)
YmatBoth = prepMEG(BothDats, paras)

# %%
timeSpan = np.linspace(0, paras.T, YmatBoth.shape[-1])
dXmatsBoth, XmatsBoth = GetBsplineEst(YmatBoth, timeSpan, paras.lamb)
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
#   1%|          | 1/157 [00:00<00:59,  2.64it/s]
#   1%|▏         | 2/157 [00:00<00:57,  2.69it/s]
#   2%|▏         | 3/157 [00:01<01:02,  2.47it/s]
#   3%|▎         | 4/157 [00:01<00:59,  2.56it/s]
#   3%|▎         | 5/157 [00:01<00:57,  2.63it/s]
#   4%|▍         | 6/157 [00:02<00:56,  2.67it/s]
#   4%|▍         | 7/157 [00:02<00:55,  2.72it/s]
#   5%|▌         | 8/157 [00:03<00:54,  2.75it/s]
#   6%|▌         | 9/157 [00:03<00:54,  2.74it/s]
#   6%|▋         | 10/157 [00:03<00:53,  2.76it/s]
#   7%|▋         | 11/157 [00:04<00:53,  2.75it/s]
#   8%|▊         | 12/157 [00:04<00:52,  2.76it/s]
#   8%|▊         | 13/157 [00:04<00:52,  2.76it/s]
#   9%|▉         | 14/157 [00:05<00:51,  2.76it/s]
#  10%|▉         | 15/157 [00:05<00:51,  2.77it/s]
#  10%|█         | 16/157 [00:05<00:50,  2.77it/s]
#  11%|█         | 17/157 [00:06<00:50,  2.76it/s]
#  11%|█▏        | 18/157 [00:06<00:50,  2.77it/s]
#  12%|█▏        | 19/157 [00:06<00:49,  2.78it/s]
#  13%|█▎        | 20/157 [00:07<00:49,  2.77it/s]
#  13%|█▎        | 21/157 [00:07<00:49,  2.75it/s]
#  14%|█▍        | 22/157 [00:08<00:49,  2.75it/s]
#  15%|█▍        | 23/157 [00:08<00:48,  2.76it/s]
#  15%|█▌        | 24/157 [00:08<00:48,  2.76it/s]
#  16%|█▌        | 25/157 [00:09<00:48,  2.75it/s]
#  17%|█▋        | 26/157 [00:09<00:48,  2.73it/s]
#  17%|█▋        | 27/157 [00:09<00:47,  2.72it/s]
#  18%|█▊        | 28/157 [00:10<00:47,  2.73it/s]
#  18%|█▊        | 29/157 [00:10<00:47,  2.72it/s]
#  19%|█▉        | 30/157 [00:10<00:46,  2.75it/s]
#  20%|█▉        | 31/157 [00:11<00:46,  2.74it/s]
#  20%|██        | 32/157 [00:11<00:45,  2.75it/s]
#  80%|████████  | 126/157 [00:46<00:11,  2.75it/s]
#  81%|████████  | 127/157 [00:46<00:10,  2.75it/s]
#  82%|████████▏ | 128/157 [00:46<00:10,  2.74it/s]
#  82%|████████▏ | 129/157 [00:47<00:10,  2.72it/s]
#  83%|████████▎ | 130/157 [00:47<00:09,  2.73it/s]
#  83%|████████▎ | 131/157 [00:48<00:09,  2.74it/s]
#  84%|████████▍ | 132/157 [00:48<00:09,  2.74it/s]
#  85%|████████▍ | 133/157 [00:48<00:08,  2.75it/s]
#  85%|████████▌ | 134/157 [00:49<00:08,  2.74it/s]
#  86%|████████▌ | 135/157 [00:49<00:08,  2.72it/s]
#  87%|████████▋ | 136/157 [00:49<00:07,  2.73it/s]
#  87%|████████▋ | 137/157 [00:50<00:07,  2.73it/s]
#  88%|████████▊ | 138/157 [00:50<00:07,  2.71it/s]
#  89%|████████▊ | 139/157 [00:50<00:06,  2.72it/s]
#  89%|████████▉ | 140/157 [00:51<00:06,  2.72it/s]
#  90%|████████▉ | 141/157 [00:51<00:05,  2.73it/s]
#  90%|█████████ | 142/157 [00:52<00:05,  2.73it/s]
#  91%|█████████ | 143/157 [00:52<00:05,  2.73it/s]
#  92%|█████████▏| 144/157 [00:52<00:04,  2.71it/s]
#  92%|█████████▏| 145/157 [00:53<00:04,  2.73it/s]
#  93%|█████████▎| 146/157 [00:53<00:04,  2.74it/s]
#  94%|█████████▎| 147/157 [00:53<00:03,  2.74it/s]
#  94%|█████████▍| 148/157 [00:54<00:03,  2.75it/s]
#  95%|█████████▍| 149/157 [00:54<00:02,  2.76it/s]
#  96%|█████████▌| 150/157 [00:54<00:02,  2.76it/s]
#  96%|█████████▌| 151/157 [00:55<00:02,  2.75it/s]
#  97%|█████████▋| 152/157 [00:55<00:01,  2.75it/s]
#  97%|█████████▋| 153/157 [00:56<00:01,  2.72it/s]
#  98%|█████████▊| 154/157 [00:56<00:01,  2.73it/s]
#  99%|█████████▊| 155/157 [00:56<00:00,  2.74it/s]
#  99%|█████████▉| 156/157 [00:57<00:00,  2.74it/s]
# 100%|██████████| 157/157 [00:57<00:00,  2.73it/s]

# %%
AmatBoth = GetAmat(dXmatsBoth, XmatsBoth, timeSpan, downrate=paras.downRate, fct=paras.fct, is_sum=True)
ResCtrl_comU = GetNewData(dXmatsCtrl, XmatsCtrl, AmatBoth, paras.r, True)
ResAD_comU = GetNewData(dXmatsAD, XmatsAD, AmatBoth, paras.r, True)
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
#   1%|          | 1/157 [00:00<01:30,  1.72it/s]
#   1%|▏         | 2/157 [00:01<01:28,  1.75it/s]
#   2%|▏         | 3/157 [00:01<01:28,  1.74it/s]
#   3%|▎         | 4/157 [00:02<01:27,  1.74it/s]
#   3%|▎         | 5/157 [00:02<01:26,  1.76it/s]
#   4%|▍         | 6/157 [00:03<01:26,  1.75it/s]
#   4%|▍         | 7/157 [00:03<01:24,  1.77it/s]
#   5%|▌         | 8/157 [00:04<01:24,  1.76it/s]
#   6%|▌         | 9/157 [00:05<01:23,  1.77it/s]
#  95%|█████████▍| 149/157 [01:24<00:04,  1.78it/s]
#  96%|█████████▌| 150/157 [01:25<00:03,  1.77it/s]
#  96%|█████████▌| 151/157 [01:25<00:03,  1.78it/s]
#  97%|█████████▋| 152/157 [01:26<00:02,  1.76it/s]
#  97%|█████████▋| 153/157 [01:26<00:02,  1.78it/s]
#  98%|█████████▊| 154/157 [01:27<00:01,  1.77it/s]
#  99%|█████████▊| 155/157 [01:28<00:01,  1.79it/s]
#  99%|█████████▉| 156/157 [01:28<00:00,  1.78it/s]
# 100%|██████████| 157/157 [01:29<00:00,  1.76it/s]

# %%
canptssAD_comU = Screening(ResAD_comU.ndXmats, ResAD_comU.nXmats, wh=paras.wh, showProgress=True)
canptssCtrl_comU = Screening(ResCtrl_comU.ndXmats, ResCtrl_comU.nXmats, wh=paras.wh, showProgress=True)
# Out:
# Screening:   0%|          | 0/87 [00:00<?, ?it/s]
# Screening:   1%|          | 1/87 [00:07<10:31,  7.35s/it]
# Screening:   2%|▏         | 2/87 [00:14<10:23,  7.34s/it]
# Screening:   3%|▎         | 3/87 [00:21<10:16,  7.33s/it]
# Screening:   5%|▍         | 4/87 [00:29<10:08,  7.33s/it]
# Screening:   6%|▌         | 5/87 [00:36<10:00,  7.32s/it]
# Screening:   7%|▋         | 6/87 [00:43<09:53,  7.32s/it]
# Screening:   8%|▊         | 7/87 [00:51<09:45,  7.32s/it]
# Screening:   9%|▉         | 8/87 [00:58<09:38,  7.32s/it]
# Screening:  10%|█         | 9/87 [01:05<09:31,  7.32s/it]
# Screening:  11%|█▏        | 10/87 [01:13<09:23,  7.32s/it]
# Screening:  13%|█▎        | 11/87 [01:20<09:16,  7.33s/it]
# Screening:  14%|█▍        | 12/87 [01:27<09:09,  7.33s/it]
# Screening:  15%|█▍        | 13/87 [01:35<09:02,  7.33s/it]
# Screening:  16%|█▌        | 14/87 [01:42<08:55,  7.33s/it]
# Screening:  17%|█▋        | 15/87 [01:49<08:48,  7.33s/it]
# Screening:  18%|█▊        | 16/87 [01:57<08:41,  7.34s/it]
# Screening:  20%|█▉        | 17/87 [02:04<08:33,  7.33s/it]
# Screening:  21%|██        | 18/87 [02:11<08:26,  7.33s/it]
# Screening:  22%|██▏       | 19/87 [02:19<08:18,  7.33s/it]
# Screening:  23%|██▎       | 20/87 [02:26<08:10,  7.33s/it]
# Screening:  24%|██▍       | 21/87 [02:33<08:03,  7.33s/it]
# Screening:  25%|██▌       | 22/87 [02:41<07:56,  7.34s/it]
# Screening:  26%|██▋       | 23/87 [02:48<07:50,  7.35s/it]
# Screening:  28%|██▊       | 24/87 [02:55<07:42,  7.35s/it]
# Screening:  29%|██▊       | 25/87 [03:03<07:35,  7.35s/it]
# Screening:  30%|██▉       | 26/87 [03:10<07:28,  7.35s/it]
# Screening:  31%|███       | 27/87 [03:18<07:21,  7.35s/it]
# Screening:  32%|███▏      | 28/87 [03:25<07:13,  7.35s/it]
# Screening:  33%|███▎      | 29/87 [03:32<07:06,  7.35s/it]
# Screening:  34%|███▍      | 30/87 [03:40<06:58,  7.35s/it]
# Screening:  96%|█████████▌| 67/70 [08:12<00:21,  7.33s/it]
# Screening:  97%|█████████▋| 68/70 [08:20<00:14,  7.32s/it]
# Screening:  99%|█████████▊| 69/70 [08:27<00:07,  7.33s/it]
# Screening: 100%|██████████| 70/70 [08:34<00:00,  7.36s/it]

# %%
detRessAD_comU = []
for ix in trange(len(canptssAD_comU)):
    res = EGenDy(ResAD_comU.ndXmats[ix], ResAD_comU.nXmats[ix], paras.kappa, Lmin=paras.Lmin, 
          canpts=canptssAD_comU[ix], MaxM=paras.MaxM, is_full=True, 
          showProgress=True)
    detRessAD_comU.append(res)
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]
#
# Dynamic Programming:   0%|          | 0/186 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/186 [00:00<01:34,  1.97it/s]
#
# Dynamic Programming:   1%|          | 2/186 [00:01<01:34,  1.95it/s]
#
# Dynamic Programming:   2%|▏         | 3/186 [00:01<01:33,  1.97it/s]
#
# Dynamic Programming:   2%|▏         | 4/186 [00:02<01:31,  1.99it/s]
#
# Dynamic Programming:   3%|▎         | 5/186 [00:02<01:31,  1.98it/s]
#
# Dynamic Programming:   3%|▎         | 6/186 [00:03<01:29,  2.01it/s]
#
# Dynamic Programming:   4%|▍         | 7/186 [00:03<01:29,  2.01it/s]
#
# Dynamic Programming:   4%|▍         | 8/186 [00:03<01:27,  2.03it/s]
#
# Dynamic Programming:   5%|▍         | 9/186 [00:04<01:26,  2.03it/s]
#
# Dynamic Programming:   5%|▌         | 10/186 [00:04<01:25,  2.07it/s]
#
# Dynamic Programming:   6%|▌         | 11/186 [00:05<01:24,  2.07it/s]
#
# Dynamic Programming:   6%|▋         | 12/186 [00:05<01:22,  2.10it/s]
#
# Dynamic Programming:   7%|▋         | 13/186 [00:06<01:22,  2.11it/s]
#
# Dynamic Programming:   8%|▊         | 14/186 [00:06<01:20,  2.13it/s]
#
# Dynamic Programming:   8%|▊         | 15/186 [00:07<01:20,  2.14it/s]
#
# Dynamic Programming:   9%|▊         | 16/186 [00:07<01:18,  2.17it/s]
#
# Dynamic Programming:   9%|▉         | 17/186 [00:08<01:17,  2.18it/s]
#
# Dynamic Programming:  10%|▉         | 18/186 [00:08<01:15,  2.22it/s]
#
# Dynamic Programming:  10%|█         | 19/186 [00:09<01:14,  2.25it/s]
#
# Dynamic Programming:  11%|█         | 20/186 [00:09<01:13,  2.25it/s]
#
# Dynamic Programming:  11%|█▏        | 21/186 [00:09<01:12,  2.29it/s]
#
# Dynamic Programming:  12%|█▏        | 22/186 [00:10<01:11,  2.29it/s]
#
# Dynamic Programming:  12%|█▏        | 23/186 [00:10<01:09,  2.33it/s]
#
# Dynamic Programming:  13%|█▎        | 24/186 [00:11<01:09,  2.35it/s]
#
# Dynamic Programming:  13%|█▎        | 25/186 [00:11<01:07,  2.38it/s]
#
# Dynamic Programming:  14%|█▍        | 26/186 [00:11<01:06,  2.42it/s]
#
# Dynamic Programming:  15%|█▍        | 27/186 [00:12<01:05,  2.41it/s]
#
# Dynamic Programming:  15%|█▌        | 28/186 [00:12<01:04,  2.45it/s]
#
# Dynamic Programming:  16%|█▌        | 29/186 [00:13<01:04,  2.45it/s]
#
# Dynamic Programming:  16%|█▌        | 30/186 [00:13<01:02,  2.49it/s]
#
# Dynamic Programming:  17%|█▋        | 31/186 [00:13<01:01,  2.53it/s]
#
# Dynamic Programming:  17%|█▋        | 32/186 [00:14<01:01,  2.52it/s]
#
# Dynamic Programming:  18%|█▊        | 33/186 [00:14<00:59,  2.57it/s]
#
# Dynamic Programming:  18%|█▊        | 34/186 [00:15<00:58,  2.61it/s]
#
# Dynamic Programming:  19%|█▉        | 35/186 [00:15<00:58,  2.60it/s]
#
# Dynamic Programming:  19%|█▉        | 36/186 [00:15<00:56,  2.65it/s]
#
# Dynamic Programming:  20%|█▉        | 37/186 [00:16<00:55,  2.67it/s]
#
# Dynamic Programming:  20%|██        | 38/186 [00:16<00:54,  2.71it/s]
#
# Dynamic Programming:  21%|██        | 39/186 [00:16<00:53,  2.75it/s]
#
# Dynamic Programming:  22%|██▏       | 40/186 [00:17<00:53,  2.74it/s]
#
# Dynamic Programming:  22%|██▏       | 41/186 [00:17<00:51,  2.80it/s]
#
# Dynamic Programming:  23%|██▎       | 42/186 [00:17<00:50,  2.86it/s]
#
# Dynamic Programming:  23%|██▎       | 43/186 [00:18<00:50,  2.86it/s]
#
# Dynamic Programming:  24%|██▎       | 44/186 [00:18<00:48,  2.91it/s]
#
# Dynamic Programming:  24%|██▍       | 45/186 [00:18<00:47,  2.97it/s]
#
# Dynamic Programming:  25%|██▍       | 46/186 [00:19<00:47,  2.98it/s]
#
# Dynamic Programming:  25%|██▌       | 47/186 [00:19<00:45,  3.03it/s]
#
# Dynamic Programming:  26%|██▌       | 48/186 [00:19<00:44,  3.08it/s]
#
# Dynamic Programming:  26%|██▋       | 49/186 [00:20<00:43,  3.12it/s]
#
# Dynamic Programming:  27%|██▋       | 50/186 [00:20<00:43,  3.13it/s]
#
# Dynamic Programming:  27%|██▋       | 51/186 [00:20<00:42,  3.18it/s]
#
# Dynamic Programming:  28%|██▊       | 52/186 [00:21<00:41,  3.23it/s]
#
# Dynamic Programming:  28%|██▊       | 53/186 [00:21<00:41,  3.23it/s]
#
# Dynamic Programming:  29%|██▉       | 54/186 [00:21<00:40,  3.28it/s]
#
# Dynamic Programming:  30%|██▉       | 55/186 [00:22<00:39,  3.33it/s]
#
# Dynamic Programming:  30%|███       | 56/186 [00:22<00:39,  3.31it/s]
#
# Dynamic Programming:  31%|███       | 57/186 [00:22<00:38,  3.38it/s]
#
# Dynamic Programming:  31%|███       | 58/186 [00:22<00:37,  3.44it/s]
#
# Dynamic Programming:  32%|███▏      | 59/186 [00:23<00:36,  3.50it/s]
#
# Dynamic Programming:  32%|███▏      | 60/186 [00:23<00:36,  3.48it/s]
#
# Dynamic Programming:  33%|███▎      | 61/186 [00:23<00:35,  3.55it/s]
#
# Dynamic Programming:  33%|███▎      | 62/186 [00:24<00:34,  3.62it/s]
#
# Dynamic Programming:  34%|███▍      | 63/186 [00:24<00:33,  3.68it/s]
#
# Dynamic Programming:  34%|███▍      | 64/186 [00:24<00:33,  3.66it/s]
#
# Dynamic Programming:  35%|███▍      | 65/186 [00:24<00:32,  3.76it/s]
#
# Dynamic Programming:  35%|███▌      | 66/186 [00:25<00:31,  3.84it/s]
#
# Dynamic Programming:  36%|███▌      | 67/186 [00:25<00:30,  3.91it/s]
#
# Dynamic Programming:  37%|███▋      | 68/186 [00:25<00:30,  3.91it/s]
#
# Dynamic Programming:  37%|███▋      | 69/186 [00:25<00:29,  3.99it/s]
#
# Dynamic Programming:  38%|███▊      | 70/186 [00:26<00:28,  4.07it/s]
#
# Dynamic Programming:  38%|███▊      | 71/186 [00:26<00:27,  4.15it/s]
#
# Dynamic Programming:  39%|███▊      | 72/186 [00:26<00:27,  4.12it/s]
#
# Dynamic Programming:  39%|███▉      | 73/186 [00:26<00:26,  4.22it/s]
#
# Dynamic Programming:  40%|███▉      | 74/186 [00:26<00:25,  4.32it/s]
#
# Dynamic Programming:  40%|████      | 75/186 [00:27<00:25,  4.39it/s]
#
# Dynamic Programming:  41%|████      | 76/186 [00:27<00:25,  4.40it/s]
#
# Dynamic Programming:  41%|████▏     | 77/186 [00:27<00:24,  4.49it/s]
#
# Dynamic Programming:  42%|████▏     | 78/186 [00:27<00:23,  4.57it/s]
#
# Dynamic Programming:  42%|████▏     | 79/186 [00:28<00:22,  4.66it/s]
#
# Dynamic Programming:  43%|████▎     | 80/186 [00:28<00:22,  4.73it/s]
#
# Dynamic Programming:  44%|████▎     | 81/186 [00:28<00:22,  4.68it/s]
#
# Dynamic Programming:  44%|████▍     | 82/186 [00:28<00:21,  4.79it/s]
#
# Dynamic Programming:  45%|████▍     | 83/186 [00:28<00:21,  4.89it/s]
#
# Dynamic Programming:  45%|████▌     | 84/186 [00:29<00:20,  4.98it/s]
#
# Dynamic Programming:  46%|████▌     | 85/186 [00:29<00:19,  5.06it/s]
#
# Dynamic Programming:  46%|████▌     | 86/186 [00:29<00:20,  4.98it/s]
#
# Dynamic Programming:  47%|████▋     | 87/186 [00:29<00:19,  5.11it/s]
#
# Dynamic Programming:  47%|████▋     | 88/186 [00:29<00:18,  5.23it/s]
#
# Dynamic Programming:  48%|████▊     | 89/186 [00:29<00:18,  5.33it/s]
#
# Dynamic Programming:  48%|████▊     | 90/186 [00:30<00:17,  5.42it/s]
#
# Dynamic Programming:  49%|████▉     | 91/186 [00:30<00:17,  5.52it/s]
#
# Dynamic Programming:  49%|████▉     | 92/186 [00:30<00:17,  5.42it/s]
#
# Dynamic Programming:  50%|█████     | 93/186 [00:30<00:16,  5.57it/s]
#
# Dynamic Programming:  51%|█████     | 94/186 [00:30<00:16,  5.72it/s]
#
# Dynamic Programming:  51%|█████     | 95/186 [00:30<00:15,  5.85it/s]
#
# Dynamic Programming:  52%|█████▏    | 96/186 [00:31<00:15,  5.98it/s]
#
# Dynamic Programming:  52%|█████▏    | 97/186 [00:31<00:14,  6.10it/s]
#
# Dynamic Programming:  53%|█████▎    | 98/186 [00:31<00:14,  5.99it/s]
#
# Dynamic Programming:  53%|█████▎    | 99/186 [00:31<00:14,  6.16it/s]
#
# Dynamic Programming:  54%|█████▍    | 100/186 [00:31<00:13,  6.32it/s]
#
# Dynamic Programming:  54%|█████▍    | 101/186 [00:31<00:13,  6.46it/s]
#
# Dynamic Programming:  55%|█████▍    | 102/186 [00:32<00:12,  6.59it/s]
#
# Dynamic Programming:  55%|█████▌    | 103/186 [00:32<00:12,  6.72it/s]
#
# Dynamic Programming:  56%|█████▌    | 104/186 [00:32<00:11,  6.84it/s]
#
# Dynamic Programming:  56%|█████▋    | 105/186 [00:32<00:12,  6.67it/s]
# Dynamic Programming:  57%|█████▋    | 106/186 [00:32<00:11,  6.90it/s]
#
# Dynamic Programming:  58%|█████▊    | 107/186 [00:32<00:11,  7.10it/s]
#
# Dynamic Programming:  58%|█████▊    | 108/186 [00:32<00:10,  7.29it/s]
#
# Dynamic Programming:  59%|█████▊    | 109/186 [00:33<00:10,  7.46it/s]
#
# Dynamic Programming:  59%|█████▉    | 110/186 [00:33<00:09,  7.61it/s]
#
# Dynamic Programming:  60%|█████▉    | 111/186 [00:33<00:09,  7.77it/s]
#
# Dynamic Programming:  60%|██████    | 112/186 [00:33<00:09,  7.56it/s]
#
# Dynamic Programming:  61%|██████    | 113/186 [00:33<00:09,  7.83it/s]
#
# Dynamic Programming:  61%|██████▏   | 114/186 [00:33<00:08,  8.09it/s]
#
# Dynamic Programming:  62%|██████▏   | 115/186 [00:33<00:08,  8.33it/s]
#
# Dynamic Programming:  62%|██████▏   | 116/186 [00:33<00:08,  8.46it/s]
#
# Dynamic Programming:  63%|██████▎   | 117/186 [00:33<00:07,  8.74it/s]
#
# Dynamic Programming:  63%|██████▎   | 118/186 [00:34<00:07,  8.99it/s]
#
# Dynamic Programming:  64%|██████▍   | 119/186 [00:34<00:07,  9.22it/s]
#
# Dynamic Programming:  65%|██████▌   | 121/186 [00:34<00:06,  9.51it/s]
#
# Dynamic Programming:  66%|██████▌   | 122/186 [00:34<00:06,  9.19it/s]
#
# Dynamic Programming:  67%|██████▋   | 124/186 [00:34<00:06,  9.67it/s]
#
# Dynamic Programming:  68%|██████▊   | 126/186 [00:34<00:05, 10.18it/s]
#
# Dynamic Programming:  69%|██████▉   | 128/186 [00:35<00:05, 10.69it/s]
#
# Dynamic Programming:  70%|██████▉   | 130/186 [00:35<00:04, 11.21it/s]
#
# Dynamic Programming:  71%|███████   | 132/186 [00:35<00:04, 11.75it/s]
#
# Dynamic Programming:  72%|███████▏  | 134/186 [00:35<00:04, 11.89it/s]
#
# Dynamic Programming:  73%|███████▎  | 136/186 [00:35<00:03, 12.65it/s]
#
# Dynamic Programming:  74%|███████▍  | 138/186 [00:35<00:03, 13.42it/s]
#
# Dynamic Programming:  75%|███████▌  | 140/186 [00:35<00:03, 14.27it/s]
#
# Dynamic Programming:  76%|███████▋  | 142/186 [00:35<00:02, 15.22it/s]
#
# Dynamic Programming:  77%|███████▋  | 144/186 [00:36<00:02, 16.33it/s]
#
# Dynamic Programming:  79%|███████▉  | 147/186 [00:36<00:02, 17.54it/s]
#
# Dynamic Programming:  81%|████████  | 150/186 [00:36<00:01, 19.03it/s]
#
# Dynamic Programming:  82%|████████▏ | 153/186 [00:36<00:01, 20.03it/s]
#
# Dynamic Programming:  84%|████████▍ | 157/186 [00:36<00:01, 22.52it/s]
#
# Dynamic Programming:  87%|████████▋ | 161/186 [00:36<00:00, 25.56it/s]
#
# Dynamic Programming:  89%|████████▉ | 166/186 [00:36<00:00, 29.78it/s]
#
# Dynamic Programming: 100%|██████████| 186/186 [00:36<00:00,  5.03it/s]
#
#   1%|          | 1/87 [00:36<53:00, 36.98s/it]
#
# Dynamic Programming:   0%|          | 0/195 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/195 [00:00<01:46,  1.82it/s]
#
# Dynamic Programming:   1%|          | 2/195 [00:01<01:44,  1.84it/s]
#
# Dynamic Programming:   2%|▏         | 3/195 [00:01<01:44,  1.83it/s]
#
# Dynamic Programming:   2%|▏         | 4/195 [00:02<01:42,  1.86it/s]
#
# Dynamic Programming:   3%|▎         | 5/195 [00:02<01:42,  1.86it/s]
#
# Dynamic Programming:   3%|▎         | 6/195 [00:03<01:40,  1.88it/s]
#
# Dynamic Programming:   4%|▎         | 7/195 [00:03<01:39,  1.88it/s]
#
# Dynamic Programming:   4%|▍         | 8/195 [00:04<01:37,  1.91it/s]
#
# Dynamic Programming:   5%|▍         | 9/195 [00:04<01:37,  1.91it/s]
#
# Dynamic Programming:   5%|▌         | 10/195 [00:05<01:35,  1.94it/s]
#
# Dynamic Programming:   6%|▌         | 11/195 [00:05<01:34,  1.95it/s]
#
# Dynamic Programming:   6%|▌         | 12/195 [00:06<01:32,  1.98it/s]
#
# Dynamic Programming:   7%|▋         | 13/195 [00:06<01:38,  1.85it/s]
#
# Dynamic Programming:   7%|▋         | 14/195 [00:07<01:34,  1.92it/s]
#
# Dynamic Programming:   8%|▊         | 15/195 [00:07<01:32,  1.95it/s]
#
# Dynamic Programming:   8%|▊         | 16/195 [00:08<01:29,  2.00it/s]
#
# Dynamic Programming:   9%|▊         | 17/195 [00:08<01:28,  2.01it/s]
#
# Dynamic Programming:   9%|▉         | 18/195 [00:09<01:26,  2.05it/s]
#
# Dynamic Programming:  10%|▉         | 19/195 [00:09<01:25,  2.06it/s]
#
# Dynamic Programming:  10%|█         | 20/195 [00:10<01:23,  2.10it/s]
#
# Dynamic Programming:  11%|█         | 21/195 [00:10<01:23,  2.09it/s]
#
# Dynamic Programming:  11%|█▏        | 22/195 [00:11<01:20,  2.14it/s]
#
# Dynamic Programming:  12%|█▏        | 23/195 [00:11<01:19,  2.18it/s]
#
# Dynamic Programming:  12%|█▏        | 24/195 [00:12<01:18,  2.19it/s]
#
# Dynamic Programming:  13%|█▎        | 25/195 [00:12<01:16,  2.22it/s]
#
# Dynamic Programming:  13%|█▎        | 26/195 [00:12<01:16,  2.22it/s]
#
# Dynamic Programming:  14%|█▍        | 27/195 [00:13<01:14,  2.26it/s]
#
# Dynamic Programming:  14%|█▍        | 28/195 [00:13<01:13,  2.27it/s]
#
# Dynamic Programming:  15%|█▍        | 29/195 [00:14<01:11,  2.32it/s]
#
# Dynamic Programming:  15%|█▌        | 30/195 [00:14<01:09,  2.36it/s]
#
# Dynamic Programming:  16%|█▌        | 31/195 [00:15<01:09,  2.36it/s]
#
# Dynamic Programming:  16%|█▋        | 32/195 [00:15<01:07,  2.41it/s]
#
# Dynamic Programming:  17%|█▋        | 33/195 [00:15<01:07,  2.42it/s]
#
# Dynamic Programming:  17%|█▋        | 34/195 [00:16<01:05,  2.46it/s]
#
# Dynamic Programming:  18%|█▊        | 35/195 [00:16<01:03,  2.51it/s]
#
# Dynamic Programming:  18%|█▊        | 36/195 [00:16<01:03,  2.50it/s]
#
# Dynamic Programming:  19%|█▉        | 37/195 [00:17<01:02,  2.55it/s]
#
# Dynamic Programming:  19%|█▉        | 38/195 [00:17<01:01,  2.57it/s]
#
# Dynamic Programming:  20%|██        | 39/195 [00:18<00:59,  2.61it/s]
#
# Dynamic Programming:  21%|██        | 40/195 [00:18<00:58,  2.65it/s]
#
# Dynamic Programming:  21%|██        | 41/195 [00:18<00:58,  2.64it/s]
#
# Dynamic Programming:  22%|██▏       | 42/195 [00:19<00:57,  2.67it/s]
#
# Dynamic Programming:  22%|██▏       | 43/195 [00:19<00:55,  2.72it/s]
#
# Dynamic Programming:  23%|██▎       | 44/195 [00:19<00:55,  2.70it/s]
#
# Dynamic Programming:  23%|██▎       | 45/195 [00:20<00:54,  2.75it/s]
#
# Dynamic Programming:  24%|██▎       | 46/195 [00:20<00:53,  2.80it/s]
#
# Dynamic Programming:  24%|██▍       | 47/195 [00:21<00:52,  2.80it/s]
#
# Dynamic Programming:  25%|██▍       | 48/195 [00:21<00:51,  2.85it/s]
#
# Dynamic Programming:  25%|██▌       | 49/195 [00:21<00:50,  2.90it/s]
#
# Dynamic Programming:  26%|██▌       | 50/195 [00:22<00:49,  2.90it/s]
#
# Dynamic Programming:  26%|██▌       | 51/195 [00:22<00:48,  2.95it/s]
#
# Dynamic Programming:  27%|██▋       | 52/195 [00:22<00:47,  3.00it/s]
#
# Dynamic Programming:  27%|██▋       | 53/195 [00:23<00:48,  2.94it/s]
#
# Dynamic Programming:  28%|██▊       | 54/195 [00:23<00:46,  3.00it/s]
#
# Dynamic Programming:  28%|██▊       | 55/195 [00:23<00:45,  3.08it/s]
#
# Dynamic Programming:  29%|██▊       | 56/195 [00:23<00:45,  3.08it/s]
#
# Dynamic Programming:  29%|██▉       | 57/195 [00:24<00:43,  3.16it/s]
#
# Dynamic Programming:  30%|██▉       | 58/195 [00:24<00:42,  3.22it/s]
#
# Dynamic Programming:  30%|███       | 59/195 [00:24<00:42,  3.21it/s]
#
# Dynamic Programming:  31%|███       | 60/195 [00:25<00:41,  3.28it/s]
#
# Dynamic Programming:  31%|███▏      | 61/195 [00:25<00:40,  3.34it/s]
#
# Dynamic Programming:  32%|███▏      | 62/195 [00:25<00:39,  3.40it/s]
#
# Dynamic Programming:  32%|███▏      | 63/195 [00:26<00:39,  3.37it/s]
#
# Dynamic Programming:  33%|███▎      | 64/195 [00:26<00:38,  3.44it/s]
#
# Dynamic Programming:  33%|███▎      | 65/195 [00:26<00:36,  3.51it/s]
#
# Dynamic Programming:  34%|███▍      | 66/195 [00:26<00:36,  3.53it/s]
#
# Dynamic Programming:  34%|███▍      | 67/195 [00:27<00:35,  3.61it/s]
#
# Dynamic Programming:  35%|███▍      | 68/195 [00:27<00:34,  3.68it/s]
#
# Dynamic Programming:  35%|███▌      | 69/195 [00:27<00:33,  3.75it/s]
#
# Dynamic Programming:  36%|███▌      | 70/195 [00:27<00:33,  3.72it/s]
#
# Dynamic Programming:  36%|███▋      | 71/195 [00:28<00:32,  3.80it/s]
#
# Dynamic Programming:  37%|███▋      | 72/195 [00:28<00:31,  3.87it/s]
#
# Dynamic Programming:  37%|███▋      | 73/195 [00:28<00:30,  3.94it/s]
#
# Dynamic Programming:  38%|███▊      | 74/195 [00:28<00:30,  3.90it/s]
#
# Dynamic Programming:  38%|███▊      | 75/195 [00:29<00:30,  3.99it/s]
#
# Dynamic Programming:  39%|███▉      | 76/195 [00:29<00:29,  4.07it/s]
#
# Dynamic Programming:  39%|███▉      | 77/195 [00:29<00:28,  4.15it/s]
#
# Dynamic Programming:  40%|████      | 78/195 [00:29<00:28,  4.05it/s]
#
# Dynamic Programming:  41%|████      | 79/195 [00:30<00:27,  4.16it/s]
#
# Dynamic Programming:  41%|████      | 80/195 [00:30<00:27,  4.26it/s]
#
# Dynamic Programming:  42%|████▏     | 81/195 [00:30<00:26,  4.34it/s]
#
# Dynamic Programming:  42%|████▏     | 82/195 [00:30<00:25,  4.43it/s]
#
# Dynamic Programming:  43%|████▎     | 83/195 [00:30<00:25,  4.38it/s]
#
# Dynamic Programming:  43%|████▎     | 84/195 [00:31<00:24,  4.48it/s]
#
# Dynamic Programming:  44%|████▎     | 85/195 [00:31<00:24,  4.57it/s]
#
# Dynamic Programming:  44%|████▍     | 86/195 [00:31<00:23,  4.67it/s]
#
# Dynamic Programming:  45%|████▍     | 87/195 [00:31<00:22,  4.76it/s]
#
# Dynamic Programming:  45%|████▌     | 88/195 [00:32<00:22,  4.80it/s]
#
# Dynamic Programming:  46%|████▌     | 89/195 [00:32<00:21,  4.90it/s]
#
# Dynamic Programming:  46%|████▌     | 90/195 [00:32<00:21,  4.99it/s]
#
# Dynamic Programming:  47%|████▋     | 91/195 [00:32<00:20,  5.10it/s]
#
# Dynamic Programming:  47%|████▋     | 92/195 [00:32<00:19,  5.20it/s]
#
# Dynamic Programming:  48%|████▊     | 93/195 [00:32<00:19,  5.13it/s]
#
# Dynamic Programming:  48%|████▊     | 94/195 [00:33<00:19,  5.25it/s]
#
# Dynamic Programming:  49%|████▊     | 95/195 [00:33<00:18,  5.38it/s]
#
# Dynamic Programming:  49%|████▉     | 96/195 [00:33<00:18,  5.50it/s]
#
# Dynamic Programming:  50%|████▉     | 97/195 [00:33<00:17,  5.61it/s]
#
# Dynamic Programming:  50%|█████     | 98/195 [00:33<00:16,  5.71it/s]
#
# Dynamic Programming:  51%|█████     | 99/195 [00:34<00:17,  5.60it/s]
#
# Dynamic Programming:  51%|█████▏    | 100/195 [00:34<00:16,  5.75it/s]
#
# Dynamic Programming:  52%|█████▏    | 101/195 [00:34<00:15,  5.90it/s]
#
# Dynamic Programming:  52%|█████▏    | 102/195 [00:34<00:15,  6.06it/s]
#
# Dynamic Programming:  53%|█████▎    | 103/195 [00:34<00:14,  6.20it/s]
#
# Dynamic Programming:  53%|█████▎    | 104/195 [00:34<00:14,  6.33it/s]
#
# Dynamic Programming:  54%|█████▍    | 105/195 [00:34<00:14,  6.20it/s]
#
# Dynamic Programming:  54%|█████▍    | 106/195 [00:35<00:13,  6.40it/s]
#
# Dynamic Programming:  55%|█████▍    | 107/195 [00:35<00:13,  6.57it/s]
#
# Dynamic Programming:  55%|█████▌    | 108/195 [00:35<00:12,  6.73it/s]
#
# Dynamic Programming:  56%|█████▌    | 109/195 [00:35<00:12,  6.88it/s]
#
# Dynamic Programming:  56%|█████▋    | 110/195 [00:35<00:12,  7.02it/s]
#
# Dynamic Programming:  57%|█████▋    | 111/195 [00:35<00:11,  7.16it/s]
#
# Dynamic Programming:  57%|█████▋    | 112/195 [00:35<00:11,  6.98it/s]
#
# Dynamic Programming:  58%|█████▊    | 113/195 [00:36<00:11,  7.20it/s]
#
# Dynamic Programming:  58%|█████▊    | 114/195 [00:36<00:10,  7.40it/s]
#
# Dynamic Programming:  59%|█████▉    | 115/195 [00:36<00:10,  7.59it/s]
#
# Dynamic Programming:  59%|█████▉    | 116/195 [00:36<00:10,  7.77it/s]
#
# Dynamic Programming:  60%|██████    | 117/195 [00:36<00:09,  7.94it/s]
#
# Dynamic Programming:  61%|██████    | 118/195 [00:36<00:09,  8.11it/s]
#
# Dynamic Programming:  61%|██████    | 119/195 [00:36<00:09,  8.28it/s]
#
# Dynamic Programming:  62%|██████▏   | 120/195 [00:36<00:09,  8.02it/s]
#
# Dynamic Programming:  62%|██████▏   | 121/195 [00:37<00:08,  8.30it/s]
#
# Dynamic Programming:  63%|██████▎   | 122/195 [00:37<00:08,  8.56it/s]
#
# Dynamic Programming:  63%|██████▎   | 123/195 [00:37<00:08,  8.80it/s]
#
# Dynamic Programming:  64%|██████▎   | 124/195 [00:37<00:07,  9.03it/s]
#
# Dynamic Programming:  64%|██████▍   | 125/195 [00:37<00:07,  9.25it/s]
#
# Dynamic Programming:  65%|██████▌   | 127/195 [00:37<00:07,  9.54it/s]
#
# Dynamic Programming:  66%|██████▌   | 129/195 [00:37<00:06,  9.86it/s]
#
# Dynamic Programming:  67%|██████▋   | 130/195 [00:37<00:06,  9.54it/s]
#
# Dynamic Programming:  68%|██████▊   | 132/195 [00:38<00:06, 10.05it/s]
#
# Dynamic Programming:  69%|██████▊   | 134/195 [00:38<00:05, 10.56it/s]
#
# Dynamic Programming:  70%|██████▉   | 136/195 [00:38<00:05, 11.11it/s]
#
# Dynamic Programming:  71%|███████   | 138/195 [00:38<00:04, 11.66it/s]
#
# Dynamic Programming:  72%|███████▏  | 140/195 [00:38<00:04, 12.25it/s]
#
# Dynamic Programming:  73%|███████▎  | 142/195 [00:38<00:04, 12.89it/s]
#
# Dynamic Programming:  74%|███████▍  | 144/195 [00:39<00:03, 13.01it/s]
#
# Dynamic Programming:  75%|███████▍  | 146/195 [00:39<00:03, 13.85it/s]
#
# Dynamic Programming:  76%|███████▌  | 148/195 [00:39<00:03, 14.71it/s]
#
# Dynamic Programming:  77%|███████▋  | 150/195 [00:39<00:02, 15.69it/s]
#
# Dynamic Programming:  78%|███████▊  | 152/195 [00:39<00:02, 16.67it/s]
#
# Dynamic Programming:  79%|███████▉  | 155/195 [00:39<00:02, 17.85it/s]
#
# Dynamic Programming:  81%|████████  | 158/195 [00:39<00:01, 19.28it/s]
#
# Dynamic Programming:  83%|████████▎ | 161/195 [00:39<00:01, 21.02it/s]
#
# Dynamic Programming:  84%|████████▍ | 164/195 [00:39<00:01, 22.46it/s]
#
# Dynamic Programming:  86%|████████▌ | 168/195 [00:40<00:01, 25.21it/s]
#
# Dynamic Programming:  89%|████████▊ | 173/195 [00:40<00:00, 28.93it/s]
#
# Dynamic Programming: 100%|██████████| 195/195 [00:40<00:00,  4.83it/s]
#
#   2%|▏         | 2/87 [01:17<53:50, 38.01s/it]
#
# Dynamic Programming:   0%|          | 0/198 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/198 [00:00<01:51,  1.77it/s]
#
# Dynamic Programming:   1%|          | 2/198 [00:01<01:49,  1.79it/s]
#
# Dynamic Programming:   2%|▏         | 3/198 [00:01<01:48,  1.79it/s]
#
# Dynamic Programming:   2%|▏         | 4/198 [00:02<01:46,  1.82it/s]
#
# Dynamic Programming:   3%|▎         | 5/198 [00:02<01:45,  1.83it/s]
#
# Dynamic Programming:   3%|▎         | 6/198 [00:03<01:43,  1.85it/s]
#
# Dynamic Programming:   4%|▎         | 7/198 [00:03<01:43,  1.85it/s]
#
# Dynamic Programming:   4%|▍         | 8/198 [00:04<01:41,  1.88it/s]
#
# Dynamic Programming:   5%|▍         | 9/198 [00:04<01:40,  1.89it/s]
#
# Dynamic Programming:   5%|▌         | 10/198 [00:05<01:38,  1.92it/s]
#
# Dynamic Programming:   6%|▌         | 11/198 [00:05<01:37,  1.92it/s]
#
# Dynamic Programming:   6%|▌         | 12/198 [00:06<01:35,  1.95it/s]
#
# Dynamic Programming:   7%|▋         | 13/198 [00:06<01:34,  1.95it/s]
#
# Dynamic Programming:   7%|▋         | 14/198 [00:07<01:32,  1.99it/s]
#
# Dynamic Programming:   8%|▊         | 15/198 [00:07<01:31,  2.00it/s]
#
# Dynamic Programming:   8%|▊         | 16/198 [00:08<01:29,  2.04it/s]
#
# Dynamic Programming:   9%|▊         | 17/198 [00:08<01:28,  2.04it/s]
#
# Dynamic Programming:   9%|▉         | 18/198 [00:09<01:27,  2.07it/s]
#
# Dynamic Programming:  10%|▉         | 19/198 [00:09<01:26,  2.07it/s]
#
# Dynamic Programming:  10%|█         | 20/198 [00:10<01:24,  2.10it/s]
#
# Dynamic Programming:  11%|█         | 21/198 [00:10<01:24,  2.10it/s]
#
# Dynamic Programming:  11%|█         | 22/198 [00:11<01:22,  2.14it/s]
#
# Dynamic Programming:  12%|█▏        | 23/198 [00:11<01:20,  2.17it/s]
#
# Dynamic Programming:  12%|█▏        | 24/198 [00:12<01:20,  2.17it/s]
#
# Dynamic Programming:  13%|█▎        | 25/198 [00:12<01:18,  2.20it/s]
#
# Dynamic Programming:  13%|█▎        | 26/198 [00:12<01:18,  2.20it/s]
#
# Dynamic Programming:  14%|█▎        | 27/198 [00:13<01:16,  2.24it/s]
#
# Dynamic Programming:  14%|█▍        | 28/198 [00:13<01:15,  2.24it/s]
# Dynamic Programming:  15%|█▍        | 29/198 [00:14<01:14,  2.28it/s]
#
# Dynamic Programming:  15%|█▌        | 30/198 [00:14<01:12,  2.32it/s]
#
# Dynamic Programming:  16%|█▌        | 31/198 [00:15<01:12,  2.31it/s]
#
# Dynamic Programming:  16%|█▌        | 32/198 [00:15<01:10,  2.35it/s]
#
# Dynamic Programming:  17%|█▋        | 33/198 [00:15<01:09,  2.36it/s]
#
# Dynamic Programming:  17%|█▋        | 34/198 [00:16<01:08,  2.40it/s]
#
# Dynamic Programming:  18%|█▊        | 35/198 [00:16<01:06,  2.44it/s]
#
# Dynamic Programming:  18%|█▊        | 36/198 [00:17<01:06,  2.43it/s]
#
# Dynamic Programming:  19%|█▊        | 37/198 [00:17<01:04,  2.48it/s]
#
# Dynamic Programming:  19%|█▉        | 38/198 [00:17<01:04,  2.48it/s]
#
# Dynamic Programming:  20%|█▉        | 39/198 [00:18<01:02,  2.53it/s]
#
# Dynamic Programming:  20%|██        | 40/198 [00:18<01:01,  2.57it/s]
#
# Dynamic Programming:  21%|██        | 41/198 [00:19<01:01,  2.57it/s]
#
# Dynamic Programming:  21%|██        | 42/198 [00:19<00:59,  2.62it/s]
#
# Dynamic Programming:  22%|██▏       | 43/198 [00:19<00:59,  2.61it/s]
#
# Dynamic Programming:  22%|██▏       | 44/198 [00:20<00:57,  2.66it/s]
#
# Dynamic Programming:  23%|██▎       | 45/198 [00:20<00:56,  2.71it/s]
#
# Dynamic Programming:  23%|██▎       | 46/198 [00:20<00:56,  2.70it/s]
#
# Dynamic Programming:  24%|██▎       | 47/198 [00:21<00:54,  2.76it/s]
#
# Dynamic Programming:  24%|██▍       | 48/198 [00:21<00:53,  2.81it/s]
#
# Dynamic Programming:  25%|██▍       | 49/198 [00:21<00:52,  2.81it/s]
#
# Dynamic Programming:  25%|██▌       | 50/198 [00:22<00:51,  2.87it/s]
#
# Dynamic Programming:  26%|██▌       | 51/198 [00:22<00:50,  2.92it/s]
#
# Dynamic Programming:  26%|██▋       | 52/198 [00:22<00:50,  2.91it/s]
#
# Dynamic Programming:  27%|██▋       | 53/198 [00:23<00:48,  2.97it/s]
#
# Dynamic Programming:  27%|██▋       | 54/198 [00:23<00:47,  3.02it/s]
#
# Dynamic Programming:  28%|██▊       | 55/198 [00:23<00:47,  3.04it/s]
#
# Dynamic Programming:  28%|██▊       | 56/198 [00:24<00:45,  3.09it/s]
#
# Dynamic Programming:  29%|██▉       | 57/198 [00:24<00:44,  3.14it/s]
#
# Dynamic Programming:  29%|██▉       | 58/198 [00:24<00:43,  3.19it/s]
#
# Dynamic Programming:  30%|██▉       | 59/198 [00:25<00:43,  3.19it/s]
#
# Dynamic Programming:  30%|███       | 60/198 [00:25<00:42,  3.24it/s]
#
# Dynamic Programming:  31%|███       | 61/198 [00:25<00:41,  3.30it/s]
#
# Dynamic Programming:  31%|███▏      | 62/198 [00:26<00:41,  3.31it/s]
#
# Dynamic Programming:  32%|███▏      | 63/198 [00:26<00:40,  3.37it/s]
#
# Dynamic Programming:  32%|███▏      | 64/198 [00:26<00:39,  3.42it/s]
#
# Dynamic Programming:  33%|███▎      | 65/198 [00:26<00:38,  3.42it/s]
#
# Dynamic Programming:  33%|███▎      | 66/198 [00:27<00:37,  3.48it/s]
#
# Dynamic Programming:  34%|███▍      | 67/198 [00:27<00:37,  3.54it/s]
#
# Dynamic Programming:  34%|███▍      | 68/198 [00:27<00:36,  3.59it/s]
#
# Dynamic Programming:  35%|███▍      | 69/198 [00:27<00:36,  3.56it/s]
#
# Dynamic Programming:  35%|███▌      | 70/198 [00:28<00:35,  3.63it/s]
#
# Dynamic Programming:  36%|███▌      | 71/198 [00:28<00:34,  3.69it/s]
#
# Dynamic Programming:  36%|███▋      | 72/198 [00:28<00:33,  3.75it/s]
#
# Dynamic Programming:  37%|███▋      | 73/198 [00:29<00:33,  3.71it/s]
#
# Dynamic Programming:  37%|███▋      | 74/198 [00:29<00:32,  3.79it/s]
#
# Dynamic Programming:  38%|███▊      | 75/198 [00:29<00:31,  3.86it/s]
#
# Dynamic Programming:  38%|███▊      | 76/198 [00:29<00:31,  3.93it/s]
#
# Dynamic Programming:  39%|███▉      | 77/198 [00:30<00:31,  3.89it/s]
#
# Dynamic Programming:  39%|███▉      | 78/198 [00:30<00:29,  4.00it/s]
#
# Dynamic Programming:  40%|███▉      | 79/198 [00:30<00:28,  4.12it/s]
#
# Dynamic Programming:  40%|████      | 80/198 [00:30<00:27,  4.22it/s]
#
# Dynamic Programming:  41%|████      | 81/198 [00:30<00:27,  4.19it/s]
#
# Dynamic Programming:  41%|████▏     | 82/198 [00:31<00:26,  4.31it/s]
#
# Dynamic Programming:  42%|████▏     | 83/198 [00:31<00:26,  4.41it/s]
#
# Dynamic Programming:  42%|████▏     | 84/198 [00:31<00:25,  4.50it/s]
#
# Dynamic Programming:  43%|████▎     | 85/198 [00:31<00:24,  4.58it/s]
#
# Dynamic Programming:  43%|████▎     | 86/198 [00:32<00:24,  4.52it/s]
#
# Dynamic Programming:  44%|████▍     | 87/198 [00:32<00:23,  4.63it/s]
#
# Dynamic Programming:  44%|████▍     | 88/198 [00:32<00:23,  4.73it/s]
#
# Dynamic Programming:  45%|████▍     | 89/198 [00:32<00:22,  4.82it/s]
#
# Dynamic Programming:  45%|████▌     | 90/198 [00:32<00:22,  4.90it/s]
#
# Dynamic Programming:  46%|████▌     | 91/198 [00:33<00:22,  4.83it/s]
#
# Dynamic Programming:  46%|████▋     | 92/198 [00:33<00:21,  4.96it/s]
#
# Dynamic Programming:  47%|████▋     | 93/198 [00:33<00:20,  5.08it/s]
#
# Dynamic Programming:  47%|████▋     | 94/198 [00:33<00:20,  5.18it/s]
#
# Dynamic Programming:  48%|████▊     | 95/198 [00:33<00:19,  5.28it/s]
#
# Dynamic Programming:  48%|████▊     | 96/198 [00:33<00:19,  5.21it/s]
#
# Dynamic Programming:  49%|████▉     | 97/198 [00:34<00:18,  5.35it/s]
#
# Dynamic Programming:  49%|████▉     | 98/198 [00:34<00:18,  5.47it/s]
#
# Dynamic Programming:  50%|█████     | 99/198 [00:34<00:17,  5.58it/s]
#
# Dynamic Programming:  51%|█████     | 100/198 [00:34<00:17,  5.69it/s]
#
# Dynamic Programming:  51%|█████     | 101/198 [00:34<00:16,  5.79it/s]
#
# Dynamic Programming:  52%|█████▏    | 102/198 [00:35<00:16,  5.69it/s]
#
# Dynamic Programming:  52%|█████▏    | 103/198 [00:35<00:16,  5.85it/s]
#
# Dynamic Programming:  53%|█████▎    | 104/198 [00:35<00:15,  5.99it/s]
#
# Dynamic Programming:  53%|█████▎    | 105/198 [00:35<00:15,  6.13it/s]
#
# Dynamic Programming:  54%|█████▎    | 106/198 [00:35<00:14,  6.25it/s]
#
# Dynamic Programming:  54%|█████▍    | 107/198 [00:35<00:14,  6.37it/s]
#
# Dynamic Programming:  55%|█████▍    | 108/198 [00:35<00:13,  6.50it/s]
#
# Dynamic Programming:  55%|█████▌    | 109/198 [00:36<00:13,  6.47it/s]
#
# Dynamic Programming:  56%|█████▌    | 110/198 [00:36<00:13,  6.63it/s]
#
# Dynamic Programming:  56%|█████▌    | 111/198 [00:36<00:12,  6.78it/s]
#
# Dynamic Programming:  57%|█████▋    | 112/198 [00:36<00:12,  6.92it/s]
#
# Dynamic Programming:  57%|█████▋    | 113/198 [00:36<00:12,  7.06it/s]
#
# Dynamic Programming:  58%|█████▊    | 114/198 [00:36<00:11,  7.20it/s]
#
# Dynamic Programming:  58%|█████▊    | 115/198 [00:36<00:11,  7.36it/s]
#
# Dynamic Programming:  59%|█████▊    | 116/198 [00:37<00:11,  7.16it/s]
#
# Dynamic Programming:  59%|█████▉    | 117/198 [00:37<00:10,  7.42it/s]
#
# Dynamic Programming:  60%|█████▉    | 118/198 [00:37<00:10,  7.64it/s]
#
# Dynamic Programming:  60%|██████    | 119/198 [00:37<00:10,  7.83it/s]
#
# Dynamic Programming:  61%|██████    | 120/198 [00:37<00:09,  8.00it/s]
#
# Dynamic Programming:  61%|██████    | 121/198 [00:37<00:09,  8.20it/s]
#
# Dynamic Programming:  62%|██████▏   | 122/198 [00:37<00:09,  8.37it/s]
#
# Dynamic Programming:  62%|██████▏   | 123/198 [00:37<00:08,  8.53it/s]
#
# Dynamic Programming:  63%|██████▎   | 124/198 [00:38<00:08,  8.25it/s]
#
# Dynamic Programming:  63%|██████▎   | 125/198 [00:38<00:08,  8.54it/s]
#
# Dynamic Programming:  64%|██████▎   | 126/198 [00:38<00:08,  8.81it/s]
#
# Dynamic Programming:  64%|██████▍   | 127/198 [00:38<00:07,  9.06it/s]
#
# Dynamic Programming:  65%|██████▍   | 128/198 [00:38<00:07,  9.30it/s]
#
# Dynamic Programming:  66%|██████▌   | 130/198 [00:38<00:07,  9.59it/s]
#
# Dynamic Programming:  66%|██████▌   | 131/198 [00:38<00:06,  9.67it/s]
#
# Dynamic Programming:  67%|██████▋   | 133/198 [00:38<00:06, 10.03it/s]
#
# Dynamic Programming:  68%|██████▊   | 135/198 [00:39<00:06, 10.10it/s]
#
# Dynamic Programming:  69%|██████▉   | 137/198 [00:39<00:05, 10.58it/s]
#
# Dynamic Programming:  70%|███████   | 139/198 [00:39<00:05, 11.08it/s]
#
# Dynamic Programming:  71%|███████   | 141/198 [00:39<00:04, 11.62it/s]
#
# Dynamic Programming:  72%|███████▏  | 143/198 [00:39<00:04, 12.23it/s]
#
# Dynamic Programming:  73%|███████▎  | 145/198 [00:39<00:04, 12.88it/s]
#
# Dynamic Programming:  74%|███████▍  | 147/198 [00:39<00:03, 13.57it/s]
#
# Dynamic Programming:  75%|███████▌  | 149/198 [00:40<00:03, 14.02it/s]
#
# Dynamic Programming:  76%|███████▋  | 151/198 [00:40<00:03, 14.91it/s]
#
# Dynamic Programming:  77%|███████▋  | 153/198 [00:40<00:02, 15.83it/s]
#
# Dynamic Programming:  78%|███████▊  | 155/198 [00:40<00:02, 16.82it/s]
#
# Dynamic Programming:  80%|███████▉  | 158/198 [00:40<00:02, 18.00it/s]
#
# Dynamic Programming:  81%|████████▏ | 161/198 [00:40<00:01, 19.45it/s]
#
# Dynamic Programming:  83%|████████▎ | 164/198 [00:40<00:01, 21.19it/s]
#
# Dynamic Programming:  85%|████████▍ | 168/198 [00:40<00:01, 23.43it/s]
#
# Dynamic Programming:  86%|████████▋ | 171/198 [00:41<00:01, 24.83it/s]
#
# Dynamic Programming:  89%|████████▉ | 176/198 [00:41<00:00, 28.64it/s]
#
# Dynamic Programming: 100%|██████████| 198/198 [00:41<00:00,  4.79it/s]
#
#   3%|▎         | 3/87 [01:58<54:37, 39.02s/it]
#
# Dynamic Programming:   0%|          | 0/199 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/199 [00:00<01:46,  1.85it/s]
#
# Dynamic Programming:   1%|          | 2/199 [00:01<01:47,  1.83it/s]
#
# Dynamic Programming:   2%|▏         | 3/199 [00:01<01:46,  1.84it/s]
#
# Dynamic Programming:   2%|▏         | 4/199 [00:02<01:46,  1.83it/s]
#
# Dynamic Programming:   3%|▎         | 5/199 [00:02<01:46,  1.82it/s]
#
# Dynamic Programming:   3%|▎         | 6/199 [00:03<01:44,  1.85it/s]
#
# Dynamic Programming:   4%|▎         | 7/199 [00:03<01:43,  1.85it/s]
#
# Dynamic Programming:   4%|▍         | 8/199 [00:04<01:41,  1.88it/s]
#
# Dynamic Programming:   5%|▍         | 9/199 [00:04<01:41,  1.88it/s]
#
# Dynamic Programming:   5%|▌         | 10/199 [00:05<01:39,  1.91it/s]
#
# Dynamic Programming:   6%|▌         | 11/199 [00:05<01:38,  1.91it/s]
#
# Dynamic Programming:   6%|▌         | 12/199 [00:06<01:36,  1.94it/s]
#
# Dynamic Programming:   7%|▋         | 13/199 [00:06<01:35,  1.94it/s]
#
# Dynamic Programming:   7%|▋         | 14/199 [00:07<01:33,  1.98it/s]
#
# Dynamic Programming:   8%|▊         | 15/199 [00:07<01:33,  1.97it/s]
#
# Dynamic Programming:   8%|▊         | 16/199 [00:08<01:31,  2.00it/s]
#
# Dynamic Programming:   9%|▊         | 17/199 [00:08<01:30,  2.01it/s]
#
# Dynamic Programming:   9%|▉         | 18/199 [00:09<01:28,  2.04it/s]
#
# Dynamic Programming:  10%|▉         | 19/199 [00:09<01:27,  2.05it/s]
#
# Dynamic Programming:  10%|█         | 20/199 [00:10<01:25,  2.08it/s]
#
# Dynamic Programming:  11%|█         | 21/199 [00:10<01:24,  2.11it/s]
#
# Dynamic Programming:  11%|█         | 22/199 [00:11<01:24,  2.10it/s]
#
# Dynamic Programming:  12%|█▏        | 23/199 [00:11<01:22,  2.14it/s]
#
# Dynamic Programming:  12%|█▏        | 24/199 [00:12<01:21,  2.15it/s]
#
# Dynamic Programming:  13%|█▎        | 25/199 [00:12<01:19,  2.19it/s]
#
# Dynamic Programming:  13%|█▎        | 26/199 [00:13<01:18,  2.19it/s]
#
# Dynamic Programming:  14%|█▎        | 27/199 [00:13<01:17,  2.22it/s]
#
# Dynamic Programming:  14%|█▍        | 28/199 [00:13<01:16,  2.23it/s]
#
# Dynamic Programming:  15%|█▍        | 29/199 [00:14<01:14,  2.27it/s]
#
# Dynamic Programming:  15%|█▌        | 30/199 [00:14<01:13,  2.31it/s]
#
# Dynamic Programming:  16%|█▌        | 31/199 [00:15<01:12,  2.30it/s]
#
# Dynamic Programming:  16%|█▌        | 32/199 [00:15<01:11,  2.34it/s]
#
# Dynamic Programming:  17%|█▋        | 33/199 [00:16<01:10,  2.36it/s]
#
# Dynamic Programming:  17%|█▋        | 34/199 [00:16<01:08,  2.40it/s]
#
# Dynamic Programming:  18%|█▊        | 35/199 [00:16<01:07,  2.44it/s]
#
# Dynamic Programming:  18%|█▊        | 36/199 [00:17<01:07,  2.43it/s]
#
# Dynamic Programming:  19%|█▊        | 37/199 [00:17<01:05,  2.47it/s]
#
# Dynamic Programming:  19%|█▉        | 38/199 [00:18<01:04,  2.48it/s]
#
# Dynamic Programming:  20%|█▉        | 39/199 [00:18<01:03,  2.53it/s]
#
# Dynamic Programming:  20%|██        | 40/199 [00:18<01:01,  2.57it/s]
#
# Dynamic Programming:  21%|██        | 41/199 [00:19<01:01,  2.56it/s]
#
# Dynamic Programming:  21%|██        | 42/199 [00:19<01:00,  2.60it/s]
#
# Dynamic Programming:  22%|██▏       | 43/199 [00:19<00:59,  2.60it/s]
#
# Dynamic Programming:  22%|██▏       | 44/199 [00:20<00:58,  2.65it/s]
#
# Dynamic Programming:  23%|██▎       | 45/199 [00:20<00:57,  2.70it/s]
#
# Dynamic Programming:  23%|██▎       | 46/199 [00:20<00:56,  2.69it/s]
#
# Dynamic Programming:  24%|██▎       | 47/199 [00:21<00:55,  2.74it/s]
#
# Dynamic Programming:  24%|██▍       | 48/199 [00:21<00:54,  2.79it/s]
#
# Dynamic Programming:  25%|██▍       | 49/199 [00:22<00:53,  2.78it/s]
#
# Dynamic Programming:  25%|██▌       | 50/199 [00:22<00:52,  2.84it/s]
#
# Dynamic Programming:  26%|██▌       | 51/199 [00:22<00:51,  2.88it/s]
#
# Dynamic Programming:  26%|██▌       | 52/199 [00:23<00:51,  2.87it/s]
#
# Dynamic Programming:  27%|██▋       | 53/199 [00:23<00:49,  2.93it/s]
#
# Dynamic Programming:  27%|██▋       | 54/199 [00:23<00:48,  2.97it/s]
#
# Dynamic Programming:  28%|██▊       | 55/199 [00:24<00:48,  2.96it/s]
#
# Dynamic Programming:  28%|██▊       | 56/199 [00:24<00:47,  3.02it/s]
#
# Dynamic Programming:  29%|██▊       | 57/199 [00:24<00:46,  3.07it/s]
#
# Dynamic Programming:  29%|██▉       | 58/199 [00:25<00:46,  3.06it/s]
#
# Dynamic Programming:  30%|██▉       | 59/199 [00:25<00:44,  3.12it/s]
#
# Dynamic Programming:  30%|███       | 60/199 [00:25<00:43,  3.17it/s]
#
# Dynamic Programming:  31%|███       | 61/199 [00:25<00:42,  3.22it/s]
#
# Dynamic Programming:  31%|███       | 62/199 [00:26<00:42,  3.20it/s]
#
# Dynamic Programming:  32%|███▏      | 63/199 [00:26<00:41,  3.26it/s]
#
# Dynamic Programming:  32%|███▏      | 64/199 [00:26<00:40,  3.33it/s]
#
# Dynamic Programming:  33%|███▎      | 65/199 [00:27<00:40,  3.32it/s]
#
# Dynamic Programming:  33%|███▎      | 66/199 [00:27<00:39,  3.39it/s]
#
# Dynamic Programming:  34%|███▎      | 67/199 [00:27<00:38,  3.46it/s]
#
# Dynamic Programming:  34%|███▍      | 68/199 [00:27<00:37,  3.52it/s]
#
# Dynamic Programming:  35%|███▍      | 69/199 [00:28<00:37,  3.50it/s]
#
# Dynamic Programming:  35%|███▌      | 70/199 [00:28<00:36,  3.57it/s]
#
# Dynamic Programming:  36%|███▌      | 71/199 [00:28<00:35,  3.64it/s]
#
# Dynamic Programming:  36%|███▌      | 72/199 [00:29<00:35,  3.62it/s]
#
# Dynamic Programming:  37%|███▋      | 73/199 [00:29<00:34,  3.70it/s]
#
# Dynamic Programming:  37%|███▋      | 74/199 [00:29<00:33,  3.77it/s]
#
# Dynamic Programming:  38%|███▊      | 75/199 [00:29<00:32,  3.84it/s]
#
# Dynamic Programming:  38%|███▊      | 76/199 [00:30<00:32,  3.80it/s]
#
# Dynamic Programming:  39%|███▊      | 77/199 [00:30<00:31,  3.89it/s]
#
# Dynamic Programming:  39%|███▉      | 78/199 [00:30<00:30,  3.97it/s]
#
# Dynamic Programming:  40%|███▉      | 79/199 [00:30<00:29,  4.04it/s]
#
# Dynamic Programming:  40%|████      | 80/199 [00:31<00:29,  4.00it/s]
#
# Dynamic Programming:  41%|████      | 81/199 [00:31<00:28,  4.09it/s]
#
# Dynamic Programming:  41%|████      | 82/199 [00:31<00:28,  4.17it/s]
#
# Dynamic Programming:  42%|████▏     | 83/199 [00:31<00:27,  4.25it/s]
#
# Dynamic Programming:  42%|████▏     | 84/199 [00:31<00:26,  4.32it/s]
#
# Dynamic Programming:  43%|████▎     | 85/199 [00:32<00:26,  4.27it/s]
#
# Dynamic Programming:  43%|████▎     | 86/199 [00:32<00:25,  4.36it/s]
#
# Dynamic Programming:  44%|████▎     | 87/199 [00:32<00:25,  4.45it/s]
#
# Dynamic Programming:  44%|████▍     | 88/199 [00:32<00:24,  4.53it/s]
# Dynamic Programming:  45%|████▍     | 89/199 [00:33<00:24,  4.47it/s]
#
# Dynamic Programming:  45%|████▌     | 90/199 [00:33<00:23,  4.58it/s]
#
# Dynamic Programming:  46%|████▌     | 91/199 [00:33<00:22,  4.70it/s]
#
# Dynamic Programming:  46%|████▌     | 92/199 [00:33<00:22,  4.80it/s]
#
# Dynamic Programming:  47%|████▋     | 93/199 [00:33<00:21,  4.89it/s]
#
# Dynamic Programming:  47%|████▋     | 94/199 [00:34<00:21,  4.85it/s]
#
# Dynamic Programming:  48%|████▊     | 95/199 [00:34<00:20,  4.96it/s]
#
# Dynamic Programming:  48%|████▊     | 96/199 [00:34<00:20,  5.07it/s]
#
# Dynamic Programming:  49%|████▊     | 97/199 [00:34<00:19,  5.19it/s]
#
# Dynamic Programming:  49%|████▉     | 98/199 [00:34<00:19,  5.29it/s]
#
# Dynamic Programming:  50%|████▉     | 99/199 [00:35<00:18,  5.39it/s]
#
# Dynamic Programming:  50%|█████     | 100/199 [00:35<00:18,  5.31it/s]
#
# Dynamic Programming:  51%|█████     | 101/199 [00:35<00:17,  5.48it/s]
#
# Dynamic Programming:  51%|█████▏    | 102/199 [00:35<00:17,  5.63it/s]
#
# Dynamic Programming:  52%|█████▏    | 103/199 [00:35<00:16,  5.76it/s]
#
# Dynamic Programming:  52%|█████▏    | 104/199 [00:35<00:16,  5.88it/s]
#
# Dynamic Programming:  53%|█████▎    | 105/199 [00:36<00:15,  6.00it/s]
#
# Dynamic Programming:  53%|█████▎    | 106/199 [00:36<00:15,  5.89it/s]
#
# Dynamic Programming:  54%|█████▍    | 107/199 [00:36<00:15,  6.05it/s]
#
# Dynamic Programming:  54%|█████▍    | 108/199 [00:36<00:14,  6.21it/s]
#
# Dynamic Programming:  55%|█████▍    | 109/199 [00:36<00:14,  6.36it/s]
#
# Dynamic Programming:  55%|█████▌    | 110/199 [00:36<00:13,  6.49it/s]
#
# Dynamic Programming:  56%|█████▌    | 111/199 [00:36<00:13,  6.63it/s]
#
# Dynamic Programming:  56%|█████▋    | 112/199 [00:37<00:13,  6.61it/s]
#
# Dynamic Programming:  57%|█████▋    | 113/199 [00:37<00:12,  6.77it/s]
#
# Dynamic Programming:  57%|█████▋    | 114/199 [00:37<00:12,  6.93it/s]
#
# Dynamic Programming:  58%|█████▊    | 115/199 [00:37<00:11,  7.08it/s]
#
# Dynamic Programming:  58%|█████▊    | 116/199 [00:37<00:11,  7.23it/s]
#
# Dynamic Programming:  59%|█████▉    | 117/199 [00:37<00:11,  7.38it/s]
#
# Dynamic Programming:  59%|█████▉    | 118/199 [00:37<00:10,  7.52it/s]
#
# Dynamic Programming:  60%|█████▉    | 119/199 [00:38<00:10,  7.68it/s]
#
# Dynamic Programming:  60%|██████    | 120/199 [00:38<00:10,  7.49it/s]
#
# Dynamic Programming:  61%|██████    | 121/199 [00:38<00:10,  7.74it/s]
#
# Dynamic Programming:  61%|██████▏   | 122/199 [00:38<00:09,  7.96it/s]
#
# Dynamic Programming:  62%|██████▏   | 123/199 [00:38<00:09,  8.20it/s]
#
# Dynamic Programming:  62%|██████▏   | 124/199 [00:38<00:08,  8.39it/s]
#
# Dynamic Programming:  63%|██████▎   | 125/199 [00:38<00:08,  8.57it/s]
#
# Dynamic Programming:  63%|██████▎   | 126/199 [00:38<00:08,  8.76it/s]
#
# Dynamic Programming:  64%|██████▍   | 127/199 [00:38<00:08,  8.90it/s]
#
# Dynamic Programming:  64%|██████▍   | 128/199 [00:39<00:07,  9.06it/s]
#
# Dynamic Programming:  65%|██████▍   | 129/199 [00:39<00:07,  8.91it/s]
#
# Dynamic Programming:  65%|██████▌   | 130/199 [00:39<00:07,  9.16it/s]
#
# Dynamic Programming:  66%|██████▋   | 132/199 [00:39<00:07,  9.47it/s]
#
# Dynamic Programming:  67%|██████▋   | 134/199 [00:39<00:06,  9.84it/s]
#
# Dynamic Programming:  68%|██████▊   | 136/199 [00:39<00:06, 10.23it/s]
#
# Dynamic Programming:  69%|██████▉   | 138/199 [00:39<00:05, 10.64it/s]
#
# Dynamic Programming:  70%|███████   | 140/199 [00:40<00:05, 10.69it/s]
#
# Dynamic Programming:  71%|███████▏  | 142/199 [00:40<00:05, 11.23it/s]
#
# Dynamic Programming:  72%|███████▏  | 144/199 [00:40<00:04, 11.90it/s]
#
# Dynamic Programming:  73%|███████▎  | 146/199 [00:40<00:04, 12.63it/s]
#
# Dynamic Programming:  74%|███████▍  | 148/199 [00:40<00:03, 13.38it/s]
#
# Dynamic Programming:  75%|███████▌  | 150/199 [00:40<00:03, 14.18it/s]
#
# Dynamic Programming:  76%|███████▋  | 152/199 [00:40<00:03, 15.01it/s]
#
# Dynamic Programming:  77%|███████▋  | 154/199 [00:41<00:02, 15.91it/s]
#
# Dynamic Programming:  78%|███████▊  | 156/199 [00:41<00:02, 16.02it/s]
#
# Dynamic Programming:  80%|███████▉  | 159/199 [00:41<00:02, 17.37it/s]
#
# Dynamic Programming:  81%|████████▏ | 162/199 [00:41<00:01, 18.95it/s]
#
# Dynamic Programming:  83%|████████▎ | 165/199 [00:41<00:01, 20.78it/s]
#
# Dynamic Programming:  85%|████████▍ | 169/199 [00:41<00:01, 23.08it/s]
#
# Dynamic Programming:  87%|████████▋ | 173/199 [00:41<00:00, 26.09it/s]
#
# Dynamic Programming:  89%|████████▉ | 178/199 [00:41<00:00, 30.19it/s]
#
# Dynamic Programming: 100%|██████████| 199/199 [00:42<00:00,  4.73it/s]
#
#   5%|▍         | 4/87 [02:40<55:15, 39.95s/it]
#
# Dynamic Programming:   0%|          | 0/196 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/196 [00:00<01:48,  1.80it/s]
#
# Dynamic Programming:   1%|          | 2/196 [00:01<01:47,  1.80it/s]
#
# Dynamic Programming:   2%|▏         | 3/196 [00:01<01:46,  1.82it/s]
#
# Dynamic Programming:   2%|▏         | 4/196 [00:02<01:45,  1.82it/s]
#
# Dynamic Programming:   3%|▎         | 5/196 [00:02<01:43,  1.85it/s]
#
# Dynamic Programming:   3%|▎         | 6/196 [00:03<01:42,  1.86it/s]
#
# Dynamic Programming:   4%|▎         | 7/196 [00:03<01:40,  1.89it/s]
#
# Dynamic Programming:   4%|▍         | 8/196 [00:04<01:39,  1.90it/s]
#
# Dynamic Programming:   5%|▍         | 9/196 [00:04<01:37,  1.93it/s]
#
# Dynamic Programming:   5%|▌         | 10/196 [00:05<01:36,  1.94it/s]
#
# Dynamic Programming:   6%|▌         | 11/196 [00:05<01:33,  1.97it/s]
#
# Dynamic Programming:   6%|▌         | 12/196 [00:06<01:32,  1.98it/s]
#
# Dynamic Programming:   7%|▋         | 13/196 [00:06<01:30,  2.02it/s]
#
# Dynamic Programming:   7%|▋         | 14/196 [00:07<01:30,  2.02it/s]
#
# Dynamic Programming:   8%|▊         | 15/196 [00:07<01:27,  2.06it/s]
#
# Dynamic Programming:   8%|▊         | 16/196 [00:08<01:26,  2.08it/s]
#
# Dynamic Programming:   9%|▊         | 17/196 [00:08<01:25,  2.10it/s]
#
# Dynamic Programming:   9%|▉         | 18/196 [00:09<01:23,  2.13it/s]
#
# Dynamic Programming:  10%|▉         | 19/196 [00:09<01:23,  2.13it/s]
#
# Dynamic Programming:  10%|█         | 20/196 [00:10<01:21,  2.16it/s]
#
# Dynamic Programming:  11%|█         | 21/196 [00:10<01:20,  2.16it/s]
#
# Dynamic Programming:  11%|█         | 22/196 [00:10<01:19,  2.20it/s]
#
# Dynamic Programming:  12%|█▏        | 23/196 [00:11<01:18,  2.20it/s]
#
# Dynamic Programming:  12%|█▏        | 24/196 [00:11<01:16,  2.24it/s]
#
# Dynamic Programming:  13%|█▎        | 25/196 [00:12<01:16,  2.24it/s]
#
# Dynamic Programming:  13%|█▎        | 26/196 [00:12<01:14,  2.29it/s]
#
# Dynamic Programming:  14%|█▍        | 27/196 [00:13<01:12,  2.33it/s]
#
# Dynamic Programming:  14%|█▍        | 28/196 [00:13<01:12,  2.33it/s]
#
# Dynamic Programming:  15%|█▍        | 29/196 [00:13<01:10,  2.37it/s]
#
# Dynamic Programming:  15%|█▌        | 30/196 [00:14<01:10,  2.37it/s]
#
# Dynamic Programming:  16%|█▌        | 31/196 [00:14<01:08,  2.41it/s]
#
# Dynamic Programming:  16%|█▋        | 32/196 [00:15<01:06,  2.45it/s]
#
# Dynamic Programming:  17%|█▋        | 33/196 [00:15<01:06,  2.45it/s]
#
# Dynamic Programming:  17%|█▋        | 34/196 [00:15<01:05,  2.49it/s]
#
# Dynamic Programming:  18%|█▊        | 35/196 [00:16<01:04,  2.49it/s]
#
# Dynamic Programming:  18%|█▊        | 36/196 [00:16<01:03,  2.53it/s]
#
# Dynamic Programming:  19%|█▉        | 37/196 [00:17<01:01,  2.58it/s]
#
# Dynamic Programming:  19%|█▉        | 38/196 [00:17<01:01,  2.58it/s]
#
# Dynamic Programming:  20%|█▉        | 39/196 [00:17<00:59,  2.62it/s]
#
# Dynamic Programming:  20%|██        | 40/196 [00:18<00:58,  2.67it/s]
#
# Dynamic Programming:  21%|██        | 41/196 [00:18<00:57,  2.70it/s]
#
# Dynamic Programming:  21%|██▏       | 42/196 [00:18<00:56,  2.74it/s]
#
# Dynamic Programming:  22%|██▏       | 43/196 [00:19<00:55,  2.77it/s]
#
# Dynamic Programming:  22%|██▏       | 44/196 [00:19<00:54,  2.78it/s]
#
# Dynamic Programming:  23%|██▎       | 45/196 [00:19<00:53,  2.81it/s]
#
# Dynamic Programming:  23%|██▎       | 46/196 [00:20<00:53,  2.81it/s]
#
# Dynamic Programming:  24%|██▍       | 47/196 [00:20<00:52,  2.86it/s]
#
# Dynamic Programming:  24%|██▍       | 48/196 [00:20<00:50,  2.90it/s]
#
# Dynamic Programming:  25%|██▌       | 49/196 [00:21<00:50,  2.89it/s]
#
# Dynamic Programming:  26%|██▌       | 50/196 [00:21<00:49,  2.95it/s]
#
# Dynamic Programming:  26%|██▌       | 51/196 [00:21<00:48,  3.00it/s]
#
# Dynamic Programming:  27%|██▋       | 52/196 [00:22<00:47,  3.04it/s]
#
# Dynamic Programming:  27%|██▋       | 53/196 [00:22<00:47,  3.04it/s]
#
# Dynamic Programming:  28%|██▊       | 54/196 [00:22<00:45,  3.09it/s]
#
# Dynamic Programming:  28%|██▊       | 55/196 [00:23<00:44,  3.14it/s]
#
# Dynamic Programming:  29%|██▊       | 56/196 [00:23<00:44,  3.13it/s]
#
# Dynamic Programming:  29%|██▉       | 57/196 [00:23<00:43,  3.19it/s]
#
# Dynamic Programming:  30%|██▉       | 58/196 [00:24<00:42,  3.24it/s]
#
# Dynamic Programming:  30%|███       | 59/196 [00:24<00:41,  3.26it/s]
#
# Dynamic Programming:  31%|███       | 60/196 [00:24<00:40,  3.32it/s]
#
# Dynamic Programming:  31%|███       | 61/196 [00:25<00:40,  3.37it/s]
#
# Dynamic Programming:  32%|███▏      | 62/196 [00:25<00:39,  3.42it/s]
#
# Dynamic Programming:  32%|███▏      | 63/196 [00:25<00:37,  3.50it/s]
#
# Dynamic Programming:  33%|███▎      | 64/196 [00:25<00:37,  3.51it/s]
#
# Dynamic Programming:  33%|███▎      | 65/196 [00:26<00:36,  3.56it/s]
#
# Dynamic Programming:  34%|███▎      | 66/196 [00:26<00:36,  3.53it/s]
#
# Dynamic Programming:  34%|███▍      | 67/196 [00:26<00:35,  3.61it/s]
#
# Dynamic Programming:  35%|███▍      | 68/196 [00:26<00:34,  3.67it/s]
#
# Dynamic Programming:  35%|███▌      | 69/196 [00:27<00:34,  3.73it/s]
#
# Dynamic Programming:  36%|███▌      | 70/196 [00:27<00:34,  3.70it/s]
#
# Dynamic Programming:  36%|███▌      | 71/196 [00:27<00:33,  3.78it/s]
#
# Dynamic Programming:  37%|███▋      | 72/196 [00:27<00:32,  3.85it/s]
#
# Dynamic Programming:  37%|███▋      | 73/196 [00:28<00:31,  3.92it/s]
#
# Dynamic Programming:  38%|███▊      | 74/196 [00:28<00:31,  3.88it/s]
#
# Dynamic Programming:  38%|███▊      | 75/196 [00:28<00:30,  3.97it/s]
#
# Dynamic Programming:  39%|███▉      | 76/196 [00:28<00:29,  4.05it/s]
#
# Dynamic Programming:  39%|███▉      | 77/196 [00:29<00:28,  4.12it/s]
#
# Dynamic Programming:  40%|███▉      | 78/196 [00:29<00:28,  4.08it/s]
#
# Dynamic Programming:  40%|████      | 79/196 [00:29<00:28,  4.17it/s]
#
# Dynamic Programming:  41%|████      | 80/196 [00:29<00:27,  4.26it/s]
#
# Dynamic Programming:  41%|████▏     | 81/196 [00:30<00:26,  4.34it/s]
#
# Dynamic Programming:  42%|████▏     | 82/196 [00:30<00:25,  4.42it/s]
#
# ...
#
# Dynamic Programming:  74%|███████▍  | 150/202 [00:41<00:03, 13.12it/s]
#
# Dynamic Programming:  75%|███████▌  | 152/202 [00:41<00:03, 13.89it/s]
#
# Dynamic Programming:  76%|███████▌  | 154/202 [00:41<00:03, 14.73it/s]
#
# Dynamic Programming:  77%|███████▋  | 156/202 [00:41<00:02, 15.62it/s]
#
# Dynamic Programming:  78%|███████▊  | 158/202 [00:41<00:02, 16.58it/s]
#
# Dynamic Programming:  80%|███████▉  | 161/202 [00:41<00:02, 17.75it/s]
#
# Dynamic Programming:  81%|████████  | 163/202 [00:42<00:02, 17.95it/s]
#
# Dynamic Programming:  82%|████████▏ | 166/202 [00:42<00:01, 19.68it/s]
#
# Dynamic Programming:  84%|████████▎ | 169/202 [00:42<00:01, 21.69it/s]
#
# Dynamic Programming:  86%|████████▌ | 173/202 [00:42<00:01, 24.17it/s]
#
# Dynamic Programming:  88%|████████▊ | 177/202 [00:42<00:00, 27.39it/s]
#
# Dynamic Programming:  91%|█████████ | 183/202 [00:42<00:00, 32.01it/s]
#
# Dynamic Programming: 100%|██████████| 202/202 [00:42<00:00,  4.72it/s]
#
#  95%|█████████▌| 83/87 [56:00<02:45, 41.26s/it]
#
# Dynamic Programming:   0%|          | 0/170 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/170 [00:00<01:19,  2.14it/s]
#
# Dynamic Programming:   1%|          | 2/170 [00:00<01:17,  2.17it/s]
#
# Dynamic Programming:   2%|▏         | 3/170 [00:01<01:17,  2.17it/s]
#
# Dynamic Programming:   2%|▏         | 4/170 [00:01<01:15,  2.20it/s]
#
# Dynamic Programming:   3%|▎         | 5/170 [00:02<01:14,  2.23it/s]
#
# Dynamic Programming:   4%|▎         | 6/170 [00:02<01:13,  2.23it/s]
#
# Dynamic Programming:   4%|▍         | 7/170 [00:03<01:12,  2.26it/s]
#
# Dynamic Programming:   5%|▍         | 8/170 [00:03<01:11,  2.26it/s]
#
# Dynamic Programming:   5%|▌         | 9/170 [00:03<01:09,  2.30it/s]
#
# Dynamic Programming:   6%|▌         | 10/170 [00:04<01:09,  2.31it/s]
#
# Dynamic Programming:   6%|▋         | 11/170 [00:04<01:07,  2.36it/s]
#
# Dynamic Programming:   7%|▋         | 12/170 [00:05<01:05,  2.40it/s]
#
# Dynamic Programming:   8%|▊         | 13/170 [00:05<01:05,  2.41it/s]
#
# Dynamic Programming:   8%|▊         | 14/170 [00:06<01:03,  2.46it/s]
#
# Dynamic Programming:   9%|▉         | 15/170 [00:06<01:03,  2.45it/s]
#
# Dynamic Programming:   9%|▉         | 16/170 [00:06<01:01,  2.50it/s]
#
# Dynamic Programming:  10%|█         | 17/170 [00:07<01:00,  2.55it/s]
#
# Dynamic Programming:  11%|█         | 18/170 [00:07<00:59,  2.55it/s]
#
# Dynamic Programming:  11%|█         | 19/170 [00:07<00:57,  2.61it/s]
#
# Dynamic Programming:  12%|█▏        | 20/170 [00:08<00:56,  2.66it/s]
#
# Dynamic Programming:  12%|█▏        | 21/170 [00:08<00:56,  2.65it/s]
#
# Dynamic Programming:  13%|█▎        | 22/170 [00:09<00:54,  2.71it/s]
#
# Dynamic Programming:  14%|█▎        | 23/170 [00:09<00:53,  2.73it/s]
#
# Dynamic Programming:  14%|█▍        | 24/170 [00:09<00:52,  2.77it/s]
#
# Dynamic Programming:  15%|█▍        | 25/170 [00:10<00:51,  2.81it/s]
#
# Dynamic Programming:  15%|█▌        | 26/170 [00:10<00:51,  2.80it/s]
#
# Dynamic Programming:  16%|█▌        | 27/170 [00:10<00:50,  2.84it/s]
#
# Dynamic Programming:  16%|█▋        | 28/170 [00:11<00:49,  2.89it/s]
#
# Dynamic Programming:  17%|█▋        | 29/170 [00:11<00:49,  2.88it/s]
#
# Dynamic Programming:  18%|█▊        | 30/170 [00:11<00:47,  2.93it/s]
#
# Dynamic Programming:  18%|█▊        | 31/170 [00:12<00:46,  2.98it/s]
#
# Dynamic Programming:  19%|█▉        | 32/170 [00:12<00:46,  2.97it/s]
#
# Dynamic Programming:  19%|█▉        | 33/170 [00:12<00:45,  3.02it/s]
#
# Dynamic Programming:  20%|██        | 34/170 [00:13<00:44,  3.07it/s]
# Dynamic Programming:  21%|██        | 35/170 [00:13<00:43,  3.12it/s]
#
# Dynamic Programming:  21%|██        | 36/170 [00:13<00:42,  3.12it/s]
#
# Dynamic Programming:  22%|██▏       | 37/170 [00:14<00:41,  3.18it/s]
#
# Dynamic Programming:  22%|██▏       | 38/170 [00:14<00:40,  3.25it/s]
#
# Dynamic Programming:  23%|██▎       | 39/170 [00:14<00:40,  3.25it/s]
#
# Dynamic Programming:  24%|██▎       | 40/170 [00:14<00:39,  3.32it/s]
#
# Dynamic Programming:  24%|██▍       | 41/170 [00:15<00:38,  3.39it/s]
#
# Dynamic Programming:  25%|██▍       | 42/170 [00:15<00:37,  3.38it/s]
#
# Dynamic Programming:  25%|██▌       | 43/170 [00:15<00:36,  3.45it/s]
#
# Dynamic Programming:  26%|██▌       | 44/170 [00:16<00:35,  3.53it/s]
#
# Dynamic Programming:  26%|██▋       | 45/170 [00:16<00:34,  3.59it/s]
#
# Dynamic Programming:  27%|██▋       | 46/170 [00:16<00:34,  3.57it/s]
#
# Dynamic Programming:  28%|██▊       | 47/170 [00:16<00:33,  3.65it/s]
#
# Dynamic Programming:  28%|██▊       | 48/170 [00:17<00:37,  3.28it/s]
#
# Dynamic Programming:  29%|██▉       | 49/170 [00:17<00:41,  2.89it/s]
#
# Dynamic Programming:  29%|██▉       | 50/170 [00:17<00:38,  3.15it/s]
#
# Dynamic Programming:  30%|███       | 51/170 [00:18<00:35,  3.39it/s]
#
# Dynamic Programming:  31%|███       | 52/170 [00:18<00:32,  3.59it/s]
#
# Dynamic Programming:  31%|███       | 53/170 [00:18<00:31,  3.67it/s]
#
# Dynamic Programming:  32%|███▏      | 54/170 [00:18<00:30,  3.82it/s]
#
# Dynamic Programming:  32%|███▏      | 55/170 [00:19<00:29,  3.96it/s]
#
# Dynamic Programming:  33%|███▎      | 56/170 [00:19<00:28,  4.07it/s]
#
# Dynamic Programming:  34%|███▎      | 57/170 [00:19<00:27,  4.05it/s]
#
# Dynamic Programming:  34%|███▍      | 58/170 [00:19<00:26,  4.17it/s]
#
# Dynamic Programming:  35%|███▍      | 59/170 [00:20<00:26,  4.26it/s]
#
# Dynamic Programming:  35%|███▌      | 60/170 [00:20<00:25,  4.35it/s]
#
# Dynamic Programming:  36%|███▌      | 61/170 [00:20<00:24,  4.44it/s]
#
# Dynamic Programming:  36%|███▋      | 62/170 [00:20<00:24,  4.44it/s]
#
# Dynamic Programming:  37%|███▋      | 63/170 [00:20<00:23,  4.55it/s]
#
# Dynamic Programming:  38%|███▊      | 64/170 [00:21<00:22,  4.65it/s]
#
# Dynamic Programming:  38%|███▊      | 65/170 [00:21<00:22,  4.74it/s]
#
# Dynamic Programming:  39%|███▉      | 66/170 [00:21<00:22,  4.67it/s]
#
# Dynamic Programming:  39%|███▉      | 67/170 [00:21<00:21,  4.79it/s]
#
# Dynamic Programming:  40%|████      | 68/170 [00:21<00:20,  4.90it/s]
#
# Dynamic Programming:  41%|████      | 69/170 [00:22<00:20,  4.99it/s]
#
# Dynamic Programming:  41%|████      | 70/170 [00:22<00:19,  5.08it/s]
#
# Dynamic Programming:  42%|████▏     | 71/170 [00:22<00:19,  5.17it/s]
#
# Dynamic Programming:  42%|████▏     | 72/170 [00:22<00:19,  5.10it/s]
#
# Dynamic Programming:  43%|████▎     | 73/170 [00:22<00:18,  5.24it/s]
#
# Dynamic Programming:  44%|████▎     | 74/170 [00:23<00:17,  5.36it/s]
#
# Dynamic Programming:  44%|████▍     | 75/170 [00:23<00:17,  5.48it/s]
#
# Dynamic Programming:  45%|████▍     | 76/170 [00:23<00:16,  5.58it/s]
#
# Dynamic Programming:  45%|████▌     | 77/170 [00:23<00:16,  5.50it/s]
#
# Dynamic Programming:  46%|████▌     | 78/170 [00:23<00:16,  5.68it/s]
#
# Dynamic Programming:  46%|████▋     | 79/170 [00:23<00:15,  5.84it/s]
#
# Dynamic Programming:  47%|████▋     | 80/170 [00:24<00:15,  5.98it/s]
#
# Dynamic Programming:  48%|████▊     | 81/170 [00:24<00:14,  6.13it/s]
#
# Dynamic Programming:  48%|████▊     | 82/170 [00:24<00:14,  6.26it/s]
#
# Dynamic Programming:  49%|████▉     | 83/170 [00:24<00:13,  6.38it/s]
#
# Dynamic Programming:  49%|████▉     | 84/170 [00:24<00:13,  6.28it/s]
#
# Dynamic Programming:  50%|█████     | 85/170 [00:24<00:13,  6.46it/s]
#
# Dynamic Programming:  51%|█████     | 86/170 [00:24<00:12,  6.62it/s]
#
# Dynamic Programming:  51%|█████     | 87/170 [00:25<00:12,  6.76it/s]
#
# Dynamic Programming:  52%|█████▏    | 88/170 [00:25<00:11,  6.91it/s]
#
# Dynamic Programming:  52%|█████▏    | 89/170 [00:25<00:11,  7.07it/s]
#
# Dynamic Programming:  53%|█████▎    | 90/170 [00:25<00:11,  7.21it/s]
#
# Dynamic Programming:  54%|█████▎    | 91/170 [00:25<00:11,  7.02it/s]
#
# Dynamic Programming:  54%|█████▍    | 92/170 [00:25<00:10,  7.25it/s]
#
# Dynamic Programming:  55%|█████▍    | 93/170 [00:25<00:10,  7.45it/s]
#
# Dynamic Programming:  55%|█████▌    | 94/170 [00:26<00:09,  7.62it/s]
#
# Dynamic Programming:  56%|█████▌    | 95/170 [00:26<00:09,  7.78it/s]
#
# Dynamic Programming:  56%|█████▋    | 96/170 [00:26<00:09,  7.93it/s]
#
# Dynamic Programming:  57%|█████▋    | 97/170 [00:26<00:09,  8.07it/s]
#
# Dynamic Programming:  58%|█████▊    | 98/170 [00:26<00:08,  8.22it/s]
#
# Dynamic Programming:  58%|█████▊    | 99/170 [00:26<00:08,  7.98it/s]
#
# Dynamic Programming:  59%|█████▉    | 100/170 [00:26<00:08,  8.28it/s]
#
# Dynamic Programming:  59%|█████▉    | 101/170 [00:26<00:08,  8.54it/s]
#
# Dynamic Programming:  60%|██████    | 102/170 [00:26<00:07,  8.78it/s]
#
# Dynamic Programming:  61%|██████    | 103/170 [00:27<00:07,  9.01it/s]
#
# Dynamic Programming:  61%|██████    | 104/170 [00:27<00:07,  9.27it/s]
#
# Dynamic Programming:  62%|██████▏   | 106/170 [00:27<00:06,  9.59it/s]
#
# Dynamic Programming:  64%|██████▎   | 108/170 [00:27<00:06,  9.93it/s]
#
# Dynamic Programming:  65%|██████▍   | 110/170 [00:27<00:06,  9.96it/s]
#
# Dynamic Programming:  66%|██████▌   | 112/170 [00:27<00:05, 10.43it/s]
#
# Dynamic Programming:  67%|██████▋   | 114/170 [00:28<00:05, 10.94it/s]
#
# Dynamic Programming:  68%|██████▊   | 116/170 [00:28<00:04, 11.46it/s]
#
# Dynamic Programming:  69%|██████▉   | 118/170 [00:28<00:04, 11.99it/s]
#
# Dynamic Programming:  71%|███████   | 120/170 [00:28<00:03, 12.54it/s]
#
# Dynamic Programming:  72%|███████▏  | 122/170 [00:28<00:03, 12.68it/s]
#
# Dynamic Programming:  73%|███████▎  | 124/170 [00:28<00:03, 13.47it/s]
#
# Dynamic Programming:  74%|███████▍  | 126/170 [00:28<00:03, 14.30it/s]
#
# Dynamic Programming:  75%|███████▌  | 128/170 [00:29<00:02, 15.24it/s]
#
# Dynamic Programming:  76%|███████▋  | 130/170 [00:29<00:02, 16.27it/s]
#
# Dynamic Programming:  78%|███████▊  | 133/170 [00:29<00:02, 17.47it/s]
#
# Dynamic Programming:  80%|████████  | 136/170 [00:29<00:01, 18.83it/s]
#
# Dynamic Programming:  82%|████████▏ | 139/170 [00:29<00:01, 20.65it/s]
#
# Dynamic Programming:  84%|████████▎ | 142/170 [00:29<00:01, 21.95it/s]
#
# Dynamic Programming:  86%|████████▌ | 146/170 [00:29<00:00, 25.08it/s]
#
# Dynamic Programming:  89%|████████▉ | 151/170 [00:29<00:00, 29.15it/s]
#
# Dynamic Programming: 100%|██████████| 170/170 [00:29<00:00,  5.67it/s]
#
#  97%|█████████▋| 84/87 [56:30<01:53, 37.89s/it]
#
# Dynamic Programming:   0%|          | 0/173 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/173 [00:00<01:21,  2.12it/s]
#
# Dynamic Programming:   1%|          | 2/173 [00:00<01:21,  2.09it/s]
#
# Dynamic Programming:   2%|▏         | 3/173 [00:01<01:21,  2.10it/s]
#
# Dynamic Programming:   2%|▏         | 4/173 [00:01<01:21,  2.08it/s]
#
# Dynamic Programming:   3%|▎         | 5/173 [00:02<01:19,  2.10it/s]
#
# Dynamic Programming:   3%|▎         | 6/173 [00:02<01:19,  2.10it/s]
#
# Dynamic Programming:   4%|▍         | 7/173 [00:03<01:18,  2.13it/s]
#
# Dynamic Programming:   5%|▍         | 8/173 [00:03<01:17,  2.13it/s]
#
# Dynamic Programming:   5%|▌         | 9/173 [00:04<01:15,  2.17it/s]
#
# Dynamic Programming:   6%|▌         | 10/173 [00:04<01:14,  2.18it/s]
#
# Dynamic Programming:   6%|▋         | 11/173 [00:05<01:13,  2.22it/s]
#
# Dynamic Programming:   7%|▋         | 12/173 [00:05<01:11,  2.25it/s]
#
# Dynamic Programming:   8%|▊         | 13/173 [00:05<01:10,  2.25it/s]
#
# Dynamic Programming:   8%|▊         | 14/173 [00:06<01:15,  2.09it/s]
#
# Dynamic Programming:   9%|▊         | 15/173 [00:07<01:19,  1.98it/s]
#
# Dynamic Programming:   9%|▉         | 16/173 [00:07<01:14,  2.10it/s]
#
# Dynamic Programming:  10%|▉         | 17/173 [00:07<01:11,  2.19it/s]
#
# Dynamic Programming:  10%|█         | 18/173 [00:08<01:08,  2.27it/s]
#
# Dynamic Programming:  11%|█         | 19/173 [00:08<01:06,  2.31it/s]
#
# Dynamic Programming:  12%|█▏        | 20/173 [00:09<01:04,  2.38it/s]
#
# Dynamic Programming:  12%|█▏        | 21/173 [00:09<01:02,  2.45it/s]
#
# Dynamic Programming:  13%|█▎        | 22/173 [00:09<01:01,  2.46it/s]
#
# Dynamic Programming:  13%|█▎        | 23/173 [00:10<00:59,  2.53it/s]
# Dynamic Programming:  34%|███▍      | 59/173 [00:21<00:28,  4.06it/s]
#
# Dynamic Programming:  35%|███▍      | 60/173 [00:21<00:27,  4.17it/s]
#
# Dynamic Programming:  35%|███▌      | 61/173 [00:21<00:26,  4.26it/s]
#
# Dynamic Programming:  36%|███▌      | 62/173 [00:21<00:26,  4.23it/s]
#
# Dynamic Programming:  36%|███▋      | 63/173 [00:22<00:25,  4.33it/s]
#
# Dynamic Programming:  37%|███▋      | 64/173 [00:22<00:24,  4.44it/s]
#
# Dynamic Programming:  38%|███▊      | 65/173 [00:22<00:23,  4.53it/s]
#
# Dynamic Programming:  38%|███▊      | 66/173 [00:22<00:23,  4.60it/s]
#
# Dynamic Programming:  39%|███▊      | 67/173 [00:22<00:23,  4.53it/s]
#
# Dynamic Programming:  39%|███▉      | 68/173 [00:23<00:22,  4.64it/s]
#
# Dynamic Programming:  40%|███▉      | 69/173 [00:23<00:21,  4.73it/s]
#
# Dynamic Programming:  40%|████      | 70/173 [00:23<00:21,  4.81it/s]
#
# Dynamic Programming:  41%|████      | 71/173 [00:23<00:20,  4.89it/s]
#
# Dynamic Programming:  42%|████▏     | 72/173 [00:23<00:20,  4.82it/s]
#
# Dynamic Programming:  42%|████▏     | 73/173 [00:24<00:20,  4.93it/s]
#
# Dynamic Programming:  43%|████▎     | 74/173 [00:24<00:19,  5.06it/s]
#
# Dynamic Programming:  43%|████▎     | 75/173 [00:24<00:18,  5.18it/s]
#
# Dynamic Programming:  44%|████▍     | 76/173 [00:24<00:18,  5.28it/s]
#
# Dynamic Programming:  45%|████▍     | 77/173 [00:24<00:18,  5.20it/s]
#
# Dynamic Programming:  45%|████▌     | 78/173 [00:25<00:17,  5.33it/s]
#
# Dynamic Programming:  46%|████▌     | 79/173 [00:25<00:17,  5.46it/s]
#
# Dynamic Programming:  46%|████▌     | 80/173 [00:25<00:16,  5.58it/s]
#
# Dynamic Programming:  47%|████▋     | 81/173 [00:25<00:16,  5.63it/s]
#
# Dynamic Programming:  47%|████▋     | 82/173 [00:25<00:15,  5.75it/s]
#
# Dynamic Programming:  48%|████▊     | 83/173 [00:25<00:15,  5.65it/s]
#
# Dynamic Programming:  49%|████▊     | 84/173 [00:26<00:15,  5.78it/s]

# %%
detRessCtrl_comU = []
for ix in trange(len(canptssCtrl_comU)):
    res = EGenDy(ResCtrl_comU.ndXmats[ix], ResCtrl_comU.nXmats[ix], paras.kappa, Lmin=paras.Lmin, 
          canpts=canptssCtrl_comU[ix], MaxM=paras.MaxM, is_full=True, 
          showProgress=True)
    detRessCtrl_comU.append(res)
# Out:
# Dynamic Programming:  54%|█████▎    | 98/183 [00:30<00:13,  6.37it/s]
#
# Dynamic Programming:  54%|█████▍    | 99/183 [00:31<00:12,  6.54it/s]
#
# Dynamic Programming:  55%|█████▍    | 100/183 [00:31<00:12,  6.72it/s]
#
# Dynamic Programming:  55%|█████▌    | 101/183 [00:31<00:11,  6.91it/s]
#
# Dynamic Programming:  56%|█████▌    | 102/183 [00:31<00:11,  7.09it/s]
#
# Dynamic Programming:  56%|█████▋    | 103/183 [00:31<00:11,  7.25it/s]
#
# Dynamic Programming:  57%|█████▋    | 104/183 [00:31<00:11,  7.07it/s]
#
# Dynamic Programming:  57%|█████▋    | 105/183 [00:31<00:10,  7.32it/s]
#
# Dynamic Programming:  58%|█████▊    | 106/183 [00:32<00:10,  7.53it/s]
#
# Dynamic Programming:  58%|█████▊    | 107/183 [00:32<00:09,  7.72it/s]
#
# Dynamic Programming:  59%|█████▉    | 108/183 [00:32<00:09,  7.90it/s]
#
# Dynamic Programming:  60%|█████▉    | 109/183 [00:32<00:09,  8.06it/s]
#
# Dynamic Programming:  60%|██████    | 110/183 [00:32<00:08,  8.23it/s]
#
# Dynamic Programming:  61%|██████    | 111/183 [00:32<00:08,  8.39it/s]
#
# Dynamic Programming:  61%|██████    | 112/183 [00:32<00:08,  8.13it/s]
#
# Dynamic Programming:  62%|██████▏   | 113/183 [00:32<00:08,  8.41it/s]
#
# Dynamic Programming:  62%|██████▏   | 114/183 [00:32<00:07,  8.70it/s]
#
# Dynamic Programming:  63%|██████▎   | 115/183 [00:33<00:07,  8.97it/s]
#
# Dynamic Programming:  63%|██████▎   | 116/183 [00:33<00:07,  9.21it/s]
#
# Dynamic Programming:  64%|██████▍   | 117/183 [00:33<00:07,  9.42it/s]
#
# Dynamic Programming:  65%|██████▌   | 119/183 [00:33<00:06,  9.68it/s]
#
# Dynamic Programming:  66%|██████▌   | 121/183 [00:33<00:06, 10.07it/s]
#
# Dynamic Programming:  67%|██████▋   | 123/183 [00:33<00:05, 10.36it/s]
#
# Dynamic Programming:  68%|██████▊   | 125/183 [00:33<00:05, 10.93it/s]
#
# Dynamic Programming:  69%|██████▉   | 127/183 [00:34<00:04, 11.49it/s]
#
# Dynamic Programming:  70%|███████   | 129/183 [00:34<00:04, 12.07it/s]
#
# Dynamic Programming:  72%|███████▏  | 131/183 [00:34<00:04, 12.70it/s]
#
# Dynamic Programming:  73%|███████▎  | 133/183 [00:34<00:03, 13.42it/s]
#
# Dynamic Programming:  74%|███████▍  | 135/183 [00:34<00:03, 14.27it/s]
#
# Dynamic Programming:  75%|███████▍  | 137/183 [00:34<00:03, 14.43it/s]
#
# Dynamic Programming:  76%|███████▌  | 139/183 [00:34<00:02, 15.46it/s]
#
# Dynamic Programming:  78%|███████▊  | 142/183 [00:35<00:02, 16.71it/s]
#
# Dynamic Programming:  79%|███████▉  | 145/183 [00:35<00:02, 18.18it/s]
#
# Dynamic Programming:  81%|████████  | 148/183 [00:35<00:01, 19.88it/s]
#
# Dynamic Programming:  83%|████████▎ | 151/183 [00:35<00:01, 21.91it/s]
#
# Dynamic Programming:  85%|████████▍ | 155/183 [00:35<00:01, 24.58it/s]
#
# Dynamic Programming:  87%|████████▋ | 160/183 [00:35<00:00, 28.19it/s]
#
# Dynamic Programming: 100%|██████████| 183/183 [00:35<00:00,  5.11it/s]
#
#   1%|▏         | 1/70 [00:35<41:12, 35.84s/it]
#
# Dynamic Programming:   0%|          | 0/196 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/196 [00:00<01:44,  1.86it/s]
#
# Dynamic Programming:   1%|          | 2/196 [00:01<01:45,  1.84it/s]
#
# Dynamic Programming:   2%|▏         | 3/196 [00:01<01:44,  1.85it/s]
#
# Dynamic Programming:   2%|▏         | 4/196 [00:02<01:44,  1.84it/s]
#
# Dynamic Programming:   3%|▎         | 5/196 [00:02<01:42,  1.86it/s]
#
# Dynamic Programming:   3%|▎         | 6/196 [00:03<01:41,  1.87it/s]
#
# Dynamic Programming:   4%|▎         | 7/196 [00:03<01:39,  1.89it/s]
#
# Dynamic Programming:   4%|▍         | 8/196 [00:04<01:39,  1.89it/s]
#
# Dynamic Programming:   5%|▍         | 9/196 [00:04<01:37,  1.92it/s]
#
# Dynamic Programming:   5%|▌         | 10/196 [00:05<01:37,  1.91it/s]
#
# Dynamic Programming:   6%|▌         | 11/196 [00:05<01:35,  1.94it/s]
#
# Dynamic Programming:   6%|▌         | 12/196 [00:06<01:34,  1.94it/s]
#
# Dynamic Programming:   7%|▋         | 13/196 [00:06<01:32,  1.97it/s]
#
# Dynamic Programming:   7%|▋         | 14/196 [00:07<01:32,  1.98it/s]
#
# Dynamic Programming:   8%|▊         | 15/196 [00:07<01:30,  2.01it/s]
#
# Dynamic Programming:   8%|▊         | 16/196 [00:08<01:29,  2.01it/s]
#
# Dynamic Programming:   9%|▊         | 17/196 [00:08<01:27,  2.05it/s]
#
# Dynamic Programming:   9%|▉         | 18/196 [00:09<01:26,  2.06it/s]
#
# Dynamic Programming:  10%|▉         | 19/196 [00:09<01:24,  2.09it/s]
#
# Dynamic Programming:  10%|█         | 20/196 [00:10<01:23,  2.10it/s]
#
# Dynamic Programming:  11%|█         | 21/196 [00:10<01:21,  2.13it/s]
#
# Dynamic Programming:  11%|█         | 22/196 [00:11<01:20,  2.15it/s]
#
# Dynamic Programming:  12%|█▏        | 23/196 [00:11<01:19,  2.18it/s]
#
# Dynamic Programming:  12%|█▏        | 24/196 [00:11<01:17,  2.22it/s]
#
# Dynamic Programming:  13%|█▎        | 25/196 [00:12<01:17,  2.22it/s]
#
# Dynamic Programming:  13%|█▎        | 26/196 [00:12<01:15,  2.25it/s]
#
# Dynamic Programming:  14%|█▍        | 27/196 [00:13<01:15,  2.25it/s]
#
# Dynamic Programming:  14%|█▍        | 28/196 [00:13<01:13,  2.29it/s]
#
# Dynamic Programming:  15%|█▍        | 29/196 [00:14<01:12,  2.29it/s]
#
# Dynamic Programming:  15%|█▌        | 30/196 [00:14<01:11,  2.34it/s]
#
# Dynamic Programming:  16%|█▌        | 31/196 [00:14<01:09,  2.39it/s]
#
# Dynamic Programming:  16%|█▋        | 32/196 [00:15<01:08,  2.40it/s]
#
# Dynamic Programming:  17%|█▋        | 33/196 [00:15<01:06,  2.45it/s]
#
# Dynamic Programming:  17%|█▋        | 34/196 [00:16<01:06,  2.44it/s]
#
# Dynamic Programming:  18%|█▊        | 35/196 [00:16<01:04,  2.49it/s]
#
# Dynamic Programming:  18%|█▊        | 36/196 [00:16<01:02,  2.54it/s]
#
# Dynamic Programming:  19%|█▉        | 37/196 [00:17<01:02,  2.54it/s]
#
# Dynamic Programming:  19%|█▉        | 38/196 [00:17<01:01,  2.59it/s]
#
# Dynamic Programming:  20%|█▉        | 39/196 [00:18<00:59,  2.64it/s]
#
# Dynamic Programming:  20%|██        | 40/196 [00:18<00:59,  2.64it/s]
#
# Dynamic Programming:  21%|██        | 41/196 [00:18<00:57,  2.69it/s]
#
# Dynamic Programming:  21%|██▏       | 42/196 [00:19<00:56,  2.74it/s]
#
# Dynamic Programming:  22%|██▏       | 43/196 [00:19<00:55,  2.78it/s]
#
# Dynamic Programming:  22%|██▏       | 44/196 [00:19<00:53,  2.82it/s]
#
# Dynamic Programming:  23%|██▎       | 45/196 [00:20<00:53,  2.81it/s]
#
# Dynamic Programming:  23%|██▎       | 46/196 [00:20<00:52,  2.86it/s]
#
# Dynamic Programming:  24%|██▍       | 47/196 [00:20<00:51,  2.90it/s]
#
# Dynamic Programming:  24%|██▍       | 48/196 [00:21<00:51,  2.89it/s]
#
# Dynamic Programming:  25%|██▌       | 49/196 [00:21<00:49,  2.95it/s]
#
# Dynamic Programming:  26%|██▌       | 50/196 [00:21<00:48,  2.99it/s]
#
# Dynamic Programming:  26%|██▌       | 51/196 [00:22<00:47,  3.03it/s]
#
# Dynamic Programming:  27%|██▋       | 52/196 [00:22<00:47,  3.02it/s]
#
# Dynamic Programming:  27%|██▋       | 53/196 [00:22<00:46,  3.07it/s]
#
# Dynamic Programming:  28%|██▊       | 54/196 [00:23<00:45,  3.12it/s]
#
# Dynamic Programming:  28%|██▊       | 55/196 [00:23<00:45,  3.12it/s]
#
# Dynamic Programming:  29%|██▊       | 56/196 [00:23<00:43,  3.19it/s]
#
# Dynamic Programming:  29%|██▉       | 57/196 [00:24<00:42,  3.25it/s]
#
# Dynamic Programming:  30%|██▉       | 58/196 [00:24<00:42,  3.24it/s]
#
# Dynamic Programming:  30%|███       | 59/196 [00:24<00:41,  3.31it/s]
#
# Dynamic Programming:  31%|███       | 60/196 [00:24<00:40,  3.38it/s]
#
# Dynamic Programming:  31%|███       | 61/196 [00:25<00:39,  3.44it/s]
#
# Dynamic Programming:  32%|███▏      | 62/196 [00:25<00:39,  3.41it/s]
#
# Dynamic Programming:  32%|███▏      | 63/196 [00:25<00:38,  3.49it/s]
#
# Dynamic Programming:  33%|███▎      | 64/196 [00:26<00:37,  3.55it/s]
#
# Dynamic Programming:  33%|███▎      | 65/196 [00:26<00:37,  3.53it/s]
#
# Dynamic Programming:  34%|███▎      | 66/196 [00:26<00:36,  3.61it/s]
#
# Dynamic Programming:  34%|███▍      | 67/196 [00:26<00:35,  3.68it/s]
#
# Dynamic Programming:  35%|███▍      | 68/196 [00:27<00:34,  3.74it/s]
#
# Dynamic Programming:  35%|███▌      | 69/196 [00:27<00:34,  3.71it/s]
#
# Dynamic Programming:  36%|███▌      | 70/196 [00:27<00:33,  3.80it/s]
#
# Dynamic Programming:  36%|███▌      | 71/196 [00:27<00:32,  3.87it/s]
#
# Dynamic Programming:  37%|███▋      | 72/196 [00:28<00:31,  3.94it/s]
#
# Dynamic Programming:  37%|███▋      | 73/196 [00:28<00:31,  3.90it/s]
#
# Dynamic Programming:  38%|███▊      | 74/196 [00:28<00:30,  3.99it/s]
#
# Dynamic Programming:  38%|███▊      | 75/196 [00:28<00:29,  4.06it/s]
#
# Dynamic Programming:  39%|███▉      | 76/196 [00:29<00:29,  4.13it/s]
#
# Dynamic Programming:  39%|███▉      | 77/196 [00:29<00:29,  4.08it/s]
#
# Dynamic Programming:  40%|███▉      | 78/196 [00:29<00:28,  4.17it/s]
#
# Dynamic Programming:  40%|████      | 79/196 [00:29<00:27,  4.25it/s]
#
# Dynamic Programming:  41%|████      | 80/196 [00:29<00:26,  4.33it/s]
#
# Dynamic Programming:  41%|████▏     | 81/196 [00:30<00:26,  4.41it/s]
#
# Dynamic Programming:  42%|████▏     | 82/196 [00:30<00:25,  4.41it/s]
#
# Dynamic Programming:  42%|████▏     | 83/196 [00:30<00:25,  4.51it/s]
#
# Dynamic Programming:  43%|████▎     | 84/196 [00:30<00:24,  4.60it/s]
#
# Dynamic Programming:  43%|████▎     | 85/196 [00:31<00:23,  4.69it/s]
#
# Dynamic Programming:  44%|████▍     | 86/196 [00:31<00:23,  4.77it/s]
#
# Dynamic Programming:  44%|████▍     | 87/196 [00:31<00:23,  4.74it/s]
#
# Dynamic Programming:  45%|████▍     | 88/196 [00:31<00:22,  4.86it/s]
#
# Dynamic Programming:  45%|████▌     | 89/196 [00:31<00:21,  4.89it/s]
#
# Dynamic Programming:  46%|████▌     | 90/196 [00:32<00:21,  5.00it/s]
#
# Dynamic Programming:  46%|████▋     | 91/196 [00:32<00:20,  5.11it/s]
#
# Dynamic Programming:  47%|████▋     | 92/196 [00:32<00:20,  5.04it/s]
#
# Dynamic Programming:  47%|████▋     | 93/196 [00:32<00:19,  5.18it/s]
#
# Dynamic Programming:  48%|████▊     | 94/196 [00:32<00:19,  5.30it/s]
#
# Dynamic Programming:  48%|████▊     | 95/196 [00:32<00:18,  5.41it/s]
#
# Dynamic Programming:  49%|████▉     | 96/196 [00:33<00:18,  5.52it/s]
#
# Dynamic Programming:  49%|████▉     | 97/196 [00:33<00:18,  5.46it/s]
#
# Dynamic Programming:  50%|█████     | 98/196 [00:33<00:17,  5.60it/s]
#
# Dynamic Programming:  51%|█████     | 99/196 [00:33<00:16,  5.73it/s]
#
# Dynamic Programming:  51%|█████     | 100/196 [00:33<00:16,  5.86it/s]
#
# Dynamic Programming:  52%|█████▏    | 101/196 [00:33<00:15,  5.97it/s]
#
# Dynamic Programming:  52%|█████▏    | 102/196 [00:34<00:15,  6.09it/s]
#
# Dynamic Programming:  53%|█████▎    | 103/196 [00:34<00:15,  6.11it/s]
#
# Dynamic Programming:  53%|█████▎    | 104/196 [00:34<00:14,  6.23it/s]
#
# Dynamic Programming:  54%|█████▎    | 105/196 [00:34<00:14,  6.36it/s]
#
# Dynamic Programming:  54%|█████▍    | 106/196 [00:34<00:13,  6.49it/s]
#
# Dynamic Programming:  55%|█████▍    | 107/196 [00:34<00:13,  6.62it/s]
#
# Dynamic Programming:  55%|█████▌    | 108/196 [00:35<00:13,  6.74it/s]
#
# Dynamic Programming:  56%|█████▌    | 109/196 [00:35<00:12,  6.86it/s]
#
# Dynamic Programming:  56%|█████▌    | 110/196 [00:35<00:12,  6.87it/s]
#
# Dynamic Programming:  57%|█████▋    | 111/196 [00:35<00:12,  6.94it/s]
#
# Dynamic Programming:  57%|█████▋    | 112/196 [00:35<00:11,  7.10it/s]
#
# Dynamic Programming:  58%|█████▊    | 113/196 [00:35<00:11,  7.27it/s]
#
# Dynamic Programming:  58%|█████▊    | 114/196 [00:35<00:11,  7.43it/s]
#
# Dynamic Programming:  59%|█████▊    | 115/196 [00:35<00:10,  7.58it/s]
#
# Dynamic Programming:  59%|█████▉    | 116/196 [00:36<00:10,  7.73it/s]
#
# Dynamic Programming:  60%|█████▉    | 117/196 [00:36<00:10,  7.88it/s]
#
# Dynamic Programming:  60%|██████    | 118/196 [00:36<00:10,  7.76it/s]
#
# Dynamic Programming:  61%|██████    | 119/196 [00:36<00:09,  7.84it/s]
#
# Dynamic Programming:  61%|██████    | 120/196 [00:36<00:09,  8.09it/s]
#
# Dynamic Programming:  62%|██████▏   | 121/196 [00:36<00:09,  8.33it/s]
#
# Dynamic Programming:  62%|██████▏   | 122/196 [00:36<00:08,  8.55it/s]
#
# Dynamic Programming:  63%|██████▎   | 123/196 [00:36<00:08,  8.77it/s]
#
# Dynamic Programming:  63%|██████▎   | 124/196 [00:37<00:08,  8.98it/s]
#
# Dynamic Programming:  64%|██████▍   | 125/196 [00:37<00:07,  9.18it/s]
#
# Dynamic Programming:  64%|██████▍   | 126/196 [00:37<00:07,  9.39it/s]
#
# Dynamic Programming:  65%|██████▍   | 127/196 [00:37<00:07,  9.04it/s]
#
# Dynamic Programming:  66%|██████▌   | 129/196 [00:37<00:07,  9.44it/s]
#
# Dynamic Programming:  67%|██████▋   | 131/196 [00:37<00:06,  9.87it/s]
#
# Dynamic Programming:  68%|██████▊   | 133/196 [00:37<00:06, 10.32it/s]
#
# Dynamic Programming:  69%|██████▉   | 135/196 [00:38<00:05, 10.79it/s]
#
# Dynamic Programming:  70%|██████▉   | 137/196 [00:38<00:05, 11.32it/s]
#
# Dynamic Programming:  71%|███████   | 139/196 [00:38<00:04, 11.42it/s]
#
# Dynamic Programming:  72%|███████▏  | 141/196 [00:38<00:04, 12.09it/s]
#
# Dynamic Programming:  73%|███████▎  | 143/196 [00:38<00:04, 12.81it/s]
#
# Dynamic Programming:  74%|███████▍  | 145/196 [00:38<00:03, 13.55it/s]
#
# Dynamic Programming:  75%|███████▌  | 147/196 [00:38<00:03, 14.32it/s]
#
# Dynamic Programming:  76%|███████▌  | 149/196 [00:39<00:03, 15.07it/s]
#
# Dynamic Programming:  77%|███████▋  | 151/196 [00:39<00:02, 15.89it/s]
#
# Dynamic Programming:  78%|███████▊  | 153/196 [00:39<00:02, 16.76it/s]
#
# Dynamic Programming:  80%|███████▉  | 156/196 [00:39<00:02, 17.17it/s]
#
# Dynamic Programming:  81%|████████  | 159/196 [00:39<00:01, 18.64it/s]
#
# Dynamic Programming:  83%|████████▎ | 162/196 [00:39<00:01, 20.56it/s]
#
# Dynamic Programming:  85%|████████▍ | 166/196 [00:39<00:01, 22.89it/s]
#
# Dynamic Programming:  87%|████████▋ | 170/196 [00:39<00:01, 25.89it/s]
#
# Dynamic Programming:  89%|████████▉ | 175/196 [00:39<00:00, 29.94it/s]
#
# Dynamic Programming: 100%|██████████| 196/196 [00:40<00:00,  4.88it/s]
#
#   3%|▎         | 2/70 [01:16<42:05, 37.14s/it]
#
# Dynamic Programming:   0%|          | 0/187 [00:00<?, ?it/s]
#
# Dynamic Programming:   1%|          | 1/187 [00:00<01:36,  1.92it/s]
#
# Dynamic Programming:   1%|          | 2/187 [00:01<01:35,  1.94it/s]
#
# Dynamic Programming:   2%|▏         | 3/187 [00:01<01:35,  1.93it/s]
#
# Dynamic Programming:   2%|▏         | 4/187 [00:02<01:33,  1.96it/s]
#
# Dynamic Programming:   3%|▎         | 5/187 [00:02<01:32,  1.96it/s]
#
# Dynamic Programming:   3%|▎         | 6/187 [00:03<01:31,  1.99it/s]
#
# Dynamic Programming:   4%|▎         | 7/187 [00:03<01:30,  1.99it/s]
#
# Dynamic Programming:   4%|▍         | 8/187 [00:04<01:28,  2.02it/s]
#
# Dynamic Programming:   5%|▍         | 9/187 [00:04<01:28,  2.02it/s]
#
# Dynamic Programming:   5%|▌         | 10/187 [00:04<01:26,  2.05it/s]
#
# Dynamic Programming:   6%|▌         | 11/187 [00:05<01:25,  2.05it/s]
#
# Dynamic Programming:   6%|▋         | 12/187 [00:05<01:23,  2.09it/s]
#
# Dynamic Programming:   7%|▋         | 13/187 [00:06<01:22,  2.10it/s]
#
# Dynamic Programming:   7%|▋         | 14/187 [00:06<01:20,  2.14it/s]
#
# Dynamic Programming:   8%|▊         | 15/187 [00:07<01:20,  2.14it/s]
#
# Dynamic Programming:   9%|▊         | 16/187 [00:07<01:18,  2.18it/s]
#
# Dynamic Programming:   9%|▉         | 17/187 [00:08<01:16,  2.21it/s]
#
# Dynamic Programming:  10%|▉         | 18/187 [00:08<01:16,  2.21it/s]
#
# Dynamic Programming:  10%|█         | 19/187 [00:09<01:14,  2.25it/s]
#
# Dynamic Programming:  11%|█         | 20/187 [00:09<01:14,  2.25it/s]
#
# Dynamic Programming:  11%|█         | 21/187 [00:09<01:12,  2.29it/s]
#
# Dynamic Programming:  12%|█▏        | 22/187 [00:10<01:11,  2.29it/s]
#
# Dynamic Programming:  12%|█▏        | 23/187 [00:10<01:10,  2.33it/s]
# Dynamic Programming:  13%|█▎        | 24/187 [00:11<01:08,  2.37it/s]
#
# Dynamic Programming:  13%|█▎        | 25/187 [00:11<01:07,  2.38it/s]
#
# Dynamic Programming:  14%|█▍        | 26/187 [00:11<01:06,  2.42it/s]
#
# Dynamic Programming:  14%|█▍        | 27/187 [00:12<01:06,  2.42it/s]
#
# Dynamic Programming:  15%|█▍        | 28/187 [00:12<01:04,  2.46it/s]
#
# Dynamic Programming:  16%|█▌        | 29/187 [00:13<01:03,  2.49it/s]
#
# Dynamic Programming:  16%|█▌        | 30/187 [00:13<01:03,  2.48it/s]
#
# Dynamic Programming:  17%|█▋        | 31/187 [00:13<01:01,  2.53it/s]
#
# Dynamic Programming:  17%|█▋        | 32/187 [00:14<01:01,  2.53it/s]
#
# Dynamic Programming:  18%|█▊        | 33/187 [00:14<00:59,  2.58it/s]
#
# Dynamic Programming:  18%|█▊        | 34/187 [00:15<00:58,  2.63it/s]
#
# Dynamic Programming:  19%|█▊        | 35/187 [00:15<00:57,  2.63it/s]
#
# Dynamic Programming:  19%|█▉        | 36/187 [00:15<00:56,  2.69it/s]
#
# Dynamic Programming:  20%|█▉        | 37/187 [00:16<00:54,  2.74it/s]
#
# Dynamic Programming:  20%|██        | 38/187 [00:16<00:54,  2.75it/s]
#
# Dynamic Programming:  21%|██        | 39/187 [00:16<00:52,  2.80it/s]
#
# Dynamic Programming:  21%|██▏       | 40/187 [00:17<00:51,  2.85it/s]
#
# Dynamic Programming:  22%|██▏       | 41/187 [00:17<00:51,  2.85it/s]
#
# Dynamic Programming:  22%|██▏       | 42/187 [00:17<00:50,  2.90it/s]
#
# Dynamic Programming:  23%|██▎       | 43/187 [00:18<00:48,  2.95it/s]
#
# Dynamic Programming:  24%|██▎       | 44/187 [00:18<00:48,  2.94it/s]
#
# Dynamic Programming:  24%|██▍       | 45/187 [00:18<00:47,  3.00it/s]
#
# Dynamic Programming:  25%|██▍       | 46/187 [00:19<00:46,  3.04it/s]
#
# Dynamic Programming:  25%|██▌       | 47/187 [00:19<00:46,  3.04it/s]
#
# Dynamic Programming:  26%|██▌       | 48/187 [00:19<00:44,  3.10it/s]
#
# Dynamic Programming:  26%|██▌       | 49/187 [00:20<00:43,  3.15it/s]
#
# Dynamic Programming:  27%|██▋       | 50/187 [00:20<00:43,  3.14it/s]
#
# Dynamic Programming:  27%|██▋       | 51/187 [00:20<00:42,  3.20it/s]
#
# Dynamic Programming:  28%|██▊       | 52/187 [00:21<00:41,  3.26it/s]
#
# Dynamic Programming:  28%|██▊       | 53/187 [00:21<00:40,  3.31it/s]
#
# Dynamic Programming:  29%|██▉       | 54/187 [00:21<00:40,  3.29it/s]
#
# Dynamic Programming:  29%|██▉       | 55/187 [00:21<00:39,  3.35it/s]
#
# Dynamic Programming:  30%|██▉       | 56/187 [00:22<00:38,  3.41it/s]
#
# Dynamic Programming:  30%|███       | 57/187 [00:22<00:38,  3.42it/s]
#
# Dynamic Programming:  31%|███       | 58/187 [00:22<00:37,  3.48it/s]
#
# Dynamic Programming:  32%|███▏      | 59/187 [00:23<00:35,  3.56it/s]
#
# Dynamic Programming:  32%|███▏      | 60/187 [00:23<00:34,  3.63it/s]
#
# Dynamic Programming:  33%|███▎      | 61/187 [00:23<00:34,  3.62it/s]
#
# Dynamic Programming:  33%|███▎      | 62/187 [00:23<00:33,  3.70it/s]
#
# Dynamic Programming:  34%|███▎      | 63/187 [00:24<00:32,  3.76it/s]
#
# Dynamic Programming:  34%|███▍      | 64/187 [00:24<00:32,  3.83it/s]
#
# Dynamic Programming:  35%|███▍      | 65/187 [00:24<00:32,  3.81it/s]
#
# Dynamic Programming:  35%|███▌      | 66/187 [00:24<00:31,  3.89it/s]
#
# Dynamic Programming:  36%|███▌      | 67/187 [00:25<00:30,  3.93it/s]
#
# Dynamic Programming:  36%|███▋      | 68/187 [00:25<00:29,  4.01it/s]
#
# Dynamic Programming:  37%|███▋      | 69/187 [00:25<00:29,  3.97it/s]
#
# Dynamic Programming:  37%|███▋      | 70/187 [00:25<00:28,  4.05it/s]
#
# Dynamic Programming:  38%|███▊      | 71/187 [00:26<00:28,  4.13it/s]
#
# Dynamic Programming:  39%|███▊      | 72/187 [00:26<00:27,  4.22it/s]
#
# Dynamic Programming:  39%|███▉      | 73/187 [00:26<00:27,  4.19it/s]
#
# Dynamic Programming:  40%|███▉      | 74/187 [00:26<00:26,  4.29it/s]
#
# Dynamic Programming:  40%|████      | 75/187 [00:26<00:25,  4.38it/s]
#
# Dynamic Programming:  41%|████      | 76/187 [00:27<00:24,  4.46it/s]
#
# Dynamic Programming:  41%|████      | 77/187 [00:27<00:24,  4.54it/s]
#
# Dynamic Programming:  42%|████▏     | 78/187 [00:27<00:23,  4.56it/s]
#
# Dynamic Programming:  42%|████▏     | 79/187 [00:27<00:23,  4.65it/s]
#
# Dynamic Programming:  43%|████▎     | 80/187 [00:28<00:22,  4.73it/s]
#
# Dynamic Programming:  43%|████▎     | 81/187 [00:28<00:22,  4.81it/s]
#
# Dynamic Programming:  44%|████▍     | 82/187 [00:28<00:21,  4.89it/s]
#
# Dynamic Programming:  44%|████▍     | 83/187 [00:28<00:21,  4.81it/s]
#
# Dynamic Programming:  45%|████▍     | 84/187 [00:28<00:20,  4.93it/s]
#
# Dynamic Programming:  45%|████▌     | 85/187 [00:29<00:20,  5.03it/s]
#
# Dynamic Programming:  46%|████▌     | 86/187 [00:29<00:19,  5.13it/s]
#
# Dynamic Programming:  47%|████▋     | 87/187 [00:29<00:19,  5.22it/s]
#
# Dynamic Programming:  47%|████▋     | 88/187 [00:29<00:19,  5.14it/s]
#
# Dynamic Programming:  48%|████▊     | 89/187 [00:29<00:18,  5.27it/s]
#
# Dynamic Programming:  48%|████▊     | 90/187 [00:29<00:17,  5.39it/s]
#
# Dynamic Programming:  49%|████▊     | 91/187 [00:30<00:17,  5.50it/s]
#
# Dynamic Programming:  49%|████▉     | 92/187 [00:30<00:16,  5.61it/s]
#
# Dynamic Programming:  50%|████▉     | 93/187 [00:30<00:16,  5.71it/s]
#
# Dynamic Programming:  50%|█████     | 94/187 [00:30<00:16,  5.60it/s]
#
# Dynamic Programming:  51%|█████     | 95/187 [00:30<00:16,  5.75it/s]
#
# Dynamic Programming:  51%|█████▏    | 96/187 [00:30<00:15,  5.89it/s]
#
# Dynamic Programming:  52%|█████▏    | 97/187 [00:31<00:14,  6.02it/s]
#
# Dynamic Programming:  52%|█████▏    | 98/187 [00:31<00:14,  6.14it/s]
#
# Dynamic Programming:  53%|█████▎    | 99/187 [00:31<00:14,  6.26it/s]
#
# Dynamic Programming:  53%|█████▎    | 100/187 [00:31<00:14,  6.12it/s]
#
# Dynamic Programming:  54%|█████▍    | 101/187 [00:31<00:13,  6.30it/s]
#
# Dynamic Programming:  55%|█████▍    | 102/187 [00:31<00:13,  6.46it/s]
#
# Dynamic Programming:  55%|█████▌    | 103/187 [00:32<00:12,  6.61it/s]
#
# Dynamic Programming:  56%|█████▌    | 104/187 [00:32<00:12,  6.75it/s]
#
# Dynamic Programming:  56%|█████▌    | 105/187 [00:32<00:11,  6.88it/s]
#
# Dynamic Programming:  57%|█████▋    | 106/187 [00:32<00:11,  7.01it/s]
#
# Dynamic Programming:  57%|█████▋    | 107/187 [00:32<00:11,  6.87it/s]
#
# Dynamic Programming:  58%|█████▊    | 108/187 [00:32<00:11,  7.10it/s]
#
# Dynamic Programming:  58%|█████▊    | 109/187 [00:32<00:10,  7.30it/s]
#
# Dynamic Programming:  59%|█████▉    | 110/187 [00:33<00:10,  7.48it/s]
#
# Dynamic Programming:  59%|█████▉    | 111/187 [00:33<00:09,  7.65it/s]
#
# Dynamic Programming:  60%|█████▉    | 112/187 [00:33<00:09,  7.83it/s]
#
# Dynamic Programming:  60%|██████    | 113/187 [00:33<00:09,  7.98it/s]
#
# Dynamic Programming:  61%|██████    | 114/187 [00:33<00:08,  8.21it/s]
#
# Dynamic Programming:  61%|██████▏   | 115/187 [00:33<00:09,  7.99it/s]
#
# Dynamic Programming:  62%|██████▏   | 116/187 [00:33<00:08,  8.29it/s]
#
# Dynamic Programming:  63%|██████▎   | 117/187 [00:33<00:08,  8.55it/s]
#
# Dynamic Programming:  63%|██████▎   | 118/187 [00:33<00:07,  8.79it/s]
#
# Dynamic Programming:  64%|██████▎   | 119/187 [00:34<00:07,  9.01it/s]
#
# Dynamic Programming:  64%|██████▍   | 120/187 [00:34<00:07,  9.29it/s]
#
# Dynamic Programming:  65%|██████▌   | 122/187 [00:34<00:06,  9.59it/s]
#
# Dynamic Programming:  66%|██████▋   | 124/187 [00:34<00:06,  9.93it/s]
#
# Dynamic Programming:  67%|██████▋   | 126/187 [00:34<00:06,  9.95it/s]
#
# Dynamic Programming:  68%|██████▊   | 128/187 [00:34<00:05, 10.43it/s]
#
# Dynamic Programming:  70%|██████▉   | 130/187 [00:35<00:05, 10.96it/s]
#
# Dynamic Programming:  71%|███████   | 132/187 [00:35<00:04, 11.53it/s]
#
# Dynamic Programming:  72%|███████▏  | 134/187 [00:35<00:04, 12.10it/s]
#
# Dynamic Programming:  73%|███████▎  | 136/187 [00:35<00:04, 12.67it/s]
#
# Dynamic Programming:  74%|███████▍  | 138/187 [00:35<00:03, 12.75it/s]
#
# Dynamic Programming:  75%|███████▍  | 140/187 [00:35<00:03, 13.67it/s]
#
# Dynamic Programming:  76%|███████▌  | 142/187 [00:35<00:03, 14.68it/s]
#
# Dynamic Programming:  77%|███████▋  | 144/187 [00:35<00:02, 15.69it/s]
#
# Dynamic Programming:  79%|███████▊  | 147/187 [00:36<00:02, 16.91it/s]
#
# Dynamic Programming:  80%|████████  | 150/187 [00:36<00:02, 18.32it/s]
#
# Dynamic Programming:  82%|████████▏ | 153/187 [00:36<00:01, 20.10it/s]
#
# Dynamic Programming:  84%|████████▍ | 157/187 [00:36<00:01, 22.50it/s]
#
# Dynamic Programming:  86%|████████▌ | 161/187 [00:36<00:01, 24.46it/s]
#
# Dynamic Programming:  89%|████████▉ | 166/187 [00:36<00:00, 28.41it/s]
#
# Dynamic Programming: 100%|██████████| 187/187 [00:36<00:00,  5.07it/s]
#
#   4%|▍         | 3/70 [01:52<41:23, 37.07s/it]
#
# Dynamic Programming:   0%|          | 0/203 [00:00<?, ?it/s]
#
# Dynamic Programming:   0%|          | 1/203 [00:00<01:51,  1.81it/s]
#
# Dynamic Programming:   1%|          | 2/203 [00:01<01:52,  1.79it/s]
#
# Dynamic Programming:   1%|▏         | 3/203 [00:01<01:51,  1.79it/s]
#
# Dynamic Programming:   2%|▏         | 4/203 [00:02<01:51,  1.78it/s]
#
# Dynamic Programming:   2%|▏         | 5/203 [00:02<01:50,  1.78it/s]
#
# Dynamic Programming:   3%|▎         | 6/203 [00:03<01:49,  1.81it/s]
#
# Dynamic Programming:   3%|▎         | 7/203 [00:03<01:48,  1.81it/s]
#
# Dynamic Programming:   4%|▍         | 8/203 [00:04<01:46,  1.84it/s]
#
# Dynamic Programming:   4%|▍         | 9/203 [00:04<01:45,  1.84it/s]
#
# Dynamic Programming:   5%|▍         | 10/203 [00:05<01:43,  1.87it/s]
#
# Dynamic Programming:   5%|▌         | 11/203 [00:06<01:42,  1.87it/s]
#
# Dynamic Programming:   6%|▌         | 12/203 [00:06<01:40,  1.90it/s]
#
# Dynamic Programming:   6%|▋         | 13/203 [00:07<01:39,  1.92it/s]
#
# Dynamic Programming:   7%|▋         | 14/203 [00:07<01:37,  1.94it/s]
#
# Dynamic Programming:   7%|▋         | 15/203 [00:08<01:36,  1.95it/s]
#
# Dynamic Programming:   8%|▊         | 16/203 [00:08<01:34,  1.98it/s]
#
# Dynamic Programming:   8%|▊         | 17/203 [00:09<01:33,  1.98it/s]
#
# Dynamic Programming:   9%|▉         | 18/203 [00:09<01:31,  2.01it/s]
#
# Dynamic Programming:   9%|▉         | 19/203 [00:10<01:31,  2.02it/s]
#
# Dynamic Programming:  10%|▉         | 20/203 [00:10<01:29,  2.05it/s]
#
# Dynamic Programming:  10%|█         | 21/203 [00:10<01:28,  2.06it/s]
#
# Dynamic Programming:  11%|█         | 22/203 [00:11<01:26,  2.09it/s]
#
# Dynamic Programming:  11%|█▏        | 23/203 [00:11<01:25,  2.11it/s]
#
# Dynamic Programming:  12%|█▏        | 24/203 [00:12<01:23,  2.14it/s]
#
# Dynamic Programming:  12%|█▏        | 25/203 [00:12<01:22,  2.17it/s]
#
# Dynamic Programming:  13%|█▎        | 26/203 [00:13<01:21,  2.17it/s]
#
# Dynamic Programming:  13%|█▎        | 27/203 [00:13<01:20,  2.20it/s]
#
# Dynamic Programming:  14%|█▍        | 28/203 [00:14<01:19,  2.20it/s]
#
# Dynamic Programming:  14%|█▍        | 29/203 [00:14<01:17,  2.24it/s]
#
# Dynamic Programming:  15%|█▍        | 30/203 [00:15<01:17,  2.24it/s]
#
# Dynamic Programming:  15%|█▌        | 31/203 [00:15<01:15,  2.28it/s]
#
# Dynamic Programming:  16%|█▌        | 32/203 [00:15<01:13,  2.31it/s]
#
# Dynamic Programming:  16%|█▋        | 33/203 [00:16<01:13,  2.31it/s]
#
# Dynamic Programming:  17%|█▋        | 34/203 [00:16<01:11,  2.35it/s]
#
# Dynamic Programming:  17%|█▋        | 35/203 [00:17<01:11,  2.35it/s]
#
# Dynamic Programming:  18%|█▊        | 36/203 [00:17<01:09,  2.40it/s]
#
# Dynamic Programming:  18%|█▊        | 37/203 [00:17<01:08,  2.43it/s]
#
# Dynamic Programming:  19%|█▊        | 38/203 [00:18<01:06,  2.46it/s]
#
# Dynamic Programming:  19%|█▉        | 39/203 [00:18<01:05,  2.50it/s]
#
# Dynamic Programming:  20%|█▉        | 40/203 [00:19<01:05,  2.49it/s]
#
# Dynamic Programming:  20%|██        | 41/203 [00:19<01:04,  2.53it/s]
#
# Dynamic Programming:  21%|██        | 42/203 [00:19<01:02,  2.57it/s]
#
# Dynamic Programming:  21%|██        | 43/203 [00:20<01:02,  2.58it/s]
#
# Dynamic Programming:  22%|██▏       | 44/203 [00:20<01:00,  2.62it/s]
#
# Dynamic Programming:  22%|██▏       | 45/203 [00:20<01:00,  2.62it/s]
#
# Dynamic Programming:  23%|██▎       | 46/203 [00:21<00:58,  2.66it/s]
#
# Dynamic Programming:  23%|██▎       | 47/203 [00:21<00:57,  2.71it/s]
#
# Dynamic Programming:  24%|██▎       | 48/203 [00:22<00:57,  2.70it/s]
#
# Dynamic Programming:  24%|██▍       | 49/203 [00:22<00:56,  2.75it/s]
#
# Dynamic Programming:  25%|██▍       | 50/203 [00:22<00:54,  2.79it/s]
#
# Dynamic Programming:  25%|██▌       | 51/203 [00:23<00:54,  2.81it/s]
#
# Dynamic Programming:  26%|██▌       | 52/203 [00:23<00:52,  2.85it/s]
#
# Dynamic Programming:  26%|██▌       | 53/203 [00:23<00:51,  2.89it/s]
#
# Dynamic Programming:  27%|██▋       | 54/203 [00:24<00:51,  2.88it/s]
#
# Dynamic Programming:  27%|██▋       | 55/203 [00:24<00:50,  2.93it/s]
#
# Dynamic Programming:  28%|██▊       | 56/203 [00:24<00:49,  2.98it/s]
#
# Dynamic Programming:  28%|██▊       | 57/203 [00:25<00:49,  2.97it/s]
#
# Dynamic Programming:  29%|██▊       | 58/203 [00:25<00:47,  3.03it/s]
#
# Dynamic Programming:  29%|██▉       | 59/203 [00:25<00:46,  3.08it/s]
#
# Dynamic Programming:  30%|██▉       | 60/203 [00:26<00:46,  3.07it/s]
#
# Dynamic Programming:  30%|███       | 61/203 [00:26<00:45,  3.13it/s]
#
# Dynamic Programming:  31%|███       | 62/203 [00:26<00:44,  3.19it/s]
#
# Dynamic Programming:  31%|███       | 63/203 [00:26<00:43,  3.24it/s]
#
# Dynamic Programming:  32%|███▏      | 64/203 [00:27<00:43,  3.22it/s]
#
# Dynamic Programming:  32%|███▏      | 65/203 [00:27<00:42,  3.28it/s]
#
# Dynamic Programming:  33%|███▎      | 66/203 [00:27<00:40,  3.34it/s]
#
# Dynamic Programming:  33%|███▎      | 67/203 [00:28<00:40,  3.37it/s]
#
# Dynamic Programming:  33%|███▎      | 68/203 [00:28<00:39,  3.43it/s]
#
# Dynamic Programming:  34%|███▍      | 69/203 [00:28<00:38,  3.49it/s]
#
# Dynamic Programming:  34%|███▍      | 70/203 [00:28<00:37,  3.54it/s]
#
# Dynamic Programming:  35%|███▍      | 71/203 [00:29<00:37,  3.51it/s]
#
# Dynamic Programming:  35%|███▌      | 72/203 [00:29<00:36,  3.58it/s]
#
# Dynamic Programming:  36%|███▌      | 73/203 [00:29<00:35,  3.65it/s]
#
# Dynamic Programming:  36%|███▋      | 74/203 [00:30<00:35,  3.62it/s]
#
# Dynamic Programming:  37%|███▋      | 75/203 [00:30<00:34,  3.70it/s]
#
# Dynamic Programming:  37%|███▋      | 76/203 [00:30<00:33,  3.78it/s]
#
# Dynamic Programming:  38%|███▊      | 77/203 [00:30<00:32,  3.84it/s]
#
# Dynamic Programming:  38%|███▊      | 78/203 [00:31<00:32,  3.81it/s]
#
# Dynamic Programming:  39%|███▉      | 79/203 [00:31<00:31,  3.89it/s]
#
# Dynamic Programming:  39%|███▉      | 80/203 [00:31<00:30,  3.97it/s]
#
# Dynamic Programming:  40%|███▉      | 81/203 [00:31<00:30,  4.04it/s]
#
# Dynamic Programming:  40%|████      | 82/203 [00:32<00:29,  4.11it/s]
#
# Dynamic Programming:  41%|████      | 83/203 [00:32<00:29,  4.06it/s]
#
# Dynamic Programming:  41%|████▏     | 84/203 [00:32<00:28,  4.16it/s]
#
# Dynamic Programming:  42%|████▏     | 85/203 [00:32<00:27,  4.24it/s]
#
# Dynamic Programming:  42%|████▏     | 86/203 [00:32<00:27,  4.32it/s]
#
# Dynamic Programming:  43%|████▎     | 87/203 [00:33<00:27,  4.27it/s]
#
# Dynamic Programming:  43%|████▎     | 88/203 [00:33<00:26,  4.37it/s]
#
# Dynamic Programming:  44%|████▍     | 89/203 [00:33<00:25,  4.47it/s]
#
# Dynamic Programming:  44%|████▍     | 90/203 [00:33<00:24,  4.56it/s]
#
# Dynamic Programming:  45%|████▍     | 91/203 [00:34<00:24,  4.64it/s]
#
# Dynamic Programming:  45%|████▌     | 92/203 [00:34<00:24,  4.58it/s]
#
# Dynamic Programming:  46%|████▌     | 93/203 [00:34<00:23,  4.70it/s]
#
# Dynamic Programming:  46%|████▋     | 94/203 [00:34<00:22,  4.80it/s]
# Dynamic Programming:  47%|████▋     | 95/203 [00:34<00:22,  4.90it/s]
#
# Dynamic Programming:  47%|████▋     | 96/203 [00:35<00:21,  4.99it/s]
#
# Dynamic Programming:  48%|████▊     | 97/203 [00:35<00:21,  4.91it/s]
#
# Dynamic Programming:  48%|████▊     | 98/203 [00:35<00:23,  4.39it/s]
#
# Dynamic Programming:  49%|████▉     | 99/203 [00:35<00:22,  4.65it/s]
#
# Dynamic Programming:  49%|████▉     | 100/203 [00:35<00:21,  4.88it/s]
#
# Dynamic Programming:  50%|████▉     | 101/203 [00:36<00:20,  4.92it/s]
#
# Dynamic Programming:  50%|█████     | 102/203 [00:36<00:19,  5.13it/s]
#
# Dynamic Programming:  51%|█████     | 103/203 [00:36<00:18,  5.31it/s]
#
# Dynamic Programming:  51%|█████     | 104/203 [00:36<00:18,  5.47it/s]
#
# Dynamic Programming:  52%|█████▏    | 105/203 [00:36<00:17,  5.61it/s]
#
# Dynamic Programming:  52%|█████▏    | 106/203 [00:37<00:16,  5.75it/s]
#
# Dynamic Programming:  53%|█████▎    | 107/203 [00:37<00:16,  5.66it/s]
#
# Dynamic Programming:  53%|█████▎    | 108/203 [00:37<00:16,  5.83it/s]
#
# Dynamic Programming:  54%|█████▎    | 109/203 [00:37<00:15,  5.99it/s]
#
# Dynamic Programming:  54%|█████▍    | 110/203 [00:37<00:15,  6.13it/s]
#
# Dynamic Programming:  55%|█████▍    | 111/203 [00:37<00:14,  6.27it/s]
#
# Dynamic Programming:  55%|█████▌    | 112/203 [00:37<00:14,  6.39it/s]
#
# Dynamic Programming:  56%|█████▌    | 113/203 [00:38<00:13,  6.52it/s]
#
# Dynamic Programming:  56%|█████▌    | 114/203 [00:38<00:13,  6.37it/s]
#
# Dynamic Programming:  57%|█████▋    | 115/203 [00:38<00:13,  6.57it/s]
#
# Dynamic Programming:  57%|█████▋    | 116/203 [00:38<00:12,  6.75it/s]
#
# Dynamic Programming:  58%|█████▊    | 117/203 [00:38<00:12,  6.92it/s]
#
# Dynamic Programming:  58%|█████▊    | 118/203 [00:38<00:12,  7.07it/s]
#
# Dynamic Programming:  59%|█████▊    | 119/203 [00:38<00:11,  7.22it/s]
#
# Dynamic Programming:  59%|█████▉    | 120/203 [00:39<00:11,  7.36it/s]
#
# Dynamic Programming:  60%|█████▉    | 121/203 [00:39<00:11,  7.32it/s]
#
# Dynamic Programming:  60%|██████    | 122/203 [00:39<00:10,  7.53it/s]
#
# Dynamic Programming:  61%|██████    | 123/203 [00:39<00:10,  7.72it/s]
#
# Dynamic Programming:  61%|██████    | 124/203 [00:39<00:09,  7.91it/s]
#
# Dynamic Programming:  62%|██████▏   | 125/203 [00:39<00:09,  8.09it/s]
#
# Dynamic Programming:  62%|██████▏   | 126/203 [00:39<00:09,  8.26it/s]
#
# Dynamic Programming:  63%|██████▎   | 127/203 [00:39<00:09,  8.44it/s]
#
# Dynamic Programming:  63%|██████▎   | 128/203 [00:40<00:08,  8.62it/s]
#
# Dynamic Programming:  64%|██████▎   | 129/203 [00:40<00:08,  8.79it/s]
#
# Dynamic Programming:  64%|██████▍   | 130/203 [00:40<00:08,  8.49it/s]
#
# Dynamic Programming:  65%|██████▍   | 131/203 [00:40<00:08,  8.79it/s]
#
# Dynamic Programming:  65%|██████▌   | 132/203 [00:40<00:07,  9.07it/s]
#
# Dynamic Programming:  66%|██████▌   | 133/203 [00:40<00:07,  9.32it/s]
#
# Dynamic Programming:  67%|██████▋   | 135/203 [00:40<00:07,  9.64it/s]
#
# Dynamic Programming:  67%|██████▋   | 137/203 [00:40<00:06,  9.99it/s]
#
# Dynamic Programming:  68%|██████▊   | 139/203 [00:41<00:06, 10.38it/s]
#
# Dynamic Programming:  69%|██████▉   | 141/203 [00:41<00:05, 10.45it/s]
#
# Dynamic Programming:  70%|███████   | 143/203 [00:41<00:05, 10.99it/s]
#
# Dynamic Programming:  71%|███████▏  | 145/203 [00:41<00:05, 11.54it/s]
#
# Dynamic Programming:  72%|███████▏  | 147/203 [00:41<00:04, 12.13it/s]
#
# Dynamic Programming:  73%|███████▎  | 149/203 [00:41<00:04, 12.75it/s]
#
# Dynamic Programming:  74%|███████▍  | 151/203 [00:42<00:03, 13.43it/s]
#
# Dynamic Programming:  75%|███████▌  | 153/203 [00:42<00:03, 14.11it/s]
#
# Dynamic Programming:  76%|███████▋  | 155/203 [00:42<00:03, 14.20it/s]
#
# Dynamic Programming:  77%|███████▋  | 157/203 [00:42<00:03, 15.17it/s]
#
# Dynamic Programming:  78%|███████▊  | 159/203 [00:42<00:02, 16.19it/s]
#
# Dynamic Programming:  80%|███████▉  | 162/203 [00:42<00:02, 17.38it/s]
#
# Dynamic Programming:  81%|████████▏ | 165/203 [00:42<00:02, 18.79it/s]
#
# Dynamic Programming:  83%|████████▎ | 168/203 [00:42<00:01, 20.47it/s]
#
# Dynamic Programming:  84%|████████▍ | 171/203 [00:43<00:01, 22.48it/s]
#
# Dynamic Programming:  86%|████████▌ | 175/203 [00:43<00:01, 25.04it/s]
#
# Dynamic Programming:  88%|████████▊ | 179/203 [00:43<00:00, 27.22it/s]
#
# Dynamic Programming: 100%|██████████| 203/203 [00:43<00:00,  4.67it/s]
#
#   6%|▌         | 4/70 [02:36<42:53, 39.00s/it]
#
# Dynamic Programming:   0%|          | 0/202 [00:00<?, ?it/s]
#
# Dynamic Programming:   0%|          | 1/202 [00:00<01:48,  1.86it/s]
#
# Dynamic Programming:   1%|          | 2/202 [00:01<01:49,  1.83it/s]
#
# Dynamic Programming:   1%|▏         | 3/202 [00:01<01:48,  1.84it/s]
#
# Dynamic Programming:   2%|▏         | 4/202 [00:02<01:48,  1.83it/s]
#
# Dynamic Programming:   2%|▏         | 5/202 [00:02<01:46,  1.85it/s]
#
# Dynamic Programming:   3%|▎         | 6/202 [00:03<01:46,  1.84it/s]
#
# Dynamic Programming:   3%|▎         | 7/202 [00:03<01:45,  1.85it/s]
#
# Dynamic Programming:   4%|▍         | 8/202 [00:04<01:43,  1.88it/s]
#
# Dynamic Programming:   4%|▍         | 9/202 [00:04<01:43,  1.87it/s]
#
# Dynamic Programming:   5%|▍         | 10/202 [00:05<01:41,  1.89it/s]
#
# Dynamic Programming:   5%|▌         | 11/202 [00:05<01:40,  1.90it/s]
#
# Dynamic Programming:   6%|▌         | 12/202 [00:06<01:38,  1.93it/s]
#
# Dynamic Programming:   6%|▋         | 13/202 [00:06<01:37,  1.93it/s]
#
# Dynamic Programming:   7%|▋         | 14/202 [00:07<01:35,  1.96it/s]
#
# Dynamic Programming:   7%|▋         | 15/202 [00:07<01:35,  1.97it/s]
#
# Dynamic Programming:   8%|▊         | 16/202 [00:08<01:33,  2.00it/s]
#
# Dynamic Programming:   8%|▊         | 17/202 [00:08<01:32,  2.00it/s]
#
# Dynamic Programming:   9%|▉         | 18/202 [00:09<01:30,  2.04it/s]
#
# Dynamic Programming:   9%|▉         | 19/202 [00:09<01:28,  2.07it/s]
#
# Dynamic Programming:  10%|▉         | 20/202 [00:10<01:27,  2.07it/s]
#
# Dynamic Programming:  10%|█         | 21/202 [00:10<01:25,  2.11it/s]
#
# Dynamic Programming:  11%|█         | 22/202 [00:11<01:25,  2.11it/s]
#
# Dynamic Programming:  11%|█▏        | 23/202 [00:11<01:23,  2.15it/s]
#
# Dynamic Programming:  12%|█▏        | 24/202 [00:12<01:22,  2.15it/s]
#
# Dynamic Programming:  12%|█▏        | 25/202 [00:12<01:20,  2.19it/s]
#
# Dynamic Programming:  13%|█▎        | 26/202 [00:13<01:20,  2.19it/s]
#
# Dynamic Programming:  13%|█▎        | 27/202 [00:13<01:18,  2.23it/s]
#
# Dynamic Programming:  14%|█▍        | 28/202 [00:13<01:17,  2.23it/s]
#
# Dynamic Programming:  14%|█▍        | 29/202 [00:14<01:15,  2.28it/s]
#
# Dynamic Programming:  15%|█▍        | 30/202 [00:14<01:14,  2.32it/s]
#
# Dynamic Programming:  15%|█▌        | 31/202 [00:15<01:14,  2.31it/s]
#
# Dynamic Programming:  16%|█▌        | 32/202 [00:15<01:12,  2.35it/s]
#
# Dynamic Programming:  16%|█▋        | 33/202 [00:16<01:11,  2.36it/s]
#
# Dynamic Programming:  17%|█▋        | 34/202 [00:16<01:09,  2.40it/s]
#
# Dynamic Programming:  17%|█▋        | 35/202 [00:16<01:08,  2.44it/s]
#
# Dynamic Programming:  18%|█▊        | 36/202 [00:17<01:07,  2.46it/s]
#
# Dynamic Programming:  18%|█▊        | 37/202 [00:17<01:05,  2.50it/s]
#
# Dynamic Programming:  19%|█▉        | 38/202 [00:17<01:05,  2.50it/s]
#
# Dynamic Programming:  19%|█▉        | 39/202 [00:18<01:04,  2.54it/s]
#
# Dynamic Programming:  20%|█▉        | 40/202 [00:18<01:02,  2.58it/s]
#
# Dynamic Programming:  20%|██        | 41/202 [00:19<01:02,  2.57it/s]
#
# Dynamic Programming:  21%|██        | 42/202 [00:19<01:01,  2.62it/s]
#
# Dynamic Programming:  21%|██▏       | 43/202 [00:19<00:59,  2.66it/s]
#
# Dynamic Programming:  22%|██▏       | 44/202 [00:20<00:58,  2.71it/s]
#
# Dynamic Programming:  22%|██▏       | 45/202 [00:20<00:57,  2.75it/s]
#
# Dynamic Programming:  23%|██▎       | 46/202 [00:20<00:56,  2.78it/s]
#
# Dynamic Programming:  23%|██▎       | 47/202 [00:21<00:56,  2.76it/s]
#
# Dynamic Programming:  24%|██▍       | 48/202 [00:21<00:54,  2.80it/s]
#
# Dynamic Programming:  24%|██▍       | 49/202 [00:21<00:53,  2.84it/s]
#
# Dynamic Programming:  25%|██▍       | 50/202 [00:22<00:53,  2.83it/s]
#
# Dynamic Programming:  25%|██▌       | 51/202 [00:22<00:52,  2.89it/s]
#
# Dynamic Programming:  26%|██▌       | 52/202 [00:22<00:51,  2.94it/s]
#
# Dynamic Programming:  26%|██▌       | 53/202 [00:23<00:50,  2.93it/s]
#
# Dynamic Programming:  27%|██▋       | 54/202 [00:23<00:49,  2.99it/s]
#
# Dynamic Programming:  27%|██▋       | 55/202 [00:23<00:48,  3.04it/s]
#
# Dynamic Programming:  28%|██▊       | 56/202 [00:24<00:47,  3.07it/s]
#
# Dynamic Programming:  28%|██▊       | 57/202 [00:24<00:46,  3.12it/s]
#
# Dynamic Programming:  29%|██▊       | 58/202 [00:24<00:45,  3.17it/s]
#
# Dynamic Programming:  29%|██▉       | 59/202 [00:25<00:45,  3.15it/s]
#
# Dynamic Programming:  30%|██▉       | 60/202 [00:25<00:44,  3.21it/s]
#
# Dynamic Programming:  30%|███       | 61/202 [00:25<00:43,  3.27it/s]
#
# Dynamic Programming:  31%|███       | 62/202 [00:26<00:43,  3.25it/s]
#
# Dynamic Programming:  31%|███       | 63/202 [00:26<00:41,  3.31it/s]
#
# Dynamic Programming:  32%|███▏      | 64/202 [00:26<00:40,  3.37it/s]
#
# Dynamic Programming:  32%|███▏      | 65/202 [00:26<00:39,  3.43it/s]
#
# Dynamic Programming:  33%|███▎      | 66/202 [00:27<00:39,  3.40it/s]
#
# Dynamic Programming:  33%|███▎      | 67/202 [00:27<00:38,  3.47it/s]
#
# Dynamic Programming:  34%|███▎      | 68/202 [00:27<00:37,  3.53it/s]
#
# Dynamic Programming:  34%|███▍      | 69/202 [00:28<00:37,  3.52it/s]
#
# Dynamic Programming:  35%|███▍      | 70/202 [00:28<00:36,  3.59it/s]
#
# Dynamic Programming:  35%|███▌      | 71/202 [00:28<00:35,  3.66it/s]
#
# Dynamic Programming:  36%|███▌      | 72/202 [00:28<00:34,  3.72it/s]
#
# Dynamic Programming:  36%|███▌      | 73/202 [00:29<00:35,  3.69it/s]
#
# Dynamic Programming:  37%|███▋      | 74/202 [00:29<00:33,  3.77it/s]
#
# Dynamic Programming:  37%|███▋      | 75/202 [00:29<00:33,  3.84it/s]
#
# Dynamic Programming:  38%|███▊      | 76/202 [00:29<00:32,  3.91it/s]
#
# Dynamic Programming:  38%|███▊      | 77/202 [00:30<00:32,  3.87it/s]
#
# Dynamic Programming:  39%|███▊      | 78/202 [00:30<00:31,  3.96it/s]
#
# Dynamic Programming:  39%|███▉      | 79/202 [00:30<00:30,  4.04it/s]
#
# Dynamic Programming:  40%|███▉      | 80/202 [00:30<00:29,  4.11it/s]
#
# Dynamic Programming:  40%|████      | 81/202 [00:31<00:29,  4.07it/s]
#
# Dynamic Programming:  41%|████      | 82/202 [00:31<00:28,  4.16it/s]
#
# Dynamic Programming:  41%|████      | 83/202 [00:31<00:28,  4.24it/s]
#
# Dynamic Programming:  42%|████▏     | 84/202 [00:31<00:27,  4.32it/s]
#
# Dynamic Programming:  42%|████▏     | 85/202 [00:32<00:26,  4.39it/s]
#
# Dynamic Programming:  43%|████▎     | 86/202 [00:32<00:26,  4.34it/s]
#
# Dynamic Programming:  43%|████▎     | 87/202 [00:32<00:25,  4.44it/s]
#
# Dynamic Programming:  44%|████▎     | 88/202 [00:32<00:25,  4.53it/s]
#
# Dynamic Programming:  44%|████▍     | 89/202 [00:32<00:24,  4.62it/s]
#
# Dynamic Programming:  45%|████▍     | 90/202 [00:33<00:23,  4.69it/s]
#
# Dynamic Programming:  45%|████▌     | 91/202 [00:33<00:23,  4.71it/s]
#
# Dynamic Programming:  46%|████▌     | 92/202 [00:33<00:22,  4.79it/s]
#
# Dynamic Programming:  46%|████▌     | 93/202 [00:33<00:22,  4.88it/s]
#
# Dynamic Programming:  47%|████▋     | 94/202 [00:33<00:21,  4.96it/s]
#
# Dynamic Programming:  47%|████▋     | 95/202 [00:34<00:21,  5.04it/s]
#
# Dynamic Programming:  48%|████▊     | 96/202 [00:34<00:21,  4.96it/s]
#
# Dynamic Programming:  48%|████▊     | 97/202 [00:34<00:20,  5.08it/s]
#
# Dynamic Programming:  49%|████▊     | 98/202 [00:34<00:20,  5.20it/s]
#
# Dynamic Programming:  49%|████▉     | 99/202 [00:34<00:19,  5.30it/s]
#
# Dynamic Programming:  50%|████▉     | 100/202 [00:35<00:18,  5.41it/s]
#
# Dynamic Programming:  50%|█████     | 101/202 [00:35<00:18,  5.32it/s]
#
# Dynamic Programming:  50%|█████     | 102/202 [00:35<00:18,  5.46it/s]
#
# Dynamic Programming:  51%|█████     | 103/202 [00:35<00:17,  5.59it/s]
#
# Dynamic Programming:  51%|█████▏    | 104/202 [00:35<00:17,  5.72it/s]
#
# Dynamic Programming:  52%|█████▏    | 105/202 [00:35<00:16,  5.84it/s]
#
# Dynamic Programming:  52%|█████▏    | 106/202 [00:36<00:16,  5.95it/s]
#
# Dynamic Programming:  53%|█████▎    | 107/202 [00:36<00:16,  5.84it/s]
#
# Dynamic Programming:  53%|█████▎    | 108/202 [00:36<00:15,  5.96it/s]
#
# Dynamic Programming:  54%|█████▍    | 109/202 [00:36<00:15,  6.12it/s]
#
# Dynamic Programming:  54%|█████▍    | 110/202 [00:36<00:14,  6.27it/s]
#
# Dynamic Programming:  55%|█████▍    | 111/202 [00:36<00:14,  6.42it/s]
#
# Dynamic Programming:  55%|█████▌    | 112/202 [00:36<00:13,  6.49it/s]
#
# Dynamic Programming:  56%|█████▌    | 113/202 [00:37<00:13,  6.64it/s]
#
# Dynamic Programming:  56%|█████▋    | 114/202 [00:37<00:13,  6.50it/s]
#
# Dynamic Programming:  57%|█████▋    | 115/202 [00:37<00:12,  6.71it/s]
#
# Dynamic Programming:  57%|█████▋    | 116/202 [00:37<00:12,  6.90it/s]
#
# Dynamic Programming:  58%|█████▊    | 117/202 [00:37<00:12,  7.03it/s]
#
# Dynamic Programming:  58%|█████▊    | 118/202 [00:37<00:11,  7.21it/s]
#
# Dynamic Programming:  59%|█████▉    | 119/202 [00:37<00:11,  7.39it/s]
#
# Dynamic Programming:  59%|█████▉    | 120/202 [00:38<00:10,  7.55it/s]
#
# Dynamic Programming:  60%|█████▉    | 121/202 [00:38<00:11,  7.35it/s]
#
# Dynamic Programming:  60%|██████    | 122/202 [00:38<00:10,  7.60it/s]
#
# Dynamic Programming:  61%|██████    | 123/202 [00:38<00:10,  7.83it/s]
#
# Dynamic Programming:  61%|██████▏   | 124/202 [00:38<00:09,  8.05it/s]
#
# Dynamic Programming:  62%|██████▏   | 125/202 [00:38<00:09,  8.25it/s]
#
# Dynamic Programming:  62%|██████▏   | 126/202 [00:38<00:08,  8.45it/s]
#
# Dynamic Programming:  63%|██████▎   | 127/202 [00:38<00:08,  8.65it/s]
#
# Dynamic Programming:  63%|██████▎   | 128/202 [00:39<00:08,  8.84it/s]
#
# Dynamic Programming:  64%|██████▍   | 129/202 [00:39<00:08,  9.02it/s]
#
# Dynamic Programming:  64%|██████▍   | 130/202 [00:39<00:08,  8.70it/s]
#
# Dynamic Programming:  65%|██████▍   | 131/202 [00:39<00:07,  9.03it/s]
#
# Dynamic Programming:  66%|██████▌   | 133/202 [00:39<00:07,  9.38it/s]
#
# Dynamic Programming:  67%|██████▋   | 135/202 [00:39<00:06,  9.76it/s]
#
# Dynamic Programming:  68%|██████▊   | 137/202 [00:39<00:06, 10.17it/s]
#
# Dynamic Programming:  69%|██████▉   | 139/202 [00:40<00:05, 10.58it/s]
#
# Dynamic Programming:  70%|██████▉   | 141/202 [00:40<00:05, 10.68it/s]
#
# Dynamic Programming:  71%|███████   | 143/202 [00:40<00:05, 11.30it/s]
#
# Dynamic Programming:  72%|███████▏  | 145/202 [00:40<00:04, 11.92it/s]
#
# Dynamic Programming:  73%|███████▎  | 147/202 [00:40<00:04, 12.58it/s]
#
# Dynamic Programming:  74%|███████▍  | 149/202 [00:40<00:04, 13.25it/s]
#
# Dynamic Programming:  75%|███████▍  | 151/202 [00:40<00:03, 13.96it/s]
#
# Dynamic Programming:  76%|███████▌  | 153/202 [00:41<00:03, 14.73it/s]
#
# Dynamic Programming:  77%|███████▋  | 155/202 [00:41<00:03, 15.52it/s]
#
# Dynamic Programming:  78%|███████▊  | 157/202 [00:41<00:02, 15.83it/s]
#
# Dynamic Programming:  79%|███████▊  | 159/202 [00:41<00:02, 16.73it/s]
#
# Dynamic Programming:  80%|████████  | 162/202 [00:41<00:02, 18.04it/s]
#
# Dynamic Programming:  82%|████████▏ | 165/202 [00:41<00:01, 19.56it/s]
#
# Dynamic Programming:  83%|████████▎ | 168/202 [00:41<00:01, 21.39it/s]
#
# Dynamic Programming:  85%|████████▌ | 172/202 [00:41<00:01, 23.67it/s]
#
# Dynamic Programming:  87%|████████▋ | 176/202 [00:42<00:00, 26.67it/s]
# Dynamic Programming:  90%|████████▉ | 181/202 [00:42<00:00, 30.81it/s]
#
# Dynamic Programming: 100%|██████████| 202/202 [00:42<00:00,  4.78it/s]
#
#   7%|▋         | 5/70 [03:18<43:19, 39.99s/it]
#
# Dynamic Programming:   0%|          | 0/204 [00:00<?, ?it/s]
#
# Dynamic Programming:   0%|          | 1/204 [00:00<01:50,  1.83it/s]
#
# Dynamic Programming:   1%|          | 2/204 [00:01<01:52,  1.80it/s]
#
# Dynamic Programming:   1%|▏         | 3/204 [00:01<01:51,  1.81it/s]
#
# Dynamic Programming:   2%|▏         | 4/204 [00:02<01:51,  1.80it/s]
#
# Dynamic Programming:   2%|▏         | 5/204 [00:02<01:49,  1.81it/s]
#
# Dynamic Programming:   3%|▎         | 6/204 [00:03<01:49,  1.81it/s]
#
# Dynamic Programming:   3%|▎         | 7/204 [00:03<01:47,  1.83it/s]
#
# Dynamic Programming:   4%|▍         | 8/204 [00:04<01:46,  1.84it/s]
#
# Dynamic Programming:   4%|▍         | 9/204 [00:04<01:44,  1.86it/s]
#
# Dynamic Programming:   5%|▍         | 10/204 [00:05<01:45,  1.84it/s]
#
# Dynamic Programming:   5%|▌         | 11/204 [00:06<01:52,  1.72it/s]
#
# Dynamic Programming:   6%|▌         | 12/204 [00:06<01:49,  1.75it/s]
#
# Dynamic Programming:   6%|▋         | 13/204 [00:07<01:52,  1.69it/s]
#
# Dynamic Programming:   7%|▋         | 14/204 [00:07<01:43,  1.83it/s]
#
# Dynamic Programming:   7%|▋         | 15/204 [00:08<01:39,  1.89it/s]
#
# Dynamic Programming:   8%|▊         | 16/204 [00:08<01:37,  1.94it/s]
#
# Dynamic Programming:   8%|▊         | 17/204 [00:09<01:35,  1.96it/s]
#
# Dynamic Programming:   9%|▉         | 18/204 [00:09<01:32,  2.00it/s]
#
# Dynamic Programming:   9%|▉         | 19/204 [00:10<01:31,  2.01it/s]
#
# Dynamic Programming:  10%|▉         | 20/204 [00:10<01:29,  2.05it/s]
#
# Dynamic Programming:  10%|█         | 21/204 [00:11<01:28,  2.06it/s]
#
# Dynamic Programming:  11%|█         | 22/204 [00:11<01:26,  2.09it/s]
#
# Dynamic Programming:  11%|█▏        | 23/204 [00:12<01:25,  2.12it/s]
#
# Dynamic Programming:  12%|█▏        | 24/204 [00:12<01:25,  2.11it/s]
#
# Dynamic Programming:  12%|█▏        | 25/204 [00:12<01:23,  2.15it/s]
#
# Dynamic Programming:  13%|█▎        | 26/204 [00:13<01:22,  2.15it/s]
#
# Dynamic Programming:  13%|█▎        | 27/204 [00:13<01:20,  2.19it/s]
#
# Dynamic Programming:  14%|█▎        | 28/204 [00:14<01:20,  2.19it/s]
#
# Dynamic Programming:  14%|█▍        | 29/204 [00:14<01:18,  2.23it/s]
#
# Dynamic Programming:  15%|█▍        | 30/204 [00:15<01:17,  2.24it/s]
#
# Dynamic Programming:  15%|█▌        | 31/204 [00:15<01:15,  2.28it/s]
#
# Dynamic Programming:  16%|█▌        | 32/204 [00:16<01:14,  2.31it/s]
#
# Dynamic Programming:  16%|█▌        | 33/204 [00:16<01:13,  2.31it/s]
#
# Dynamic Programming:  17%|█▋        | 34/204 [00:16<01:12,  2.35it/s]
#
# Dynamic Programming:  17%|█▋        | 35/204 [00:17<01:11,  2.37it/s]
#
# Dynamic Programming:  18%|█▊        | 36/204 [00:17<01:09,  2.41it/s]
#
# ...
#
# Dynamic Programming:  40%|████      | 80/200 [00:30<00:28,  4.16it/s]
#
# Dynamic Programming:  40%|████      | 81/200 [00:30<00:28,  4.23it/s]
#
# Dynamic Programming:  41%|████      | 82/200 [00:30<00:27,  4.31it/s]
#
# Dynamic Programming:  42%|████▏     | 83/200 [00:31<00:27,  4.26it/s]
#
# Dynamic Programming:  42%|████▏     | 84/200 [00:31<00:26,  4.35it/s]
#
# Dynamic Programming:  42%|████▎     | 85/200 [00:31<00:25,  4.46it/s]
#
# Dynamic Programming:  43%|████▎     | 86/200 [00:31<00:25,  4.56it/s]
#
# Dynamic Programming:  44%|████▎     | 87/200 [00:32<00:25,  4.51it/s]
#
# Dynamic Programming:  44%|████▍     | 88/200 [00:32<00:24,  4.63it/s]
#
# Dynamic Programming:  44%|████▍     | 89/200 [00:32<00:23,  4.75it/s]
#
# Dynamic Programming:  45%|████▌     | 90/200 [00:32<00:22,  4.84it/s]
#
# Dynamic Programming:  46%|████▌     | 91/200 [00:32<00:22,  4.93it/s]
#
# Dynamic Programming:  46%|████▌     | 92/200 [00:33<00:21,  5.01it/s]
#
# Dynamic Programming:  46%|████▋     | 93/200 [00:33<00:21,  5.09it/s]
#
# Dynamic Programming:  47%|████▋     | 94/200 [00:33<00:20,  5.17it/s]
#
# Dynamic Programming:  48%|████▊     | 95/200 [00:33<00:19,  5.26it/s]
#
# Dynamic Programming:  48%|████▊     | 96/200 [00:33<00:19,  5.34it/s]
#
# Dynamic Programming:  48%|████▊     | 97/200 [00:33<00:18,  5.42it/s]
#
# Dynamic Programming:  49%|████▉     | 98/200 [00:34<00:18,  5.57it/s]
#
# Dynamic Programming:  50%|████▉     | 99/200 [00:34<00:17,  5.65it/s]
#
# Dynamic Programming:  50%|█████     | 100/200 [00:34<00:17,  5.73it/s]
#
# Dynamic Programming:  50%|█████     | 101/200 [00:34<00:17,  5.81it/s]
#
# Dynamic Programming:  51%|█████     | 102/200 [00:34<00:16,  5.89it/s]
#
# Dynamic Programming:  52%|█████▏    | 103/200 [00:34<00:16,  5.98it/s]
#
# Dynamic Programming:  52%|█████▏    | 104/200 [00:35<00:16,  5.84it/s]
#
# Dynamic Programming:  52%|█████▎    | 105/200 [00:35<00:15,  6.00it/s]
#
# Dynamic Programming:  53%|█████▎    | 106/200 [00:35<00:15,  6.15it/s]
#
# Dynamic Programming:  54%|█████▎    | 107/200 [00:35<00:14,  6.29it/s]
#
# Dynamic Programming:  54%|█████▍    | 108/200 [00:35<00:14,  6.41it/s]
#
# Dynamic Programming:  55%|█████▍    | 109/200 [00:35<00:13,  6.55it/s]
#
# Dynamic Programming:  55%|█████▌    | 110/200 [00:36<00:13,  6.68it/s]
#
# Dynamic Programming:  56%|█████▌    | 111/200 [00:36<00:13,  6.76it/s]
#
# Dynamic Programming:  56%|█████▌    | 112/200 [00:36<00:12,  6.89it/s]
#
# Dynamic Programming:  56%|█████▋    | 113/200 [00:36<00:12,  7.03it/s]
#
# Dynamic Programming:  57%|█████▋    | 114/200 [00:36<00:12,  7.16it/s]
#
# Dynamic Programming:  57%|█████▊    | 115/200 [00:36<00:11,  7.30it/s]
#
# Dynamic Programming:  58%|█████▊    | 116/200 [00:36<00:11,  7.43it/s]
#
# Dynamic Programming:  58%|█████▊    | 117/200 [00:36<00:10,  7.57it/s]
#
# Dynamic Programming:  59%|█████▉    | 118/200 [00:37<00:11,  7.35it/s]
#
# Dynamic Programming:  60%|█████▉    | 119/200 [00:37<00:10,  7.59it/s]
#
# Dynamic Programming:  60%|██████    | 120/200 [00:37<00:10,  7.81it/s]
#
# Dynamic Programming:  60%|██████    | 121/200 [00:37<00:09,  8.01it/s]
#
# Dynamic Programming:  61%|██████    | 122/200 [00:37<00:09,  8.21it/s]
#
# Dynamic Programming:  62%|██████▏   | 123/200 [00:37<00:09,  8.39it/s]
#
# Dynamic Programming:  62%|██████▏   | 124/200 [00:37<00:08,  8.58it/s]
#
# Dynamic Programming:  62%|██████▎   | 125/200 [00:37<00:08,  8.76it/s]
#
# Dynamic Programming:  63%|██████▎   | 126/200 [00:38<00:08,  8.95it/s]
#
# Dynamic Programming:  64%|██████▎   | 127/200 [00:38<00:08,  8.65it/s]
#
# Dynamic Programming:  64%|██████▍   | 128/200 [00:38<00:08,  8.96it/s]
#
# Dynamic Programming:  65%|██████▌   | 130/200 [00:38<00:07,  9.31it/s]
#
# Dynamic Programming:  66%|██████▌   | 132/200 [00:38<00:07,  9.69it/s]
#
# Dynamic Programming:  67%|██████▋   | 134/200 [00:38<00:06, 10.09it/s]
#
# Dynamic Programming:  68%|██████▊   | 136/200 [00:39<00:06, 10.53it/s]
#
# Dynamic Programming:  69%|██████▉   | 138/200 [00:39<00:05, 10.64it/s]
#
# Dynamic Programming:  70%|███████   | 140/200 [00:39<00:05, 11.22it/s]
#
# Dynamic Programming:  71%|███████   | 142/200 [00:39<00:04, 11.82it/s]
#
# Dynamic Programming:  72%|███████▏  | 144/200 [00:39<00:04, 12.44it/s]
#
# Dynamic Programming:  73%|███████▎  | 146/200 [00:39<00:04, 13.10it/s]
#
# Dynamic Programming:  74%|███████▍  | 148/200 [00:39<00:03, 13.80it/s]
#
# Dynamic Programming:  75%|███████▌  | 150/200 [00:40<00:03, 14.54it/s]
#
# Dynamic Programming:  76%|███████▌  | 152/200 [00:40<00:03, 15.02it/s]
#
# Dynamic Programming:  77%|███████▋  | 154/200 [00:40<00:02, 15.95it/s]
#
# Dynamic Programming:  78%|███████▊  | 156/200 [00:40<00:02, 16.94it/s]
#
# Dynamic Programming:  80%|███████▉  | 159/200 [00:40<00:02, 18.11it/s]
#
# Dynamic Programming:  81%|████████  | 162/200 [00:40<00:01, 19.52it/s]
#
# Dynamic Programming:  82%|████████▎ | 165/200 [00:40<00:01, 21.20it/s]
#
# Dynamic Programming:  84%|████████▍ | 168/200 [00:40<00:01, 23.18it/s]
#
# Dynamic Programming:  86%|████████▌ | 172/200 [00:40<00:01, 25.71it/s]
#
# Dynamic Programming:  88%|████████▊ | 177/200 [00:41<00:00, 29.06it/s]
#
# Dynamic Programming: 100%|██████████| 200/200 [00:41<00:00,  4.85it/s]
#
#  99%|█████████▊| 69/70 [46:33<00:42, 42.29s/it]
#
# Dynamic Programming:   0%|          | 0/201 [00:00<?, ?it/s]
#
# Dynamic Programming:   0%|          | 1/201 [00:00<01:50,  1.82it/s]
#
# Dynamic Programming:   1%|          | 2/201 [00:01<01:50,  1.80it/s]
#
# Dynamic Programming:   1%|▏         | 3/201 [00:01<01:49,  1.81it/s]
#
# Dynamic Programming:   2%|▏         | 4/201 [00:02<01:48,  1.81it/s]
#
# Dynamic Programming:   2%|▏         | 5/201 [00:02<01:47,  1.83it/s]
#
# Dynamic Programming:   3%|▎         | 6/201 [00:03<01:46,  1.83it/s]
#
# Dynamic Programming:   3%|▎         | 7/201 [00:03<01:44,  1.85it/s]
#
# Dynamic Programming:   4%|▍         | 8/201 [00:04<01:44,  1.85it/s]
#
# Dynamic Programming:   4%|▍         | 9/201 [00:04<01:42,  1.88it/s]
#
# Dynamic Programming:   5%|▍         | 10/201 [00:05<01:40,  1.89it/s]
#
# Dynamic Programming:   5%|▌         | 11/201 [00:05<01:39,  1.91it/s]
#
# Dynamic Programming:   6%|▌         | 12/201 [00:06<01:37,  1.94it/s]
#
# Dynamic Programming:   6%|▋         | 13/201 [00:06<01:35,  1.96it/s]
#
# Dynamic Programming:   7%|▋         | 14/201 [00:07<01:34,  1.97it/s]
#
# Dynamic Programming:   7%|▋         | 15/201 [00:07<01:33,  1.99it/s]
#
# Dynamic Programming:   8%|▊         | 16/201 [00:08<01:32,  2.00it/s]
#
# Dynamic Programming:   8%|▊         | 17/201 [00:08<01:30,  2.04it/s]
#
# Dynamic Programming:   9%|▉         | 18/201 [00:09<01:29,  2.04it/s]
#
# Dynamic Programming:   9%|▉         | 19/201 [00:09<01:27,  2.08it/s]
#
# Dynamic Programming:  10%|▉         | 20/201 [00:10<01:26,  2.09it/s]
#
# Dynamic Programming:  10%|█         | 21/201 [00:10<01:24,  2.12it/s]
#
# Dynamic Programming:  11%|█         | 22/201 [00:11<01:24,  2.13it/s]
#
# Dynamic Programming:  11%|█▏        | 23/201 [00:11<01:22,  2.16it/s]
#
# Dynamic Programming:  12%|█▏        | 24/201 [00:12<01:21,  2.17it/s]
#
# Dynamic Programming:  12%|█▏        | 25/201 [00:12<01:19,  2.21it/s]
#
# Dynamic Programming:  13%|█▎        | 26/201 [00:12<01:18,  2.24it/s]
#
# Dynamic Programming:  13%|█▎        | 27/201 [00:13<01:17,  2.24it/s]
#
# Dynamic Programming:  14%|█▍        | 28/201 [00:13<01:15,  2.28it/s]
#
# Dynamic Programming:  14%|█▍        | 29/201 [00:14<01:15,  2.28it/s]
#
# Dynamic Programming:  15%|█▍        | 30/201 [00:14<01:13,  2.32it/s]
#
# Dynamic Programming:  15%|█▌        | 31/201 [00:15<01:13,  2.33it/s]
#
# Dynamic Programming:  16%|█▌        | 32/201 [00:15<01:11,  2.37it/s]
# Dynamic Programming:  16%|█▋        | 33/201 [00:15<01:09,  2.41it/s]
#
# Dynamic Programming:  17%|█▋        | 34/201 [00:16<01:09,  2.41it/s]
#
# Dynamic Programming:  17%|█▋        | 35/201 [00:16<01:07,  2.45it/s]
#
# Dynamic Programming:  18%|█▊        | 36/201 [00:17<01:07,  2.45it/s]
#
# Dynamic Programming:  18%|█▊        | 37/201 [00:17<01:05,  2.50it/s]
#
# Dynamic Programming:  19%|█▉        | 38/201 [00:17<01:04,  2.54it/s]
#
# Dynamic Programming:  19%|█▉        | 39/201 [00:18<01:03,  2.53it/s]
#
# Dynamic Programming:  20%|█▉        | 40/201 [00:18<01:02,  2.57it/s]
#
# Dynamic Programming:  20%|██        | 41/201 [00:19<01:01,  2.61it/s]
#
# Dynamic Programming:  21%|██        | 42/201 [00:19<01:01,  2.60it/s]
#
# Dynamic Programming:  21%|██▏       | 43/201 [00:19<00:59,  2.64it/s]
#
# Dynamic Programming:  22%|██▏       | 44/201 [00:20<00:59,  2.64it/s]
#
# Dynamic Programming:  22%|██▏       | 45/201 [00:20<00:58,  2.69it/s]
#
# Dynamic Programming:  23%|██▎       | 46/201 [00:20<00:56,  2.74it/s]
#
# Dynamic Programming:  23%|██▎       | 47/201 [00:21<00:56,  2.73it/s]
#
# Dynamic Programming:  24%|██▍       | 48/201 [00:21<00:55,  2.78it/s]
#
# Dynamic Programming:  24%|██▍       | 49/201 [00:21<00:53,  2.83it/s]
#
# Dynamic Programming:  25%|██▍       | 50/201 [00:22<00:53,  2.82it/s]
#
# Dynamic Programming:  25%|██▌       | 51/201 [00:22<00:52,  2.87it/s]
#
# Dynamic Programming:  26%|██▌       | 52/201 [00:22<00:51,  2.92it/s]
#
# Dynamic Programming:  26%|██▋       | 53/201 [00:23<00:50,  2.94it/s]
#
# Dynamic Programming:  27%|██▋       | 54/201 [00:23<00:48,  3.00it/s]
#
# Dynamic Programming:  27%|██▋       | 55/201 [00:23<00:47,  3.05it/s]
#
# Dynamic Programming:  28%|██▊       | 56/201 [00:24<00:47,  3.05it/s]
#
# Dynamic Programming:  28%|██▊       | 57/201 [00:24<00:46,  3.11it/s]
#
# Dynamic Programming:  29%|██▉       | 58/201 [00:24<00:45,  3.16it/s]
#
# Dynamic Programming:  29%|██▉       | 59/201 [00:25<00:45,  3.15it/s]
#
# Dynamic Programming:  30%|██▉       | 60/201 [00:25<00:43,  3.21it/s]
#
# Dynamic Programming:  30%|███       | 61/201 [00:25<00:42,  3.27it/s]
#
# Dynamic Programming:  31%|███       | 62/201 [00:26<00:41,  3.32it/s]
#
# Dynamic Programming:  31%|███▏      | 63/201 [00:26<00:41,  3.30it/s]
#
# Dynamic Programming:  32%|███▏      | 64/201 [00:26<00:40,  3.37it/s]
#
# Dynamic Programming:  32%|███▏      | 65/201 [00:26<00:39,  3.43it/s]
#
# Dynamic Programming:  33%|███▎      | 66/201 [00:27<00:39,  3.41it/s]
#
# Dynamic Programming:  33%|███▎      | 67/201 [00:27<00:38,  3.48it/s]
#
# Dynamic Programming:  34%|███▍      | 68/201 [00:27<00:37,  3.54it/s]
#
# Dynamic Programming:  34%|███▍      | 69/201 [00:28<00:36,  3.60it/s]
#
# Dynamic Programming:  35%|███▍      | 70/201 [00:28<00:35,  3.68it/s]
#
# Dynamic Programming:  35%|███▌      | 71/201 [00:28<00:34,  3.73it/s]
#
# Dynamic Programming:  36%|███▌      | 72/201 [00:28<00:34,  3.78it/s]
#
# Dynamic Programming:  36%|███▋      | 73/201 [00:29<00:33,  3.83it/s]
#
# Dynamic Programming:  37%|███▋      | 74/201 [00:29<00:33,  3.78it/s]
#
# Dynamic Programming:  37%|███▋      | 75/201 [00:29<00:32,  3.86it/s]
#
# Dynamic Programming:  38%|███▊      | 76/201 [00:29<00:31,  3.93it/s]
#
# Dynamic Programming:  38%|███▊      | 77/201 [00:30<00:31,  3.99it/s]
#
# Dynamic Programming:  39%|███▉      | 78/201 [00:30<00:31,  3.95it/s]
#
# Dynamic Programming:  39%|███▉      | 79/201 [00:30<00:30,  4.04it/s]
#
# Dynamic Programming:  40%|███▉      | 80/201 [00:30<00:29,  4.12it/s]
#
# Dynamic Programming:  40%|████      | 81/201 [00:31<00:28,  4.19it/s]
#
# Dynamic Programming:  41%|████      | 82/201 [00:31<00:28,  4.15it/s]
#
# Dynamic Programming:  41%|████▏     | 83/201 [00:31<00:27,  4.25it/s]
#
# Dynamic Programming:  42%|████▏     | 84/201 [00:31<00:27,  4.33it/s]
#
# Dynamic Programming:  42%|████▏     | 85/201 [00:31<00:26,  4.42it/s]
#
# Dynamic Programming:  43%|████▎     | 86/201 [00:32<00:25,  4.50it/s]
#
# Dynamic Programming:  43%|████▎     | 87/201 [00:32<00:25,  4.44it/s]
#
# Dynamic Programming:  44%|████▍     | 88/201 [00:32<00:24,  4.55it/s]
#
# Dynamic Programming:  44%|████▍     | 89/201 [00:32<00:24,  4.65it/s]
#
# Dynamic Programming:  45%|████▍     | 90/201 [00:32<00:23,  4.74it/s]
#
# Dynamic Programming:  45%|████▌     | 91/201 [00:33<00:22,  4.83it/s]
#
# Dynamic Programming:  46%|████▌     | 92/201 [00:33<00:22,  4.76it/s]
#
# Dynamic Programming:  46%|████▋     | 93/201 [00:33<00:22,  4.88it/s]
#
# Dynamic Programming:  47%|████▋     | 94/201 [00:33<00:21,  4.99it/s]
#
# Dynamic Programming:  47%|████▋     | 95/201 [00:33<00:20,  5.09it/s]
#
# Dynamic Programming:  48%|████▊     | 96/201 [00:34<00:20,  5.19it/s]
#
# Dynamic Programming:  48%|████▊     | 97/201 [00:34<00:20,  5.19it/s]
#
# Dynamic Programming:  49%|████▉     | 98/201 [00:34<00:19,  5.31it/s]
#
# Dynamic Programming:  49%|████▉     | 99/201 [00:34<00:18,  5.42it/s]
#
# Dynamic Programming:  50%|████▉     | 100/201 [00:34<00:18,  5.52it/s]
#
# Dynamic Programming:  50%|█████     | 101/201 [00:35<00:17,  5.62it/s]
#
# Dynamic Programming:  51%|█████     | 102/201 [00:35<00:17,  5.72it/s]
#
# Dynamic Programming:  51%|█████     | 103/201 [00:35<00:17,  5.61it/s]
#
# Dynamic Programming:  52%|█████▏    | 104/201 [00:35<00:16,  5.77it/s]
#
# Dynamic Programming:  52%|█████▏    | 105/201 [00:35<00:16,  5.91it/s]
#
# Dynamic Programming:  53%|█████▎    | 106/201 [00:35<00:15,  6.03it/s]
#
# Dynamic Programming:  53%|█████▎    | 107/201 [00:36<00:15,  6.16it/s]
#
# Dynamic Programming:  54%|█████▎    | 108/201 [00:36<00:14,  6.29it/s]
#
# Dynamic Programming:  54%|█████▍    | 109/201 [00:36<00:14,  6.16it/s]
#
# Dynamic Programming:  55%|█████▍    | 110/201 [00:36<00:14,  6.34it/s]
#
# Dynamic Programming:  55%|█████▌    | 111/201 [00:36<00:13,  6.50it/s]
#
# Dynamic Programming:  56%|█████▌    | 112/201 [00:36<00:13,  6.66it/s]
#
# Dynamic Programming:  56%|█████▌    | 113/201 [00:36<00:12,  6.80it/s]
#
# Dynamic Programming:  57%|█████▋    | 114/201 [00:37<00:12,  6.94it/s]
#
# Dynamic Programming:  57%|█████▋    | 115/201 [00:37<00:12,  7.08it/s]
#
# Dynamic Programming:  58%|█████▊    | 116/201 [00:37<00:12,  6.89it/s]
#
# Dynamic Programming:  58%|█████▊    | 117/201 [00:37<00:11,  7.12it/s]
#
# Dynamic Programming:  59%|█████▊    | 118/201 [00:37<00:11,  7.32it/s]
#
# Dynamic Programming:  59%|█████▉    | 119/201 [00:37<00:10,  7.51it/s]
#
# Dynamic Programming:  60%|█████▉    | 120/201 [00:37<00:10,  7.68it/s]
#
# Dynamic Programming:  60%|██████    | 121/201 [00:37<00:10,  7.85it/s]
#
# Dynamic Programming:  61%|██████    | 122/201 [00:38<00:09,  8.02it/s]
#
# Dynamic Programming:  61%|██████    | 123/201 [00:38<00:09,  8.19it/s]
#
# Dynamic Programming:  62%|██████▏   | 124/201 [00:38<00:09,  7.96it/s]
#
# Dynamic Programming:  62%|██████▏   | 125/201 [00:38<00:09,  8.23it/s]
#
# Dynamic Programming:  63%|██████▎   | 126/201 [00:38<00:08,  8.48it/s]
#
# Dynamic Programming:  63%|██████▎   | 127/201 [00:38<00:08,  8.70it/s]
#
# Dynamic Programming:  64%|██████▎   | 128/201 [00:38<00:08,  8.93it/s]
#
# Dynamic Programming:  64%|██████▍   | 129/201 [00:38<00:07,  9.14it/s]
#
# Dynamic Programming:  65%|██████▍   | 130/201 [00:38<00:07,  9.35it/s]
#
# Dynamic Programming:  66%|██████▌   | 132/201 [00:39<00:07,  9.61it/s]
#
# Dynamic Programming:  67%|██████▋   | 134/201 [00:39<00:06,  9.61it/s]
#
# Dynamic Programming:  68%|██████▊   | 136/201 [00:39<00:06, 10.04it/s]
#
# Dynamic Programming:  69%|██████▊   | 138/201 [00:39<00:06, 10.49it/s]
#
# Dynamic Programming:  70%|██████▉   | 140/201 [00:39<00:05, 10.95it/s]
#
# Dynamic Programming:  71%|███████   | 142/201 [00:40<00:05, 11.46it/s]
#
# Dynamic Programming:  72%|███████▏  | 144/201 [00:40<00:04, 12.00it/s]
#
# Dynamic Programming:  73%|███████▎  | 146/201 [00:40<00:04, 12.11it/s]
#
# Dynamic Programming:  74%|███████▎  | 148/201 [00:40<00:04, 12.83it/s]
#
# Dynamic Programming:  75%|███████▍  | 150/201 [00:40<00:03, 13.59it/s]
#
# Dynamic Programming:  76%|███████▌  | 152/201 [00:40<00:03, 14.39it/s]
#
# Dynamic Programming:  77%|███████▋  | 154/201 [00:40<00:03, 15.26it/s]
#
# Dynamic Programming:  78%|███████▊  | 156/201 [00:40<00:02, 16.19it/s]
#
# Dynamic Programming:  79%|███████▉  | 159/201 [00:41<00:02, 17.28it/s]
#
# Dynamic Programming:  81%|████████  | 162/201 [00:41<00:02, 18.62it/s]
#
# Dynamic Programming:  82%|████████▏ | 164/201 [00:41<00:01, 18.90it/s]
#
# Dynamic Programming:  83%|████████▎ | 167/201 [00:41<00:01, 20.82it/s]
#
# Dynamic Programming:  85%|████████▌ | 171/201 [00:41<00:01, 23.17it/s]
#
# Dynamic Programming:  87%|████████▋ | 175/201 [00:41<00:00, 26.26it/s]
#
# Dynamic Programming:  90%|████████▉ | 180/201 [00:41<00:00, 30.44it/s]
#
# Dynamic Programming: 100%|██████████| 201/201 [00:41<00:00,  4.79it/s]
#
# 100%|██████████| 70/70 [47:15<00:00, 40.51s/it]

# %%
ecptssCtrl_comU = [len(ix.mbic_ecpts) for ix in detRessCtrl_comU]
ecptssAD_comU = [len(ix.mbic_ecpts) for ix in detRessAD_comU]

# %%
res = ttest_ind(ecptssCtrl_comU, ecptssAD_comU, equal_var=False)
plt.figure(figsize=[5, 5])
sns.boxplot(data=[ecptssCtrl_comU, ecptssAD_comU], showfliers=0)
plt.xticks([0, 1], ["Ctrl", "AD"])
plt.title(f"Num of switching points (T-test:{res.pvalue:.3f})")
# Out:
# Text(0.5, 1.0, 'Num of switching points (T-test:0.388)')

# %% [markdown]
# ### Analysis the two group separately.

# %%
AmatAD = GetAmat(dXmatsAD, XmatsAD, timeSpan, downrate=paras.downRate, fct=paras.fct, is_sum=True)
ResAD_ADU = GetNewData(dXmatsAD, XmatsAD, AmatAD, paras.r, True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [02:40<00:00,  1.82s/it]

# %%
canptssAD_ADU = Screening(ResAD_ADU.ndXmats, ResAD_ADU.nXmats, wh=paras.wh, showProgress=True)
# Out:
# Screening: 100%|██████████████████████████████████████████████████████████████████████████████████████| 88/88 [20:42<00:00, 14.11s/it]

# %%
detRessAD_ADU = []
for ix in trange(len(canptssAD_ADU)):
    res = EGenDy(ResAD_ADU.ndXmats[ix], ResAD_ADU.nXmats[ix], paras.kappa, Lmin=paras.Lmin, 
          canpts=canptssAD_ADU[ix], MaxM=paras.MaxM, is_full=False, 
          showProgress=False)
    detRessAD_ADU.append(res)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [56:50<00:00, 38.76s/it]

# %%
ecptssCtrl = [len(ix.mbic_ecpts) for ix in detRessCtrl]
ecptssAD_ADU = [len(ix.mbic_ecpts) for ix in detRessAD_ADU]

# %%
res = ttest_ind(ecptssCtrl, ecptssAD_ADU, equal_var=False)
plt.figure(figsize=[5, 5])
sns.boxplot(data=[ecptssCtrl, ecptssAD_ADU], showfliers=0)
plt.xticks([0, 1], ["Ctrl", "AD"])
plt.title(f"Num of switching points (T-test:{res.pvalue:.3f})")
# Out:
# Text(0.5, 1.0, 'Num of switching points (T-test:0.938)')

# %% [markdown]
# ### Compare AD and Ctrl Us

# %%
import pandas as pd
from scipy.stats import pearsonr
import seaborn as sns
def minmax(x):
    rev = (x - np.min(x))/(np.max(x) - np.min(x))
    return rev

# %%
AmatAD = GetAmat(dXmatsAD, XmatsAD, timeSpan, downrate=paras.downRate, fct=paras.fct, is_sum=True)
ResAD = GetNewData(dXmatsAD, XmatsAD, AmatAD, paras.r, True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:24<00:00,  3.59it/s]

# %%
AmatCtrl = GetAmat(dXmatsCtrl, XmatsCtrl, timeSpan, downrate=paras.downRate, fct=paras.fct, is_sum=True)
ResCtrl = GetNewData(dXmatsCtrl, XmatsCtrl, AmatCtrl, paras.r, True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:24<00:00,  3.63it/s]

# %%
defNetsFil = list(dataDir.glob("DK_dic68.csv"))[0]
defNets = pd.read_csv(defNetsFil).T

mmDefNets = {}
for ix in range(defNets.shape[-1]):
    curCol = defNets[ix]
    mmDefNets[curCol[0]] = minmax(np.array(curCol[1:]))
kysOrd = sorted(mmDefNets.keys())

# %%
curUs = np.abs(res.factors[1][:, :20])
corrMat = np.zeros((7, curUs.shape[-1]))
for ix in range(curUs.shape[-1]):
    curU = minmax(curUs[:, ix])
    for iy, ky in enumerate(kysOrd):
        curV = mmDefNets[ky]
        corrMat[iy, ix] = pearsonr(curU, curV)[0]
#corrMat = np.abs(corrMat)

plt.figure(figsize=[20, 4])
#sns.heatmap(corrMat,  yticklabels=kysOrd, cmap="hot_r", vmin=0, vmax=1, annot=np.round(corrMat, 2))
sns.heatmap(corrMat,  yticklabels=kysOrd, cmap="coolwarm", center=0, vmin=-1, vmax=1, annot=np.round(corrMat, 2))
# Out:
# <AxesSubplot:>

# %%
ADUs = np.abs(ResAD.eigVecs[:, ResAD.kpidxs])
corrMatAD = np.zeros((7, ADUs.shape[-1]))
for ix in range(ADUs.shape[-1]):
    curU = minmax(ADUs[:, ix])
    for iy, ky in enumerate(kysOrd):
        curV = mmDefNets[ky]
        corrMatAD[iy, ix] = pearsonr(curU, curV)[0]

# %%
CtrlUs = np.abs(ResCtrl.eigVecs[:, ResCtrl.kpidxs])
corrMatCtrl = np.zeros((7, CtrlUs.shape[-1]))
for ix in range(CtrlUs.shape[-1]):
    curU = minmax(CtrlUs[:, ix])
    for iy, ky in enumerate(kysOrd):
        curV = mmDefNets[ky]
        corrMatCtrl[iy, ix] = pearsonr(curU, curV)[0]

# %%
plt.figure(figsize=[10, 4])
plt.title("Amat-AD")
sns.heatmap(corrMatAD,  yticklabels=kysOrd, cmap="coolwarm", center=0, vmin=-1, vmax=1, annot=corrMatAD)
plt.xlabel("U")

plt.figure(figsize=[10, 4])
plt.title("Amat-Ctrl")
sns.heatmap(corrMatCtrl,  yticklabels=kysOrd, cmap="coolwarm", center=0, vmin=-1, vmax=1, annot=corrMatCtrl)
plt.xlabel("U")
# Out:
# Text(0.5, 15.0, 'U')

# %% [markdown]
# #### save in brain

# %%
def reorderU(wU):
    wUreorder = np.zeros_like(wU, dtype=np.float64)
    wUreorder[0::2] = wU[:34]
    wUreorder[1::2] = wU[34:]
    return wUreorder

# %%
with open(dataDir/'BNVtemplate_DK68.txt', "r") as tf:
    DKtmplateRaw = tf.readlines()
DKtmplate = np.array([int(x.strip()) for x in DKtmplateRaw])

def U2BrainVec(wU):
    emVec = np.zeros_like(DKtmplate, dtype=np.float64)
    for idx in range(1, 69):
        emVec[DKtmplate==idx] = wU[idx-1]
    return emVec

# %%
curUs = CtrlUs
for ix in range(curUs.shape[-1]):
    curU = minmax(curUs[:, ix])
    outVec = U2BrainVec(reorderU(curU))
    np.savetxt(resDir/f"Ctrl_U_{ix}.txt", outVec)
    #np.savetxt(resDir/f"AD_U_{ix}.txt", outVec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1023/1847527158.py in <module>
# ----> 1 curUs = CtrlUs
#       2 for ix in range(curUs.shape[-1]):
#       3     curU = minmax(curUs[:, ix])
#       4     outVec = U2BrainVec(reorderU(curU))
#       5     np.savetxt(resDir/f"Ctrl_U_{ix}.txt", outVec)
#
# NameError: name 'CtrlUs' is not defined

# %%
np.savetxt("test.txt", outVec)

# %%
def GetAmatS(dXmat, Xmat):
    N, d, n = Xmats.shape
    Amat = np.zeros((d, d))
    kerdXmat = dXmat.T # n x d
    kerXmat = Xmat.T # n x d
    M = kerXmat.T.dot(kerXmat)/n
    XY = kerdXmat.T.dot(kerXmat)/n # it is Y\trans x X , formula is Amat = Y\trans X (X\trans X)^{-1}
    U, S, VT = np.linalg.svd(M)
    # Num of singular values to keep
    r = np.argmax(np.cumsum(S)/np.sum(S) >= 0.999) + 1 # For real data
    invM = VT.T[:, :r].dot(np.diag(1/S[:r])).dot(U.T[:r, :]) # M is symmetric and PSD
    Amat = XY.dot(invM)
    return Amat

# %%
Usall = []
r = 20
for ix in trange(70):
    curAmat = GetAmatS(dXmats[ix], Xmats[ix])
    eigVals, eigVecs = np.linalg.eig(curAmat)
    # sort the eigvs and eigvecs
    sidx = np.argsort(-np.abs(eigVals))
    eigVals = eigVals[sidx]
    eigVecs = eigVecs[:, sidx]
        
    # if breaking conjugate eigval pair, add r with 1
    if (eigVals[r-1].imag + eigVals[r].imag ) == 0:
        r = r + 1

    eigValsfull = np.concatenate([[np.Inf], eigVals])
    kpidxs = np.where(np.diff(np.abs(eigValsfull))[:r] != 0)[0]
    Usall.append(np.abs(eigVecs[:, kpidxs]))
# Out:
# 100%|██████████| 70/70 [00:00<00:00, 166.26it/s]

# %%
from sklearn.cluster import KMeans
UsallArr = np.concatenate(Usall, axis=1).T
kmeans = KMeans(n_clusters=7, random_state=0).fit(UsallArr)
# Out:
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:445: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_iter=max_iter, verbose=verbose)
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:445: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_iter=max_iter, verbose=verbose)
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:445: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_iter=max_iter, verbose=verbose)
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:445: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_iter=max_iter, verbose=verbose)
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/huaqingj/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float

# %%
KCs = kmeans.cluster_centers_.T
corrMatKCs = np.zeros((7, KCs.shape[-1]))
for ix in range(KCs.shape[-1]):
    curU = minmax(KCs[:, ix])
    for iy, ky in enumerate(kysOrd):
        curV = mmDefNets[ky]
        corrMatKCs[iy, ix] = pearsonr(curU, curV)[0]

# %%
plt.figure(figsize=[10, 5])
plt.title("Kmeans static")
sns.heatmap(corrMatKCs,  yticklabels=kysOrd, cmap="coolwarm", center=0, vmin=-1, vmax=1, annot=corrMatKCs)
plt.xlabel("U")
# Out:
# Text(0.5, 24.0, 'U')

# %% [markdown]
# ## later

# %%
canptss = Screening(Res.ndXmats, Res.nXmats, wh=paras.wh, showProgress=True)
# Out:
# Screening: 100%|██████████| 10/10 [01:12<00:00,  7.26s/it]

# %%
detRess = []
for ix in trange(10):
    res = EGenDy(Res.ndXmats[ix], Res.nXmats[ix], paras.kappa, Lmin=paras.Lmin, 
          canpts=canptss[ix], MaxM=paras.MaxM, is_full=True, 
          showProgress=True)
    detRess.append(res)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Dynamic Programming:   0%|          | 0/191 [00:00<?, ?it/s]
# Dynamic Programming:   1%|          | 1/191 [00:00<01:42,  1.86it/s]
# Dynamic Programming:   1%|          | 2/191 [00:01<01:40,  1.88it/s]
# Dynamic Programming:   2%|▏         | 3/191 [00:01<01:40,  1.87it/s]
# Dynamic Programming:   2%|▏         | 4/191 [00:02<01:38,  1.90it/s]
# Dynamic Programming:   3%|▎         | 5/191 [00:02<01:37,  1.90it/s]
# Dynamic Programming:   3%|▎         | 6/191 [00:03<01:35,  1.93it/s]
# Dynamic Programming:   4%|▎         | 7/191 [00:03<01:35,  1.93it/s]
# Dynamic Programming:   4%|▍         | 8/191 [00:04<01:33,  1.96it/s]
# Dynamic Programming:   5%|▍         | 9/191 [00:04<01:32,  1.97it/s]
# Dynamic Programming:   5%|▌         | 10/191 [00:05<01:30,  2.00it/s]
# Dynamic Programming:   6%|▌         | 11/191 [00:05<01:29,  2.01it/s]
# Dynamic Programming:   6%|▋         | 12/191 [00:06<01:27,  2.04it/s]
# Dynamic Programming:   7%|▋         | 13/191 [00:06<01:26,  2.05it/s]
# Dynamic Programming:   7%|▋         | 14/191 [00:07<01:24,  2.08it/s]
# Dynamic Programming:   8%|▊         | 15/191 [00:07<01:23,  2.10it/s]
# Dynamic Programming:   8%|▊         | 16/191 [00:07<01:22,  2.13it/s]
# Dynamic Programming:   9%|▉         | 17/191 [00:08<01:20,  2.16it/s]
# Dynamic Programming:   9%|▉         | 18/191 [00:08<01:20,  2.15it/s]
# Dynamic Programming:  10%|▉         | 19/191 [00:09<01:18,  2.19it/s]
# Dynamic Programming:  10%|█         | 20/191 [00:09<01:18,  2.19it/s]
# Dynamic Programming:  11%|█         | 21/191 [00:10<01:16,  2.22it/s]
# Dynamic Programming:  12%|█▏        | 22/191 [00:10<01:16,  2.22it/s]
# Dynamic Programming:  12%|█▏        | 23/191 [00:11<01:14,  2.26it/s]
# Dynamic Programming:  13%|█▎        | 24/191 [00:11<01:12,  2.29it/s]
# Dynamic Programming:  13%|█▎        | 25/191 [00:11<01:12,  2.29it/s]
# Dynamic Programming:  14%|█▎        | 26/191 [00:12<01:10,  2.32it/s]
# Dynamic Programming:  14%|█▍        | 27/191 [00:12<01:10,  2.32it/s]
# Dynamic Programming:  78%|███████▊  | 154/197 [00:39<00:02, 16.39it/s]
# Dynamic Programming:  80%|███████▉  | 157/197 [00:39<00:02, 17.62it/s]
# Dynamic Programming:  81%|████████  | 160/197 [00:39<00:02, 18.46it/s]
# Dynamic Programming:  83%|████████▎ | 163/197 [00:39<00:01, 20.39it/s]
# Dynamic Programming:  85%|████████▍ | 167/197 [00:40<00:01, 22.76it/s]
# Dynamic Programming:  87%|████████▋ | 171/197 [00:40<00:01, 25.72it/s]
# Dynamic Programming:  89%|████████▉ | 176/197 [00:40<00:00, 29.78it/s]
# Dynamic Programming: 100%|██████████| 197/197 [00:40<00:00,  4.87it/s]
#  20%|██        | 2/10 [01:18<05:12, 39.10s/it]
# Dynamic Programming:   0%|          | 0/189 [00:00<?, ?it/s]
# Dynamic Programming:   1%|          | 1/189 [00:00<01:40,  1.87it/s]
# Dynamic Programming:   1%|          | 2/189 [00:01<01:38,  1.89it/s]
# Dynamic Programming:   2%|▏         | 3/189 [00:01<01:38,  1.89it/s]
# Dynamic Programming:   2%|▏         | 4/189 [00:02<01:36,  1.91it/s]
# Dynamic Programming:   3%|▎         | 5/189 [00:02<01:36,  1.91it/s]
# Dynamic Programming:   3%|▎         | 6/189 [00:03<01:34,  1.94it/s]
# Dynamic Programming:   4%|▎         | 7/189 [00:03<01:33,  1.94it/s]
# Dynamic Programming:   4%|▍         | 8/189 [00:04<01:31,  1.97it/s]
# Dynamic Programming:   5%|▍         | 9/189 [00:04<01:31,  1.97it/s]
# Dynamic Programming:   5%|▌         | 10/189 [00:05<01:29,  2.01it/s]
# Dynamic Programming:   6%|▌         | 11/189 [00:05<01:28,  2.01it/s]
# Dynamic Programming:   6%|▋         | 12/189 [00:06<01:26,  2.05it/s]
# Dynamic Programming:   7%|▋         | 13/189 [00:06<01:25,  2.06it/s]
# Dynamic Programming:   7%|▋         | 14/189 [00:06<01:23,  2.10it/s]
# Dynamic Programming:   8%|▊         | 15/189 [00:07<01:22,  2.10it/s]
# Dynamic Programming:   8%|▊         | 16/189 [00:07<01:20,  2.14it/s]
# Dynamic Programming:   9%|▉         | 17/189 [00:08<01:19,  2.17it/s]
# Dynamic Programming:  10%|▉         | 18/189 [00:08<01:17,  2.22it/s]
# Dynamic Programming:  10%|█         | 19/189 [00:09<01:15,  2.24it/s]
# Dynamic Programming:  11%|█         | 20/189 [00:09<01:15,  2.24it/s]
# Dynamic Programming:  11%|█         | 21/189 [00:10<01:13,  2.28it/s]
# Dynamic Programming:  12%|█▏        | 22/189 [00:10<01:13,  2.28it/s]
# Dynamic Programming:  12%|█▏        | 23/189 [00:10<01:11,  2.32it/s]
# Dynamic Programming:  13%|█▎        | 24/189 [00:11<01:10,  2.35it/s]
# Dynamic Programming:  13%|█▎        | 25/189 [00:11<01:09,  2.35it/s]
# Dynamic Programming:  14%|█▍        | 26/189 [00:12<01:08,  2.39it/s]
# Dynamic Programming:  14%|█▍        | 27/189 [00:12<01:07,  2.38it/s]
# Dynamic Programming:  15%|█▍        | 28/189 [00:13<01:06,  2.43it/s]
# Dynamic Programming:  86%|████████▌ | 163/189 [00:37<00:01, 24.88it/s]
# Dynamic Programming:  89%|████████▉ | 168/189 [00:37<00:00, 28.82it/s]
# Dynamic Programming: 100%|██████████| 189/189 [00:37<00:00,  4.99it/s]
#  30%|███       | 3/10 [01:56<04:31, 38.73s/it]
# Dynamic Programming:   0%|          | 0/200 [00:00<?, ?it/s]
# Dynamic Programming:   0%|          | 1/200 [00:00<01:47,  1.86it/s]
# Dynamic Programming:   1%|          | 2/200 [00:01<01:48,  1.83it/s]
# Dynamic Programming:   2%|▏         | 3/200 [00:01<01:47,  1.84it/s]
# Dynamic Programming:   2%|▏         | 4/200 [00:02<01:47,  1.83it/s]
# Dynamic Programming:   2%|▎         | 5/200 [00:02<01:45,  1.85it/s]
# Dynamic Programming:   3%|▎         | 6/200 [00:03<01:44,  1.85it/s]
# Dynamic Programming:   4%|▎         | 7/200 [00:03<01:42,  1.88it/s]
# Dynamic Programming:   4%|▍         | 8/200 [00:04<01:42,  1.88it/s]
# Dynamic Programming:   4%|▍         | 9/200 [00:04<01:40,  1.91it/s]
# Dynamic Programming:   5%|▌         | 10/200 [00:05<01:39,  1.91it/s]
# Dynamic Programming:   6%|▌         | 11/200 [00:05<01:37,  1.94it/s]
# Dynamic Programming:   6%|▌         | 12/200 [00:06<01:36,  1.94it/s]
# Dynamic Programming:   6%|▋         | 13/200 [00:06<01:34,  1.97it/s]
# Dynamic Programming:   7%|▋         | 14/200 [00:07<01:34,  1.98it/s]
# Dynamic Programming:   8%|▊         | 15/200 [00:07<01:32,  2.01it/s]
# Dynamic Programming:   8%|▊         | 16/200 [00:08<01:31,  2.01it/s]
# Dynamic Programming:   8%|▊         | 17/200 [00:08<01:29,  2.04it/s]
# Dynamic Programming:   9%|▉         | 18/200 [00:09<01:28,  2.06it/s]
# Dynamic Programming:  10%|▉         | 19/200 [00:09<01:26,  2.09it/s]
# Dynamic Programming:  10%|█         | 20/200 [00:10<01:26,  2.09it/s]
# Dynamic Programming:  10%|█         | 21/200 [00:10<01:24,  2.12it/s]
# Dynamic Programming:  11%|█         | 22/200 [00:11<01:23,  2.13it/s]
# Dynamic Programming:  12%|█▏        | 23/200 [00:11<01:21,  2.16it/s]
# Dynamic Programming:  12%|█▏        | 24/200 [00:12<01:20,  2.19it/s]
# Dynamic Programming:  12%|█▎        | 25/200 [00:12<01:19,  2.19it/s]
# Dynamic Programming:  13%|█▎        | 26/200 [00:12<01:18,  2.23it/s]
# Dynamic Programming:  14%|█▎        | 27/200 [00:13<01:17,  2.22it/s]
# Dynamic Programming:  14%|█▍        | 28/200 [00:13<01:16,  2.26it/s]
# Dynamic Programming:  14%|█▍        | 29/200 [00:14<01:15,  2.26it/s]
# Dynamic Programming:  15%|█▌        | 30/200 [00:14<01:13,  2.30it/s]
# Dynamic Programming:  16%|█▌        | 31/200 [00:15<01:12,  2.34it/s]
# Dynamic Programming:  16%|█▌        | 32/200 [00:15<01:11,  2.35it/s]
# Dynamic Programming:  16%|█▋        | 33/200 [00:15<01:09,  2.39it/s]
# Dynamic Programming:  78%|███████▊  | 155/200 [00:41<00:02, 15.70it/s]
# Dynamic Programming:  78%|███████▊  | 157/200 [00:41<00:02, 16.65it/s]
# Dynamic Programming:  80%|████████  | 160/200 [00:41<00:02, 17.25it/s]
# Dynamic Programming:  82%|████████▏ | 163/200 [00:41<00:01, 18.69it/s]
# Dynamic Programming:  83%|████████▎ | 166/200 [00:41<00:01, 20.54it/s]
# Dynamic Programming:  85%|████████▌ | 170/200 [00:41<00:01, 22.97it/s]
# Dynamic Programming:  87%|████████▋ | 174/200 [00:41<00:01, 25.95it/s]
# Dynamic Programming:  90%|████████▉ | 179/200 [00:42<00:00, 30.00it/s]
# Dynamic Programming: 100%|██████████| 200/200 [00:42<00:00,  4.74it/s]
#  40%|████      | 4/10 [02:39<03:58, 39.77s/it]
# Dynamic Programming:   0%|          | 0/202 [00:00<?, ?it/s]
# Dynamic Programming:   0%|          | 1/202 [00:00<01:51,  1.79it/s]
# Dynamic Programming:   1%|          | 2/202 [00:01<01:50,  1.81it/s]
# Dynamic Programming:   1%|▏         | 3/202 [00:01<01:50,  1.81it/s]
# Dynamic Programming:   2%|▏         | 4/202 [00:02<01:48,  1.83it/s]
# Dynamic Programming:   2%|▏         | 5/202 [00:02<01:47,  1.83it/s]
# Dynamic Programming:   3%|▎         | 6/202 [00:03<01:46,  1.84it/s]
# Dynamic Programming:   3%|▎         | 7/202 [00:03<01:44,  1.86it/s]
# Dynamic Programming:   4%|▍         | 8/202 [00:04<01:43,  1.87it/s]
# Dynamic Programming:   4%|▍         | 9/202 [00:04<01:41,  1.90it/s]
# Dynamic Programming:   5%|▍         | 10/202 [00:05<01:40,  1.90it/s]
# Dynamic Programming:   5%|▌         | 11/202 [00:05<01:38,  1.93it/s]
# Dynamic Programming:   6%|▌         | 12/202 [00:06<01:38,  1.93it/s]
# Dynamic Programming:   6%|▋         | 13/202 [00:06<01:36,  1.97it/s]
# Dynamic Programming:   7%|▋         | 14/202 [00:07<01:35,  1.97it/s]
# Dynamic Programming:   7%|▋         | 15/202 [00:07<01:33,  2.00it/s]
# Dynamic Programming:   8%|▊         | 16/202 [00:08<01:32,  2.01it/s]
# Dynamic Programming:   8%|▊         | 17/202 [00:08<01:30,  2.04it/s]
# Dynamic Programming:   9%|▉         | 18/202 [00:09<01:28,  2.07it/s]
# Dynamic Programming:   9%|▉         | 19/202 [00:09<01:27,  2.09it/s]
# Dynamic Programming:  10%|▉         | 20/202 [00:10<01:25,  2.12it/s]
# Dynamic Programming:  10%|█         | 21/202 [00:10<01:25,  2.12it/s]
# Dynamic Programming:  11%|█         | 22/202 [00:11<01:23,  2.15it/s]
# Dynamic Programming:  11%|█▏        | 23/202 [00:11<01:23,  2.15it/s]
# Dynamic Programming:  12%|█▏        | 24/202 [00:12<01:21,  2.19it/s]
# Dynamic Programming:  12%|█▏        | 25/202 [00:12<01:20,  2.19it/s]
# Dynamic Programming:  13%|█▎        | 26/202 [00:12<01:19,  2.23it/s]
# Dynamic Programming:   2%|▏         | 4/200 [00:02<01:48,  1.81it/s]
# Dynamic Programming:   2%|▎         | 5/200 [00:02<01:47,  1.82it/s]
# Dynamic Programming:   3%|▎         | 6/200 [00:03<01:45,  1.84it/s]
# Dynamic Programming:   4%|▎         | 7/200 [00:03<01:44,  1.85it/s]
# Dynamic Programming:   4%|▍         | 8/200 [00:04<01:42,  1.87it/s]
# Dynamic Programming:   4%|▍         | 9/200 [00:04<01:41,  1.88it/s]
# Dynamic Programming:   5%|▌         | 10/200 [00:05<01:39,  1.91it/s]
# Dynamic Programming:   6%|▌         | 11/200 [00:05<01:38,  1.91it/s]
# Dynamic Programming:   6%|▌         | 12/200 [00:06<01:36,  1.94it/s]
# Dynamic Programming:   6%|▋         | 13/200 [00:06<01:35,  1.96it/s]
# Dynamic Programming:   7%|▋         | 14/200 [00:07<01:34,  1.98it/s]
# Dynamic Programming:   8%|▊         | 15/200 [00:07<01:33,  1.98it/s]
# Dynamic Programming:   8%|▊         | 16/200 [00:08<01:31,  2.01it/s]
# Dynamic Programming:   8%|▊         | 17/200 [00:08<01:30,  2.02it/s]
# Dynamic Programming:   9%|▉         | 18/200 [00:09<01:28,  2.05it/s]
# Dynamic Programming:  10%|▉         | 19/200 [00:09<01:28,  2.05it/s]
# Dynamic Programming:  10%|█         | 20/200 [00:10<01:26,  2.09it/s]
# Dynamic Programming:  10%|█         | 21/200 [00:10<01:25,  2.09it/s]
# Dynamic Programming:  11%|█         | 22/200 [00:11<01:23,  2.12it/s]
# Dynamic Programming:  12%|█▏        | 23/200 [00:11<01:22,  2.15it/s]
# Dynamic Programming:  12%|█▏        | 24/200 [00:12<01:20,  2.18it/s]
# Dynamic Programming:  12%|█▎        | 25/200 [00:12<01:20,  2.18it/s]
# Dynamic Programming:  13%|█▎        | 26/200 [00:12<01:18,  2.21it/s]
# Dynamic Programming:  14%|█▎        | 27/200 [00:13<01:17,  2.25it/s]
# Dynamic Programming:  14%|█▍        | 28/200 [00:13<01:16,  2.25it/s]
# Dynamic Programming:  14%|█▍        | 29/200 [00:14<01:14,  2.28it/s]
# Dynamic Programming:  15%|█▌        | 30/200 [00:14<01:14,  2.28it/s]
# Dynamic Programming:  16%|█▌        | 31/200 [00:15<01:12,  2.32it/s]
# Dynamic Programming:  16%|█▌        | 32/200 [00:15<01:11,  2.36it/s]
# Dynamic Programming:  16%|█▋        | 33/200 [00:15<01:10,  2.35it/s]
# Dynamic Programming:  17%|█▋        | 34/200 [00:16<01:09,  2.39it/s]
# Dynamic Programming:  18%|█▊        | 35/200 [00:16<01:09,  2.39it/s]
# Dynamic Programming:  18%|█▊        | 36/200 [00:17<01:07,  2.44it/s]
# Dynamic Programming:  18%|█▊        | 37/200 [00:17<01:05,  2.48it/s]
# Dynamic Programming:  19%|█▉        | 38/200 [00:17<01:05,  2.47it/s]
# Dynamic Programming:  20%|█▉        | 39/200 [00:18<01:03,  2.52it/s]
# Dynamic Programming:  20%|██        | 40/200 [00:18<01:03,  2.52it/s]
